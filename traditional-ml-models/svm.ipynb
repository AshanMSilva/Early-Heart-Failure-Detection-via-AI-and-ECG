# %% [markdown]
# # Imports

# %%
# !pip install imbalanced-learn
# !pip install xgboost
# Out:
# Requirement already satisfied: imbalanced-learn in c:\users\chanuka athalage\appdata\local\programs\python\python312\lib\site-packages (0.14.0)
# Requirement already satisfied: numpy<3,>=1.25.2 in c:\users\chanuka athalage\appdata\local\programs\python\python312\lib\site-packages (from imbalanced-learn) (1.26.4)
# Requirement already satisfied: scipy<2,>=1.11.4 in c:\users\chanuka athalage\appdata\local\programs\python\python312\lib\site-packages (from imbalanced-learn) (1.15.2)
# Requirement already satisfied: scikit-learn<2,>=1.4.2 in c:\users\chanuka athalage\appdata\local\programs\python\python312\lib\site-packages (from imbalanced-learn) (1.6.1)
# Requirement already satisfied: joblib<2,>=1.2.0 in c:\users\chanuka athalage\appdata\local\programs\python\python312\lib\site-packages (from imbalanced-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl<4,>=2.0.0 in c:\users\chanuka athalage\appdata\local\programs\python\python312\lib\site-packages (from imbalanced-learn) (3.6.0)
# [notice] A new release of pip is available: 23.2.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: xgboost in c:\users\chanuka athalage\appdata\local\programs\python\python312\lib\site-packages (3.0.4)
# Requirement already satisfied: numpy in c:\users\chanuka athalage\appdata\local\programs\python\python312\lib\site-packages (from xgboost) (1.26.4)
# Requirement already satisfied: scipy in c:\users\chanuka athalage\appdata\local\programs\python\python312\lib\site-packages (from xgboost) (1.15.2)
# [notice] A new release of pip is available: 23.2.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from data_utils import train

# %% [markdown]
# # Train Model

# %% [markdown]
# ## 2D_CNN

# %% [markdown]
# ### Datasets

# %%
cnn_2d_dataset_paths = [
    "../feature-extraction/2D_cnn/datasets/features_with_metadata_base_dense32.csv",
    "../feature-extraction/2D_cnn/datasets/features_with_metadata_base_dense64.csv",
    "../feature-extraction/2D_cnn/datasets/features_with_metadata_base_dense128.csv",
    "../feature-extraction/2D_cnn/datasets/features_with_metadata_base_dense256.csv",
    "../feature-extraction/2D_cnn/datasets/features_with_metadata_oversampling_dense32.csv",
    "../feature-extraction/2D_cnn/datasets/features_with_metadata_oversampling_dense64.csv",
    "../feature-extraction/2D_cnn/datasets/features_with_metadata_oversampling_dense128.csv",
    "../feature-extraction/2D_cnn/datasets/features_with_metadata_oversampling_dense256.csv",
    "../feature-extraction/2D_cnn/datasets/features_with_metadata_undersampling_dense32.csv",
    "../feature-extraction/2D_cnn/datasets/features_with_metadata_undersampling_dense64.csv",
    "../feature-extraction/2D_cnn/datasets/features_with_metadata_undersampling_dense128.csv",
    "../feature-extraction/2D_cnn/datasets/features_with_metadata_undersampling_dense256.csv",
    "../feature-extraction/2D_cnn/datasets/features_with_metadata_weighted_dense32.csv",
    "../feature-extraction/2D_cnn/datasets/features_with_metadata_weighted_dense64.csv",
    "../feature-extraction/2D_cnn/datasets/features_with_metadata_weighted_dense128.csv",
    "../feature-extraction/2D_cnn/datasets/features_with_metadata_weighted_dense256.csv",

]

# %% [markdown]
# ### Imbalanced

# %%
train(cnn_2d_dataset_paths, "svm", "normal")
# Out:
# Processing ../feature-extraction/2D_cnn/datasets/features_with_metadata_base_dense32.csv...
# Accuracy  : 0.8273
# Precision : 0.7309
# Recall    : 0.8971
# F1 Score  : 0.8055
# F2 Score  : 0.8581
# Best Threshold  : 0.12
# TP: 1081, TN: 1419, FP: 398, FN: 124
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.92      0.78      0.84      1817
#            1       0.73      0.90      0.81      1205
#
#     accuracy                           0.83      3022
#    macro avg       0.83      0.84      0.83      3022
# weighted avg       0.84      0.83      0.83      3022
#
# Model saved to models/svm\svm_normal_features_with_metadata_base_dense32.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/2D_cnn/datasets/features_with_metadata_base_dense64.csv...
# Accuracy  : 0.8521
# Precision : 0.7650
# Recall    : 0.9079
# F1 Score  : 0.8304
# F2 Score  : 0.8752
# Best Threshold  : 0.11
# TP: 1094, TN: 1481, FP: 336, FN: 111
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.93      0.82      0.87      1817
#            1       0.77      0.91      0.83      1205
#
#     accuracy                           0.85      3022
#    macro avg       0.85      0.86      0.85      3022
# weighted avg       0.86      0.85      0.85      3022
#
# Model saved to models/svm\svm_normal_features_with_metadata_base_dense64.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/2D_cnn/datasets/features_with_metadata_base_dense128.csv...
# Accuracy  : 0.8680
# Precision : 0.8178
# Recall    : 0.8606
# F1 Score  : 0.8387
# F2 Score  : 0.8517
# Best Threshold  : 0.1
# TP: 1037, TN: 1586, FP: 231, FN: 168
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.90      0.87      0.89      1817
#            1       0.82      0.86      0.84      1205
#
#     accuracy                           0.87      3022
#    macro avg       0.86      0.87      0.86      3022
# weighted avg       0.87      0.87      0.87      3022
#
# Model saved to models/svm\svm_normal_features_with_metadata_base_dense128.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/2D_cnn/datasets/features_with_metadata_base_dense256.csv...
# Accuracy  : 0.7945
# Precision : 0.6755
# Recall    : 0.9328
# F1 Score  : 0.7835
# F2 Score  : 0.8667
# Best Threshold  : 0.12
# TP: 1124, TN: 1277, FP: 540, FN: 81
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.70      0.80      1817
#            1       0.68      0.93      0.78      1205
#
#     accuracy                           0.79      3022
#    macro avg       0.81      0.82      0.79      3022
# weighted avg       0.83      0.79      0.80      3022
#
# Model saved to models/svm\svm_normal_features_with_metadata_base_dense256.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/2D_cnn/datasets/features_with_metadata_oversampling_dense32.csv...
# Accuracy  : 0.8120
# Precision : 0.6939
# Recall    : 0.9461
# F1 Score  : 0.8006
# F2 Score  : 0.8819
# Best Threshold  : 0.1
# TP: 1140, TN: 1314, FP: 503, FN: 65
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.95      0.72      0.82      1817
#            1       0.69      0.95      0.80      1205
#
#     accuracy                           0.81      3022
#    macro avg       0.82      0.83      0.81      3022
# weighted avg       0.85      0.81      0.81      3022
#
# Model saved to models/svm\svm_normal_features_with_metadata_oversampling_dense32.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/2D_cnn/datasets/features_with_metadata_oversampling_dense64.csv...
# Accuracy  : 0.8127
# Precision : 0.7047
# Recall    : 0.9129
# F1 Score  : 0.7954
# F2 Score  : 0.8619
# Best Threshold  : 0.12
# TP: 1100, TN: 1356, FP: 461, FN: 105
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.93      0.75      0.83      1817
#            1       0.70      0.91      0.80      1205
#
#     accuracy                           0.81      3022
#    macro avg       0.82      0.83      0.81      3022
# weighted avg       0.84      0.81      0.81      3022
#
# Model saved to models/svm\svm_normal_features_with_metadata_oversampling_dense64.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/2D_cnn/datasets/features_with_metadata_oversampling_dense128.csv...
# Accuracy  : 0.8024
# Precision : 0.6854
# Recall    : 0.9328
# F1 Score  : 0.7902
# F2 Score  : 0.8700
# Best Threshold  : 0.12
# TP: 1124, TN: 1301, FP: 516, FN: 81
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.72      0.81      1817
#            1       0.69      0.93      0.79      1205
#
#     accuracy                           0.80      3022
#    macro avg       0.81      0.82      0.80      3022
# weighted avg       0.84      0.80      0.80      3022
#
# Model saved to models/svm\svm_normal_features_with_metadata_oversampling_dense128.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/2D_cnn/datasets/features_with_metadata_oversampling_dense256.csv...
# Accuracy  : 0.7690
# Precision : 0.6446
# Recall    : 0.9378
# F1 Score  : 0.7640
# F2 Score  : 0.8596
# Best Threshold  : 0.12
# TP: 1130, TN: 1194, FP: 623, FN: 75
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.66      0.77      1817
#            1       0.64      0.94      0.76      1205
#
#     accuracy                           0.77      3022
#    macro avg       0.79      0.80      0.77      3022
# weighted avg       0.82      0.77      0.77      3022
#
# Model saved to models/svm\svm_normal_features_with_metadata_oversampling_dense256.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/2D_cnn/datasets/features_with_metadata_undersampling_dense32.csv...
# Accuracy  : 0.7872
# Precision : 0.6743
# Recall    : 0.9021
# F1 Score  : 0.7717
# F2 Score  : 0.8450
# Best Threshold  : 0.13999999999999999
# TP: 1087, TN: 1292, FP: 525, FN: 118
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.92      0.71      0.80      1817
#            1       0.67      0.90      0.77      1205
#
#     accuracy                           0.79      3022
#    macro avg       0.80      0.81      0.79      3022
# weighted avg       0.82      0.79      0.79      3022
#
# Model saved to models/svm\svm_normal_features_with_metadata_undersampling_dense32.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/2D_cnn/datasets/features_with_metadata_undersampling_dense64.csv...
# Accuracy  : 0.7687
# Precision : 0.6464
# Recall    : 0.9270
# F1 Score  : 0.7617
# F2 Score  : 0.8529
# Best Threshold  : 0.12
# TP: 1117, TN: 1206, FP: 611, FN: 88
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.93      0.66      0.78      1817
#            1       0.65      0.93      0.76      1205
#
#     accuracy                           0.77      3022
#    macro avg       0.79      0.80      0.77      3022
# weighted avg       0.82      0.77      0.77      3022
#
# Model saved to models/svm\svm_normal_features_with_metadata_undersampling_dense64.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/2D_cnn/datasets/features_with_metadata_undersampling_dense128.csv...
# Accuracy  : 0.8180
# Precision : 0.7122
# Recall    : 0.9120
# F1 Score  : 0.7999
# F2 Score  : 0.8636
# Best Threshold  : 0.12
# TP: 1099, TN: 1373, FP: 444, FN: 106
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.93      0.76      0.83      1817
#            1       0.71      0.91      0.80      1205
#
#     accuracy                           0.82      3022
#    macro avg       0.82      0.83      0.82      3022
# weighted avg       0.84      0.82      0.82      3022
#
# Model saved to models/svm\svm_normal_features_with_metadata_undersampling_dense128.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/2D_cnn/datasets/features_with_metadata_undersampling_dense256.csv...
# Accuracy  : 0.8491
# Precision : 0.7639
# Recall    : 0.8996
# F1 Score  : 0.8262
# F2 Score  : 0.8687
# Best Threshold  : 0.1
# TP: 1084, TN: 1482, FP: 335, FN: 121
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.92      0.82      0.87      1817
#            1       0.76      0.90      0.83      1205
#
#     accuracy                           0.85      3022
#    macro avg       0.84      0.86      0.85      3022
# weighted avg       0.86      0.85      0.85      3022
#
# Model saved to models/svm\svm_normal_features_with_metadata_undersampling_dense256.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/2D_cnn/datasets/features_with_metadata_weighted_dense32.csv...
# Accuracy  : 0.8309
# Precision : 0.7361
# Recall    : 0.8979
# F1 Score  : 0.8090
# F2 Score  : 0.8601
# Best Threshold  : 0.12
# TP: 1082, TN: 1429, FP: 388, FN: 123
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.92      0.79      0.85      1817
#            1       0.74      0.90      0.81      1205
#
#     accuracy                           0.83      3022
#    macro avg       0.83      0.84      0.83      3022
# weighted avg       0.85      0.83      0.83      3022
#
# Model saved to models/svm\svm_normal_features_with_metadata_weighted_dense32.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/2D_cnn/datasets/features_with_metadata_weighted_dense64.csv...
# Accuracy  : 0.8385
# Precision : 0.7408
# Recall    : 0.9154
# F1 Score  : 0.8189
# F2 Score  : 0.8741
# Best Threshold  : 0.1
# TP: 1103, TN: 1431, FP: 386, FN: 102
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.93      0.79      0.85      1817
#            1       0.74      0.92      0.82      1205
#
#     accuracy                           0.84      3022
#    macro avg       0.84      0.85      0.84      3022
# weighted avg       0.86      0.84      0.84      3022
#
# Model saved to models/svm\svm_normal_features_with_metadata_weighted_dense64.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/2D_cnn/datasets/features_with_metadata_weighted_dense128.csv...
# Accuracy  : 0.8246
# Precision : 0.7225
# Recall    : 0.9095
# F1 Score  : 0.8053
# F2 Score  : 0.8648
# Best Threshold  : 0.1
# TP: 1096, TN: 1396, FP: 421, FN: 109
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.93      0.77      0.84      1817
#            1       0.72      0.91      0.81      1205
#
#     accuracy                           0.82      3022
#    macro avg       0.83      0.84      0.82      3022
# weighted avg       0.85      0.82      0.83      3022
#
# Model saved to models/svm\svm_normal_features_with_metadata_weighted_dense128.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/2D_cnn/datasets/features_with_metadata_weighted_dense256.csv...
# Accuracy  : 0.7912
# Precision : 0.6727
# Recall    : 0.9278
# F1 Score  : 0.7799
# F2 Score  : 0.8624
# Best Threshold  : 0.12
# TP: 1118, TN: 1273, FP: 544, FN: 87
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.70      0.80      1817
#            1       0.67      0.93      0.78      1205
#
#     accuracy                           0.79      3022
#    macro avg       0.80      0.81      0.79      3022
# weighted avg       0.83      0.79      0.79      3022
#
# Model saved to models/svm\svm_normal_features_with_metadata_weighted_dense256.joblib
# Results saved to results_summary.csv

# %% [markdown]
# ### Under-sampling

# %%
train(cnn_2d_dataset_paths, "svm", "under")
# Out:
# Processing ../feature-extraction/2D_cnn/datasets/features_with_metadata_base_dense32.csv...
# Accuracy  : 0.7909
# Precision : 0.6729
# Recall    : 0.9253
# F1 Score  : 0.7792
# F2 Score  : 0.8607
# Best Threshold  : 0.13
# TP: 1115, TN: 1275, FP: 542, FN: 90
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.93      0.70      0.80      1817
#            1       0.67      0.93      0.78      1205
#
#     accuracy                           0.79      3022
#    macro avg       0.80      0.81      0.79      3022
# weighted avg       0.83      0.79      0.79      3022
#
# Model saved to models/svm\svm_under_features_with_metadata_base_dense32.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/2D_cnn/datasets/features_with_metadata_base_dense64.csv...
# Accuracy  : 0.8537
# Precision : 0.7692
# Recall    : 0.9046
# F1 Score  : 0.8314
# F2 Score  : 0.8738
# Best Threshold  : 0.17999999999999997
# TP: 1090, TN: 1490, FP: 327, FN: 115
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.93      0.82      0.87      1817
#            1       0.77      0.90      0.83      1205
#
#     accuracy                           0.85      3022
#    macro avg       0.85      0.86      0.85      3022
# weighted avg       0.86      0.85      0.86      3022
#
# Model saved to models/svm\svm_under_features_with_metadata_base_dense64.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/2D_cnn/datasets/features_with_metadata_base_dense128.csv...
# Accuracy  : 0.8544
# Precision : 0.7738
# Recall    : 0.8971
# F1 Score  : 0.8309
# F2 Score  : 0.8694
# Best Threshold  : 0.1
# TP: 1081, TN: 1501, FP: 316, FN: 124
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.92      0.83      0.87      1817
#            1       0.77      0.90      0.83      1205
#
#     accuracy                           0.85      3022
#    macro avg       0.85      0.86      0.85      3022
# weighted avg       0.86      0.85      0.86      3022
#
# Model saved to models/svm\svm_under_features_with_metadata_base_dense128.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/2D_cnn/datasets/features_with_metadata_base_dense256.csv...
# Accuracy  : 0.7763
# Precision : 0.6512
# Recall    : 0.9452
# F1 Score  : 0.7712
# F2 Score  : 0.8670
# Best Threshold  : 0.14999999999999997
# TP: 1139, TN: 1207, FP: 610, FN: 66
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.95      0.66      0.78      1817
#            1       0.65      0.95      0.77      1205
#
#     accuracy                           0.78      3022
#    macro avg       0.80      0.80      0.78      3022
# weighted avg       0.83      0.78      0.78      3022
#
# Model saved to models/svm\svm_under_features_with_metadata_base_dense256.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/2D_cnn/datasets/features_with_metadata_oversampling_dense32.csv...
# Accuracy  : 0.8091
# Precision : 0.6887
# Recall    : 0.9510
# F1 Score  : 0.7989
# F2 Score  : 0.8837
# Best Threshold  : 0.13999999999999999
# TP: 1146, TN: 1299, FP: 518, FN: 59
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.96      0.71      0.82      1817
#            1       0.69      0.95      0.80      1205
#
#     accuracy                           0.81      3022
#    macro avg       0.82      0.83      0.81      3022
# weighted avg       0.85      0.81      0.81      3022
#
# Model saved to models/svm\svm_under_features_with_metadata_oversampling_dense32.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/2D_cnn/datasets/features_with_metadata_oversampling_dense64.csv...
# Accuracy  : 0.8306
# Precision : 0.7336
# Recall    : 0.9029
# F1 Score  : 0.8095
# F2 Score  : 0.8631
# Best Threshold  : 0.22999999999999995
# TP: 1088, TN: 1422, FP: 395, FN: 117
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.92      0.78      0.85      1817
#            1       0.73      0.90      0.81      1205
#
#     accuracy                           0.83      3022
#    macro avg       0.83      0.84      0.83      3022
# weighted avg       0.85      0.83      0.83      3022
#
# Model saved to models/svm\svm_under_features_with_metadata_oversampling_dense64.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/2D_cnn/datasets/features_with_metadata_oversampling_dense128.csv...
# Accuracy  : 0.7935
# Precision : 0.6730
# Recall    : 0.9378
# F1 Score  : 0.7836
# F2 Score  : 0.8694
# Best Threshold  : 0.15999999999999998
# TP: 1130, TN: 1268, FP: 549, FN: 75
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.70      0.80      1817
#            1       0.67      0.94      0.78      1205
#
#     accuracy                           0.79      3022
#    macro avg       0.81      0.82      0.79      3022
# weighted avg       0.84      0.79      0.79      3022
#
# Model saved to models/svm\svm_under_features_with_metadata_oversampling_dense128.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/2D_cnn/datasets/features_with_metadata_oversampling_dense256.csv...
# Accuracy  : 0.7773
# Precision : 0.6552
# Recall    : 0.9320
# F1 Score  : 0.7694
# F2 Score  : 0.8594
# Best Threshold  : 0.18999999999999995
# TP: 1123, TN: 1226, FP: 591, FN: 82
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.67      0.78      1817
#            1       0.66      0.93      0.77      1205
#
#     accuracy                           0.78      3022
#    macro avg       0.80      0.80      0.78      3022
# weighted avg       0.82      0.78      0.78      3022
#
# Model saved to models/svm\svm_under_features_with_metadata_oversampling_dense256.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/2D_cnn/datasets/features_with_metadata_undersampling_dense32.csv...
# Accuracy  : 0.7574
# Precision : 0.6308
# Recall    : 0.9444
# F1 Score  : 0.7564
# F2 Score  : 0.8590
# Best Threshold  : 0.15999999999999998
# TP: 1138, TN: 1151, FP: 666, FN: 67
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.63      0.76      1817
#            1       0.63      0.94      0.76      1205
#
#     accuracy                           0.76      3022
#    macro avg       0.79      0.79      0.76      3022
# weighted avg       0.82      0.76      0.76      3022
#
# Model saved to models/svm\svm_under_features_with_metadata_undersampling_dense32.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/2D_cnn/datasets/features_with_metadata_undersampling_dense64.csv...
# Accuracy  : 0.7776
# Precision : 0.6561
# Recall    : 0.9295
# F1 Score  : 0.7692
# F2 Score  : 0.8580
# Best Threshold  : 0.16999999999999998
# TP: 1120, TN: 1230, FP: 587, FN: 85
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.68      0.79      1817
#            1       0.66      0.93      0.77      1205
#
#     accuracy                           0.78      3022
#    macro avg       0.80      0.80      0.78      3022
# weighted avg       0.82      0.78      0.78      3022
#
# Model saved to models/svm\svm_under_features_with_metadata_undersampling_dense64.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/2D_cnn/datasets/features_with_metadata_undersampling_dense128.csv...
# Accuracy  : 0.8177
# Precision : 0.7110
# Recall    : 0.9145
# F1 Score  : 0.8000
# F2 Score  : 0.8650
# Best Threshold  : 0.16999999999999998
# TP: 1102, TN: 1369, FP: 448, FN: 103
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.93      0.75      0.83      1817
#            1       0.71      0.91      0.80      1205
#
#     accuracy                           0.82      3022
#    macro avg       0.82      0.83      0.82      3022
# weighted avg       0.84      0.82      0.82      3022
#
# Model saved to models/svm\svm_under_features_with_metadata_undersampling_dense128.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/2D_cnn/datasets/features_with_metadata_undersampling_dense256.csv...
# Accuracy  : 0.8279
# Precision : 0.7276
# Recall    : 0.9087
# F1 Score  : 0.8081
# F2 Score  : 0.8656
# Best Threshold  : 0.1
# TP: 1095, TN: 1407, FP: 410, FN: 110
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.93      0.77      0.84      1817
#            1       0.73      0.91      0.81      1205
#
#     accuracy                           0.83      3022
#    macro avg       0.83      0.84      0.83      3022
# weighted avg       0.85      0.83      0.83      3022
#
# Model saved to models/svm\svm_under_features_with_metadata_undersampling_dense256.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/2D_cnn/datasets/features_with_metadata_weighted_dense32.csv...
# Accuracy  : 0.7955
# Precision : 0.6780
# Recall    : 0.9278
# F1 Score  : 0.7835
# F2 Score  : 0.8641
# Best Threshold  : 0.13999999999999999
# TP: 1118, TN: 1286, FP: 531, FN: 87
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.71      0.81      1817
#            1       0.68      0.93      0.78      1205
#
#     accuracy                           0.80      3022
#    macro avg       0.81      0.82      0.79      3022
# weighted avg       0.83      0.80      0.80      3022
#
# Model saved to models/svm\svm_under_features_with_metadata_weighted_dense32.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/2D_cnn/datasets/features_with_metadata_weighted_dense64.csv...
# Accuracy  : 0.8435
# Precision : 0.7503
# Recall    : 0.9104
# F1 Score  : 0.8226
# F2 Score  : 0.8731
# Best Threshold  : 0.16999999999999998
# TP: 1097, TN: 1452, FP: 365, FN: 108
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.93      0.80      0.86      1817
#            1       0.75      0.91      0.82      1205
#
#     accuracy                           0.84      3022
#    macro avg       0.84      0.85      0.84      3022
# weighted avg       0.86      0.84      0.85      3022
#
# Model saved to models/svm\svm_under_features_with_metadata_weighted_dense64.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/2D_cnn/datasets/features_with_metadata_weighted_dense128.csv...
# Accuracy  : 0.8127
# Precision : 0.7018
# Recall    : 0.9220
# F1 Score  : 0.7970
# F2 Score  : 0.8676
# Best Threshold  : 0.12
# TP: 1111, TN: 1345, FP: 472, FN: 94
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.93      0.74      0.83      1817
#            1       0.70      0.92      0.80      1205
#
#     accuracy                           0.81      3022
#    macro avg       0.82      0.83      0.81      3022
# weighted avg       0.84      0.81      0.81      3022
#
# Model saved to models/svm\svm_under_features_with_metadata_weighted_dense128.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/2D_cnn/datasets/features_with_metadata_weighted_dense256.csv...
# Accuracy  : 0.7727
# Precision : 0.6477
# Recall    : 0.9427
# F1 Score  : 0.7678
# F2 Score  : 0.8640
# Best Threshold  : 0.14999999999999997
# TP: 1136, TN: 1199, FP: 618, FN: 69
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.95      0.66      0.78      1817
#            1       0.65      0.94      0.77      1205
#
#     accuracy                           0.77      3022
#    macro avg       0.80      0.80      0.77      3022
# weighted avg       0.83      0.77      0.77      3022
#
# Model saved to models/svm\svm_under_features_with_metadata_weighted_dense256.joblib
# Results saved to results_summary.csv

# %% [markdown]
# ### Over-Sampling

# %%
train(cnn_2d_dataset_paths, "svm", "over")
# Out:
# Processing ../feature-extraction/2D_cnn/datasets/features_with_metadata_base_dense32.csv...
# Accuracy  : 0.7856
# Precision : 0.6649
# Recall    : 0.9320
# F1 Score  : 0.7761
# F2 Score  : 0.8627
# Best Threshold  : 0.12
# TP: 1123, TN: 1251, FP: 566, FN: 82
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.69      0.79      1817
#            1       0.66      0.93      0.78      1205
#
#     accuracy                           0.79      3022
#    macro avg       0.80      0.81      0.79      3022
# weighted avg       0.83      0.79      0.79      3022
#
# Model saved to models/svm\svm_over_features_with_metadata_base_dense32.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/2D_cnn/datasets/features_with_metadata_base_dense64.csv...
# Accuracy  : 0.8478
# Precision : 0.7585
# Recall    : 0.9071
# F1 Score  : 0.8262
# F2 Score  : 0.8729
# Best Threshold  : 0.14999999999999997
# TP: 1093, TN: 1469, FP: 348, FN: 112
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.93      0.81      0.86      1817
#            1       0.76      0.91      0.83      1205
#
#     accuracy                           0.85      3022
#    macro avg       0.84      0.86      0.85      3022
# weighted avg       0.86      0.85      0.85      3022
#
# Model saved to models/svm\svm_over_features_with_metadata_base_dense64.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/2D_cnn/datasets/features_with_metadata_base_dense128.csv...
# Accuracy  : 0.8570
# Precision : 0.7807
# Recall    : 0.8921
# F1 Score  : 0.8327
# F2 Score  : 0.8674
# Best Threshold  : 0.1
# TP: 1075, TN: 1515, FP: 302, FN: 130
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.92      0.83      0.88      1817
#            1       0.78      0.89      0.83      1205
#
#     accuracy                           0.86      3022
#    macro avg       0.85      0.86      0.85      3022
# weighted avg       0.87      0.86      0.86      3022
#
# Model saved to models/svm\svm_over_features_with_metadata_base_dense128.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/2D_cnn/datasets/features_with_metadata_base_dense256.csv...
# Accuracy  : 0.7766
# Precision : 0.6516
# Recall    : 0.9452
# F1 Score  : 0.7714
# F2 Score  : 0.8671
# Best Threshold  : 0.13999999999999999
# TP: 1139, TN: 1208, FP: 609, FN: 66
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.95      0.66      0.78      1817
#            1       0.65      0.95      0.77      1205
#
#     accuracy                           0.78      3022
#    macro avg       0.80      0.81      0.78      3022
# weighted avg       0.83      0.78      0.78      3022
#
# Model saved to models/svm\svm_over_features_with_metadata_base_dense256.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/2D_cnn/datasets/features_with_metadata_oversampling_dense32.csv...
# Accuracy  : 0.8117
# Precision : 0.6920
# Recall    : 0.9510
# F1 Score  : 0.8011
# F2 Score  : 0.8848
# Best Threshold  : 0.13999999999999999
# TP: 1146, TN: 1307, FP: 510, FN: 59
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.96      0.72      0.82      1817
#            1       0.69      0.95      0.80      1205
#
#     accuracy                           0.81      3022
#    macro avg       0.82      0.84      0.81      3022
# weighted avg       0.85      0.81      0.81      3022
#
# Model saved to models/svm\svm_over_features_with_metadata_oversampling_dense32.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/2D_cnn/datasets/features_with_metadata_oversampling_dense64.csv...
# Accuracy  : 0.8293
# Precision : 0.7317
# Recall    : 0.9029
# F1 Score  : 0.8083
# F2 Score  : 0.8625
# Best Threshold  : 0.19999999999999996
# TP: 1088, TN: 1418, FP: 399, FN: 117
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.92      0.78      0.85      1817
#            1       0.73      0.90      0.81      1205
#
#     accuracy                           0.83      3022
#    macro avg       0.83      0.84      0.83      3022
# weighted avg       0.85      0.83      0.83      3022
#
# Model saved to models/svm\svm_over_features_with_metadata_oversampling_dense64.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/2D_cnn/datasets/features_with_metadata_oversampling_dense128.csv...
# Accuracy  : 0.7942
# Precision : 0.6738
# Recall    : 0.9378
# F1 Score  : 0.7842
# F2 Score  : 0.8696
# Best Threshold  : 0.14999999999999997
# TP: 1130, TN: 1270, FP: 547, FN: 75
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.70      0.80      1817
#            1       0.67      0.94      0.78      1205
#
#     accuracy                           0.79      3022
#    macro avg       0.81      0.82      0.79      3022
# weighted avg       0.84      0.79      0.80      3022
#
# Model saved to models/svm\svm_over_features_with_metadata_oversampling_dense128.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/2D_cnn/datasets/features_with_metadata_oversampling_dense256.csv...
# Accuracy  : 0.7806
# Precision : 0.6590
# Recall    : 0.9320
# F1 Score  : 0.7721
# F2 Score  : 0.8607
# Best Threshold  : 0.17999999999999997
# TP: 1123, TN: 1236, FP: 581, FN: 82
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.68      0.79      1817
#            1       0.66      0.93      0.77      1205
#
#     accuracy                           0.78      3022
#    macro avg       0.80      0.81      0.78      3022
# weighted avg       0.83      0.78      0.78      3022
#
# Model saved to models/svm\svm_over_features_with_metadata_oversampling_dense256.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/2D_cnn/datasets/features_with_metadata_undersampling_dense32.csv...
# Accuracy  : 0.7614
# Precision : 0.6360
# Recall    : 0.9394
# F1 Score  : 0.7585
# F2 Score  : 0.8576
# Best Threshold  : 0.15999999999999998
# TP: 1132, TN: 1169, FP: 648, FN: 73
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.64      0.76      1817
#            1       0.64      0.94      0.76      1205
#
#     accuracy                           0.76      3022
#    macro avg       0.79      0.79      0.76      3022
# weighted avg       0.82      0.76      0.76      3022
#
# Model saved to models/svm\svm_over_features_with_metadata_undersampling_dense32.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/2D_cnn/datasets/features_with_metadata_undersampling_dense64.csv...
# Accuracy  : 0.7750
# Precision : 0.6531
# Recall    : 0.9295
# F1 Score  : 0.7671
# F2 Score  : 0.8569
# Best Threshold  : 0.15999999999999998
# TP: 1120, TN: 1222, FP: 595, FN: 85
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.93      0.67      0.78      1817
#            1       0.65      0.93      0.77      1205
#
#     accuracy                           0.77      3022
#    macro avg       0.79      0.80      0.77      3022
# weighted avg       0.82      0.77      0.78      3022
#
# Model saved to models/svm\svm_over_features_with_metadata_undersampling_dense64.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/2D_cnn/datasets/features_with_metadata_undersampling_dense128.csv...
# Accuracy  : 0.8008
# Precision : 0.6849
# Recall    : 0.9270
# F1 Score  : 0.7877
# F2 Score  : 0.8658
# Best Threshold  : 0.13
# TP: 1117, TN: 1303, FP: 514, FN: 88
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.72      0.81      1817
#            1       0.68      0.93      0.79      1205
#
#     accuracy                           0.80      3022
#    macro avg       0.81      0.82      0.80      3022
# weighted avg       0.84      0.80      0.80      3022
#
# Model saved to models/svm\svm_over_features_with_metadata_undersampling_dense128.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/2D_cnn/datasets/features_with_metadata_undersampling_dense256.csv...
# Accuracy  : 0.8296
# Precision : 0.7297
# Recall    : 0.9095
# F1 Score  : 0.8098
# F2 Score  : 0.8668
# Best Threshold  : 0.11
# TP: 1096, TN: 1411, FP: 406, FN: 109
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.93      0.78      0.85      1817
#            1       0.73      0.91      0.81      1205
#
#     accuracy                           0.83      3022
#    macro avg       0.83      0.84      0.83      3022
# weighted avg       0.85      0.83      0.83      3022
#
# Model saved to models/svm\svm_over_features_with_metadata_undersampling_dense256.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/2D_cnn/datasets/features_with_metadata_weighted_dense32.csv...
# Accuracy  : 0.8101
# Precision : 0.7003
# Recall    : 0.9154
# F1 Score  : 0.7935
# F2 Score  : 0.8624
# Best Threshold  : 0.14999999999999997
# TP: 1103, TN: 1345, FP: 472, FN: 102
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.93      0.74      0.82      1817
#            1       0.70      0.92      0.79      1205
#
#     accuracy                           0.81      3022
#    macro avg       0.81      0.83      0.81      3022
# weighted avg       0.84      0.81      0.81      3022
#
# Model saved to models/svm\svm_over_features_with_metadata_weighted_dense32.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/2D_cnn/datasets/features_with_metadata_weighted_dense64.csv...
# Accuracy  : 0.8349
# Precision : 0.7356
# Recall    : 0.9145
# F1 Score  : 0.8154
# F2 Score  : 0.8721
# Best Threshold  : 0.13999999999999999
# TP: 1102, TN: 1421, FP: 396, FN: 103
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.93      0.78      0.85      1817
#            1       0.74      0.91      0.82      1205
#
#     accuracy                           0.83      3022
#    macro avg       0.83      0.85      0.83      3022
# weighted avg       0.85      0.83      0.84      3022
#
# Model saved to models/svm\svm_over_features_with_metadata_weighted_dense64.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/2D_cnn/datasets/features_with_metadata_weighted_dense128.csv...
# Accuracy  : 0.8210
# Precision : 0.7159
# Recall    : 0.9137
# F1 Score  : 0.8028
# F2 Score  : 0.8658
# Best Threshold  : 0.13
# TP: 1101, TN: 1380, FP: 437, FN: 104
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.93      0.76      0.84      1817
#            1       0.72      0.91      0.80      1205
#
#     accuracy                           0.82      3022
#    macro avg       0.82      0.84      0.82      3022
# weighted avg       0.84      0.82      0.82      3022
#
# Model saved to models/svm\svm_over_features_with_metadata_weighted_dense128.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/2D_cnn/datasets/features_with_metadata_weighted_dense256.csv...
# Accuracy  : 0.7723
# Precision : 0.6471
# Recall    : 0.9436
# F1 Score  : 0.7677
# F2 Score  : 0.8644
# Best Threshold  : 0.13999999999999999
# TP: 1137, TN: 1197, FP: 620, FN: 68
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.95      0.66      0.78      1817
#            1       0.65      0.94      0.77      1205
#
#     accuracy                           0.77      3022
#    macro avg       0.80      0.80      0.77      3022
# weighted avg       0.83      0.77      0.77      3022
#
# Model saved to models/svm\svm_over_features_with_metadata_weighted_dense256.joblib
# Results saved to results_summary.csv

# %% [markdown]
# ### Weighted

# %%
train(cnn_2d_dataset_paths, "svm", "weighted")
# Out:
# Processing ../feature-extraction/2D_cnn/datasets/features_with_metadata_base_dense32.csv...
# Accuracy  : 0.8157
# Precision : 0.7112
# Recall    : 0.9054
# F1 Score  : 0.7966
# F2 Score  : 0.8585
# Best Threshold  : 0.12
# TP: 1091, TN: 1374, FP: 443, FN: 114
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.92      0.76      0.83      1817
#            1       0.71      0.91      0.80      1205
#
#     accuracy                           0.82      3022
#    macro avg       0.82      0.83      0.81      3022
# weighted avg       0.84      0.82      0.82      3022
#
# Model saved to models/svm\svm_weighted_features_with_metadata_base_dense32.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/2D_cnn/datasets/features_with_metadata_base_dense64.csv...
# Accuracy  : 0.8481
# Precision : 0.7590
# Recall    : 0.9071
# F1 Score  : 0.8265
# F2 Score  : 0.8730
# Best Threshold  : 0.11
# TP: 1093, TN: 1470, FP: 347, FN: 112
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.93      0.81      0.86      1817
#            1       0.76      0.91      0.83      1205
#
#     accuracy                           0.85      3022
#    macro avg       0.84      0.86      0.85      3022
# weighted avg       0.86      0.85      0.85      3022
#
# Model saved to models/svm\svm_weighted_features_with_metadata_base_dense64.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/2D_cnn/datasets/features_with_metadata_base_dense128.csv...
# Accuracy  : 0.8666
# Precision : 0.8123
# Recall    : 0.8656
# F1 Score  : 0.8381
# F2 Score  : 0.8544
# Best Threshold  : 0.1
# TP: 1043, TN: 1576, FP: 241, FN: 162
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.91      0.87      0.89      1817
#            1       0.81      0.87      0.84      1205
#
#     accuracy                           0.87      3022
#    macro avg       0.86      0.87      0.86      3022
# weighted avg       0.87      0.87      0.87      3022
#
# Model saved to models/svm\svm_weighted_features_with_metadata_base_dense128.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/2D_cnn/datasets/features_with_metadata_base_dense256.csv...
# Accuracy  : 0.7743
# Precision : 0.6492
# Recall    : 0.9444
# F1 Score  : 0.7694
# F2 Score  : 0.8657
# Best Threshold  : 0.1
# TP: 1138, TN: 1202, FP: 615, FN: 67
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.95      0.66      0.78      1817
#            1       0.65      0.94      0.77      1205
#
#     accuracy                           0.77      3022
#    macro avg       0.80      0.80      0.77      3022
# weighted avg       0.83      0.77      0.78      3022
#
# Model saved to models/svm\svm_weighted_features_with_metadata_base_dense256.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/2D_cnn/datasets/features_with_metadata_oversampling_dense32.csv...
# Accuracy  : 0.8210
# Precision : 0.7060
# Recall    : 0.9444
# F1 Score  : 0.8080
# F2 Score  : 0.8846
# Best Threshold  : 0.11
# TP: 1138, TN: 1343, FP: 474, FN: 67
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.95      0.74      0.83      1817
#            1       0.71      0.94      0.81      1205
#
#     accuracy                           0.82      3022
#    macro avg       0.83      0.84      0.82      3022
# weighted avg       0.85      0.82      0.82      3022
#
# Model saved to models/svm\svm_weighted_features_with_metadata_oversampling_dense32.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/2D_cnn/datasets/features_with_metadata_oversampling_dense64.csv...
# Accuracy  : 0.8312
# Precision : 0.7346
# Recall    : 0.9029
# F1 Score  : 0.8101
# F2 Score  : 0.8634
# Best Threshold  : 0.15999999999999998
# TP: 1088, TN: 1424, FP: 393, FN: 117
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.92      0.78      0.85      1817
#            1       0.73      0.90      0.81      1205
#
#     accuracy                           0.83      3022
#    macro avg       0.83      0.84      0.83      3022
# weighted avg       0.85      0.83      0.83      3022
#
# Model saved to models/svm\svm_weighted_features_with_metadata_oversampling_dense64.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/2D_cnn/datasets/features_with_metadata_oversampling_dense128.csv...
# Accuracy  : 0.7991
# Precision : 0.6812
# Recall    : 0.9328
# F1 Score  : 0.7874
# F2 Score  : 0.8686
# Best Threshold  : 0.12
# TP: 1124, TN: 1291, FP: 526, FN: 81
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.71      0.81      1817
#            1       0.68      0.93      0.79      1205
#
#     accuracy                           0.80      3022
#    macro avg       0.81      0.82      0.80      3022
# weighted avg       0.84      0.80      0.80      3022
#
# Model saved to models/svm\svm_weighted_features_with_metadata_oversampling_dense128.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/2D_cnn/datasets/features_with_metadata_oversampling_dense256.csv...
# Accuracy  : 0.7737
# Precision : 0.6503
# Recall    : 0.9353
# F1 Score  : 0.7672
# F2 Score  : 0.8599
# Best Threshold  : 0.13
# TP: 1127, TN: 1211, FP: 606, FN: 78
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.67      0.78      1817
#            1       0.65      0.94      0.77      1205
#
#     accuracy                           0.77      3022
#    macro avg       0.79      0.80      0.77      3022
# weighted avg       0.82      0.77      0.77      3022
#
# Model saved to models/svm\svm_weighted_features_with_metadata_oversampling_dense256.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/2D_cnn/datasets/features_with_metadata_undersampling_dense32.csv...
# Accuracy  : 0.7852
# Precision : 0.6667
# Recall    : 0.9228
# F1 Score  : 0.7741
# F2 Score  : 0.8570
# Best Threshold  : 0.13
# TP: 1112, TN: 1261, FP: 556, FN: 93
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.93      0.69      0.80      1817
#            1       0.67      0.92      0.77      1205
#
#     accuracy                           0.79      3022
#    macro avg       0.80      0.81      0.78      3022
# weighted avg       0.83      0.79      0.79      3022
#
# Model saved to models/svm\svm_weighted_features_with_metadata_undersampling_dense32.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/2D_cnn/datasets/features_with_metadata_undersampling_dense64.csv...
# Accuracy  : 0.7816
# Precision : 0.6611
# Recall    : 0.9278
# F1 Score  : 0.7721
# F2 Score  : 0.8585
# Best Threshold  : 0.12
# TP: 1118, TN: 1244, FP: 573, FN: 87
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.93      0.68      0.79      1817
#            1       0.66      0.93      0.77      1205
#
#     accuracy                           0.78      3022
#    macro avg       0.80      0.81      0.78      3022
# weighted avg       0.83      0.78      0.78      3022
#
# Model saved to models/svm\svm_weighted_features_with_metadata_undersampling_dense64.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/2D_cnn/datasets/features_with_metadata_undersampling_dense128.csv...
# Accuracy  : 0.7991
# Precision : 0.6828
# Recall    : 0.9270
# F1 Score  : 0.7863
# F2 Score  : 0.8651
# Best Threshold  : 0.1
# TP: 1117, TN: 1298, FP: 519, FN: 88
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.71      0.81      1817
#            1       0.68      0.93      0.79      1205
#
#     accuracy                           0.80      3022
#    macro avg       0.81      0.82      0.80      3022
# weighted avg       0.84      0.80      0.80      3022
#
# Model saved to models/svm\svm_weighted_features_with_metadata_undersampling_dense128.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/2D_cnn/datasets/features_with_metadata_undersampling_dense256.csv...
# Accuracy  : 0.8475
# Precision : 0.7627
# Recall    : 0.8963
# F1 Score  : 0.8241
# F2 Score  : 0.8659
# Best Threshold  : 0.11
# TP: 1080, TN: 1481, FP: 336, FN: 125
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.92      0.82      0.87      1817
#            1       0.76      0.90      0.82      1205
#
#     accuracy                           0.85      3022
#    macro avg       0.84      0.86      0.84      3022
# weighted avg       0.86      0.85      0.85      3022
#
# Model saved to models/svm\svm_weighted_features_with_metadata_undersampling_dense256.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/2D_cnn/datasets/features_with_metadata_weighted_dense32.csv...
# Accuracy  : 0.7965
# Precision : 0.6803
# Recall    : 0.9237
# F1 Score  : 0.7835
# F2 Score  : 0.8620
# Best Threshold  : 0.1
# TP: 1113, TN: 1294, FP: 523, FN: 92
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.93      0.71      0.81      1817
#            1       0.68      0.92      0.78      1205
#
#     accuracy                           0.80      3022
#    macro avg       0.81      0.82      0.80      3022
# weighted avg       0.83      0.80      0.80      3022
#
# Model saved to models/svm\svm_weighted_features_with_metadata_weighted_dense32.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/2D_cnn/datasets/features_with_metadata_weighted_dense64.csv...
# Accuracy  : 0.8372
# Precision : 0.7397
# Recall    : 0.9129
# F1 Score  : 0.8172
# F2 Score  : 0.8720
# Best Threshold  : 0.11
# TP: 1100, TN: 1430, FP: 387, FN: 105
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.93      0.79      0.85      1817
#            1       0.74      0.91      0.82      1205
#
#     accuracy                           0.84      3022
#    macro avg       0.84      0.85      0.84      3022
# weighted avg       0.86      0.84      0.84      3022
#
# Model saved to models/svm\svm_weighted_features_with_metadata_weighted_dense64.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/2D_cnn/datasets/features_with_metadata_weighted_dense128.csv...
# Accuracy  : 0.8259
# Precision : 0.7244
# Recall    : 0.9095
# F1 Score  : 0.8065
# F2 Score  : 0.8653
# Best Threshold  : 0.11
# TP: 1096, TN: 1400, FP: 417, FN: 109
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.93      0.77      0.84      1817
#            1       0.72      0.91      0.81      1205
#
#     accuracy                           0.83      3022
#    macro avg       0.83      0.84      0.82      3022
# weighted avg       0.85      0.83      0.83      3022
#
# Model saved to models/svm\svm_weighted_features_with_metadata_weighted_dense128.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/2D_cnn/datasets/features_with_metadata_weighted_dense256.csv...
# Accuracy  : 0.7803
# Precision : 0.6574
# Recall    : 0.9378
# F1 Score  : 0.7729
# F2 Score  : 0.8640
# Best Threshold  : 0.11
# TP: 1130, TN: 1228, FP: 589, FN: 75
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.68      0.79      1817
#            1       0.66      0.94      0.77      1205
#
#     accuracy                           0.78      3022
#    macro avg       0.80      0.81      0.78      3022
# weighted avg       0.83      0.78      0.78      3022
#
# Model saved to models/svm\svm_weighted_features_with_metadata_weighted_dense256.joblib
# Results saved to results_summary.csv

# %% [markdown]
# ## Residual

# %% [markdown]
# ### Datasets

# %%
residual_dataset_paths = [
    "../feature-extraction/residual_cnn/datasets/normal_residual_cnn_features_32.csv",
    "../feature-extraction/residual_cnn/datasets/normal_residual_cnn_features_64.csv",
    "../feature-extraction/residual_cnn/datasets/normal_residual_cnn_features_128.csv",
    "../feature-extraction/residual_cnn/datasets/normal_residual_cnn_features_256.csv",
    "../feature-extraction/residual_cnn/datasets/over_sampled_residual_cnn_features_32.csv",
    "../feature-extraction/residual_cnn/datasets/over_sampled_residual_cnn_features_64.csv",
    "../feature-extraction/residual_cnn/datasets/over_sampled_residual_cnn_features_128.csv",
    "../feature-extraction/residual_cnn/datasets/over_sampled_residual_cnn_features_256.csv",
    "../feature-extraction/residual_cnn/datasets/under_sampled_residual_cnn_features_32.csv",
    "../feature-extraction/residual_cnn/datasets/under_sampled_residual_cnn_features_64.csv",
    "../feature-extraction/residual_cnn/datasets/under_sampled_residual_cnn_features_128.csv",
    "../feature-extraction/residual_cnn/datasets/under_sampled_residual_cnn_features_256.csv",
    "../feature-extraction/residual_cnn/datasets/weighted_residual_cnn_features_32.csv",
    "../feature-extraction/residual_cnn/datasets/weighted_residual_cnn_features_64.csv",
    "../feature-extraction/residual_cnn/datasets/weighted_residual_cnn_features_128.csv",
    "../feature-extraction/residual_cnn/datasets/weighted_residual_cnn_features_256.csv",

]

# %% [markdown]
# ### Imbalanced

# %%
train(residual_dataset_paths, "svm", "normal")
# Out:
# Processing ../feature-extraction/residual_cnn/datasets/normal_residual_cnn_features_32.csv...
# Accuracy  : 0.8537
# Precision : 0.7640
# Recall    : 0.9162
# F1 Score  : 0.8332
# F2 Score  : 0.8811
# Best Threshold  : 0.11
# TP: 1104, TN: 1476, FP: 341, FN: 101
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.81      0.87      1817
#            1       0.76      0.92      0.83      1205
#
#     accuracy                           0.85      3022
#    macro avg       0.85      0.86      0.85      3022
# weighted avg       0.87      0.85      0.86      3022
#
# Model saved to models/svm\svm_normal_normal_residual_cnn_features_32.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/normal_residual_cnn_features_64.csv...
# Accuracy  : 0.8494
# Precision : 0.7622
# Recall    : 0.9046
# F1 Score  : 0.8273
# F2 Score  : 0.8720
# Best Threshold  : 0.12
# TP: 1090, TN: 1477, FP: 340, FN: 115
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.93      0.81      0.87      1817
#            1       0.76      0.90      0.83      1205
#
#     accuracy                           0.85      3022
#    macro avg       0.85      0.86      0.85      3022
# weighted avg       0.86      0.85      0.85      3022
#
# Model saved to models/svm\svm_normal_normal_residual_cnn_features_64.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/normal_residual_cnn_features_128.csv...
# Accuracy  : 0.8408
# Precision : 0.7456
# Recall    : 0.9120
# F1 Score  : 0.8205
# F2 Score  : 0.8731
# Best Threshold  : 0.12
# TP: 1099, TN: 1442, FP: 375, FN: 106
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.93      0.79      0.86      1817
#            1       0.75      0.91      0.82      1205
#
#     accuracy                           0.84      3022
#    macro avg       0.84      0.85      0.84      3022
# weighted avg       0.86      0.84      0.84      3022
#
# Model saved to models/svm\svm_normal_normal_residual_cnn_features_128.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/normal_residual_cnn_features_256.csv...
# Accuracy  : 0.8475
# Precision : 0.7583
# Recall    : 0.9062
# F1 Score  : 0.8257
# F2 Score  : 0.8722
# Best Threshold  : 0.12
# TP: 1092, TN: 1469, FP: 348, FN: 113
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.93      0.81      0.86      1817
#            1       0.76      0.91      0.83      1205
#
#     accuracy                           0.85      3022
#    macro avg       0.84      0.86      0.85      3022
# weighted avg       0.86      0.85      0.85      3022
#
# Model saved to models/svm\svm_normal_normal_residual_cnn_features_256.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/over_sampled_residual_cnn_features_32.csv...
# Accuracy  : 0.8653
# Precision : 0.7858
# Recall    : 0.9104
# F1 Score  : 0.8435
# F2 Score  : 0.8824
# Best Threshold  : 0.1
# TP: 1097, TN: 1518, FP: 299, FN: 108
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.93      0.84      0.88      1817
#            1       0.79      0.91      0.84      1205
#
#     accuracy                           0.87      3022
#    macro avg       0.86      0.87      0.86      3022
# weighted avg       0.87      0.87      0.87      3022
#
# Model saved to models/svm\svm_normal_over_sampled_residual_cnn_features_32.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/over_sampled_residual_cnn_features_64.csv...
# Accuracy  : 0.8422
# Precision : 0.7423
# Recall    : 0.9253
# F1 Score  : 0.8238
# F2 Score  : 0.8818
# Best Threshold  : 0.12
# TP: 1115, TN: 1430, FP: 387, FN: 90
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.79      0.86      1817
#            1       0.74      0.93      0.82      1205
#
#     accuracy                           0.84      3022
#    macro avg       0.84      0.86      0.84      3022
# weighted avg       0.86      0.84      0.84      3022
#
# Model saved to models/svm\svm_normal_over_sampled_residual_cnn_features_64.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/over_sampled_residual_cnn_features_128.csv...
# Accuracy  : 0.8445
# Precision : 0.7485
# Recall    : 0.9187
# F1 Score  : 0.8249
# F2 Score  : 0.8787
# Best Threshold  : 0.11
# TP: 1107, TN: 1445, FP: 372, FN: 98
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.80      0.86      1817
#            1       0.75      0.92      0.82      1205
#
#     accuracy                           0.84      3022
#    macro avg       0.84      0.86      0.84      3022
# weighted avg       0.86      0.84      0.85      3022
#
# Model saved to models/svm\svm_normal_over_sampled_residual_cnn_features_128.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/over_sampled_residual_cnn_features_256.csv...
# Accuracy  : 0.8415
# Precision : 0.7446
# Recall    : 0.9170
# F1 Score  : 0.8219
# F2 Score  : 0.8764
# Best Threshold  : 0.11
# TP: 1105, TN: 1438, FP: 379, FN: 100
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.93      0.79      0.86      1817
#            1       0.74      0.92      0.82      1205
#
#     accuracy                           0.84      3022
#    macro avg       0.84      0.85      0.84      3022
# weighted avg       0.86      0.84      0.84      3022
#
# Model saved to models/svm\svm_normal_over_sampled_residual_cnn_features_256.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/under_sampled_residual_cnn_features_32.csv...
# Accuracy  : 0.8355
# Precision : 0.7428
# Recall    : 0.8988
# F1 Score  : 0.8134
# F2 Score  : 0.8625
# Best Threshold  : 0.13
# TP: 1083, TN: 1442, FP: 375, FN: 122
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.92      0.79      0.85      1817
#            1       0.74      0.90      0.81      1205
#
#     accuracy                           0.84      3022
#    macro avg       0.83      0.85      0.83      3022
# weighted avg       0.85      0.84      0.84      3022
#
# Model saved to models/svm\svm_normal_under_sampled_residual_cnn_features_32.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/under_sampled_residual_cnn_features_64.csv...
# Accuracy  : 0.8508
# Precision : 0.7633
# Recall    : 0.9071
# F1 Score  : 0.8290
# F2 Score  : 0.8741
# Best Threshold  : 0.12
# TP: 1093, TN: 1478, FP: 339, FN: 112
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.93      0.81      0.87      1817
#            1       0.76      0.91      0.83      1205
#
#     accuracy                           0.85      3022
#    macro avg       0.85      0.86      0.85      3022
# weighted avg       0.86      0.85      0.85      3022
#
# Model saved to models/svm\svm_normal_under_sampled_residual_cnn_features_64.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/under_sampled_residual_cnn_features_128.csv...
# Accuracy  : 0.8488
# Precision : 0.7544
# Recall    : 0.9203
# F1 Score  : 0.8292
# F2 Score  : 0.8816
# Best Threshold  : 0.11
# TP: 1109, TN: 1456, FP: 361, FN: 96
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.80      0.86      1817
#            1       0.75      0.92      0.83      1205
#
#     accuracy                           0.85      3022
#    macro avg       0.85      0.86      0.85      3022
# weighted avg       0.86      0.85      0.85      3022
#
# Model saved to models/svm\svm_normal_under_sampled_residual_cnn_features_128.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/under_sampled_residual_cnn_features_256.csv...
# Accuracy  : 0.8491
# Precision : 0.7574
# Recall    : 0.9145
# F1 Score  : 0.8286
# F2 Score  : 0.8781
# Best Threshold  : 0.11
# TP: 1102, TN: 1464, FP: 353, FN: 103
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.93      0.81      0.87      1817
#            1       0.76      0.91      0.83      1205
#
#     accuracy                           0.85      3022
#    macro avg       0.85      0.86      0.85      3022
# weighted avg       0.86      0.85      0.85      3022
#
# Model saved to models/svm\svm_normal_under_sampled_residual_cnn_features_256.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/weighted_residual_cnn_features_32.csv...
# Accuracy  : 0.8564
# Precision : 0.7686
# Recall    : 0.9154
# F1 Score  : 0.8356
# F2 Score  : 0.8817
# Best Threshold  : 0.11
# TP: 1103, TN: 1485, FP: 332, FN: 102
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.82      0.87      1817
#            1       0.77      0.92      0.84      1205
#
#     accuracy                           0.86      3022
#    macro avg       0.85      0.87      0.85      3022
# weighted avg       0.87      0.86      0.86      3022
#
# Model saved to models/svm\svm_normal_weighted_residual_cnn_features_32.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/weighted_residual_cnn_features_64.csv...
# Accuracy  : 0.8395
# Precision : 0.7507
# Recall    : 0.8946
# F1 Score  : 0.8164
# F2 Score  : 0.8616
# Best Threshold  : 0.13
# TP: 1078, TN: 1459, FP: 358, FN: 127
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.92      0.80      0.86      1817
#            1       0.75      0.89      0.82      1205
#
#     accuracy                           0.84      3022
#    macro avg       0.84      0.85      0.84      3022
# weighted avg       0.85      0.84      0.84      3022
#
# Model saved to models/svm\svm_normal_weighted_residual_cnn_features_64.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/weighted_residual_cnn_features_128.csv...
# Accuracy  : 0.8504
# Precision : 0.7588
# Recall    : 0.9162
# F1 Score  : 0.8301
# F2 Score  : 0.8797
# Best Threshold  : 0.12
# TP: 1104, TN: 1466, FP: 351, FN: 101
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.81      0.87      1817
#            1       0.76      0.92      0.83      1205
#
#     accuracy                           0.85      3022
#    macro avg       0.85      0.86      0.85      3022
# weighted avg       0.87      0.85      0.85      3022
#
# Model saved to models/svm\svm_normal_weighted_residual_cnn_features_128.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/weighted_residual_cnn_features_256.csv...
# Accuracy  : 0.8445
# Precision : 0.7540
# Recall    : 0.9054
# F1 Score  : 0.8228
# F2 Score  : 0.8704
# Best Threshold  : 0.12
# TP: 1091, TN: 1461, FP: 356, FN: 114
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.93      0.80      0.86      1817
#            1       0.75      0.91      0.82      1205
#
#     accuracy                           0.84      3022
#    macro avg       0.84      0.85      0.84      3022
# weighted avg       0.86      0.84      0.85      3022
#
# Model saved to models/svm\svm_normal_weighted_residual_cnn_features_256.joblib
# Results saved to results_summary.csv

# %% [markdown]
# ### Under-Sampled

# %%
train(residual_dataset_paths, "svm", "under")
# Out:
# Processing ../feature-extraction/residual_cnn/datasets/normal_residual_cnn_features_32.csv...
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:484: FutureWarning: `BaseEstimator._check_n_features` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation._check_n_features` instead.
#   warnings.warn(
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:493: FutureWarning: `BaseEstimator._check_feature_names` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation._check_feature_names` instead.
#   warnings.warn(
# Accuracy  : 0.8342
# Precision : 0.7289
# Recall    : 0.9303
# F1 Score  : 0.8174
# F2 Score  : 0.8816
# Best Threshold  : 0.13999999999999999
# TP: 1121, TN: 1400, FP: 417, FN: 84
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.77      0.85      1817
#            1       0.73      0.93      0.82      1205
#
#     accuracy                           0.83      3022
#    macro avg       0.84      0.85      0.83      3022
# weighted avg       0.86      0.83      0.84      3022
#
# Model saved to models/svm\svm_under_normal_residual_cnn_features_32.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/normal_residual_cnn_features_64.csv...
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:484: FutureWarning: `BaseEstimator._check_n_features` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation._check_n_features` instead.
#   warnings.warn(
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:493: FutureWarning: `BaseEstimator._check_feature_names` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation._check_feature_names` instead.
#   warnings.warn(
# Accuracy  : 0.8412
# Precision : 0.7418
# Recall    : 0.9228
# F1 Score  : 0.8225
# F2 Score  : 0.8799
# Best Threshold  : 0.16999999999999998
# TP: 1112, TN: 1430, FP: 387, FN: 93
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.79      0.86      1817
#            1       0.74      0.92      0.82      1205
#
#     accuracy                           0.84      3022
#    macro avg       0.84      0.85      0.84      3022
# weighted avg       0.86      0.84      0.84      3022
#
# Model saved to models/svm\svm_under_normal_residual_cnn_features_64.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/normal_residual_cnn_features_128.csv...
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:484: FutureWarning: `BaseEstimator._check_n_features` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation._check_n_features` instead.
#   warnings.warn(
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:493: FutureWarning: `BaseEstimator._check_feature_names` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation._check_feature_names` instead.
#   warnings.warn(
# Accuracy  : 0.8104
# Precision : 0.6960
# Recall    : 0.9311
# F1 Score  : 0.7966
# F2 Score  : 0.8722
# Best Threshold  : 0.13999999999999999
# TP: 1122, TN: 1327, FP: 490, FN: 83
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.73      0.82      1817
#            1       0.70      0.93      0.80      1205
#
#     accuracy                           0.81      3022
#    macro avg       0.82      0.83      0.81      3022
# weighted avg       0.84      0.81      0.81      3022
#
# Model saved to models/svm\svm_under_normal_residual_cnn_features_128.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/normal_residual_cnn_features_256.csv...
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:484: FutureWarning: `BaseEstimator._check_n_features` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation._check_n_features` instead.
#   warnings.warn(
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:493: FutureWarning: `BaseEstimator._check_feature_names` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation._check_feature_names` instead.
#   warnings.warn(
# Accuracy  : 0.8028
# Precision : 0.6829
# Recall    : 0.9436
# F1 Score  : 0.7923
# F2 Score  : 0.8766
# Best Threshold  : 0.13
# TP: 1137, TN: 1289, FP: 528, FN: 68
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.95      0.71      0.81      1817
#            1       0.68      0.94      0.79      1205
#
#     accuracy                           0.80      3022
#    macro avg       0.82      0.83      0.80      3022
# weighted avg       0.84      0.80      0.80      3022
#
# Model saved to models/svm\svm_under_normal_residual_cnn_features_256.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/over_sampled_residual_cnn_features_32.csv...
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:484: FutureWarning: `BaseEstimator._check_n_features` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation._check_n_features` instead.
#   warnings.warn(
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:493: FutureWarning: `BaseEstimator._check_feature_names` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation._check_feature_names` instead.
#   warnings.warn(
# Accuracy  : 0.8365
# Precision : 0.7257
# Recall    : 0.9485
# F1 Score  : 0.8223
# F2 Score  : 0.8937
# Best Threshold  : 0.1
# TP: 1143, TN: 1385, FP: 432, FN: 62
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.96      0.76      0.85      1817
#            1       0.73      0.95      0.82      1205
#
#     accuracy                           0.84      3022
#    macro avg       0.84      0.86      0.84      3022
# weighted avg       0.86      0.84      0.84      3022
#
# Model saved to models/svm\svm_under_over_sampled_residual_cnn_features_32.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/over_sampled_residual_cnn_features_64.csv...
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:484: FutureWarning: `BaseEstimator._check_n_features` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation._check_n_features` instead.
#   warnings.warn(
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:493: FutureWarning: `BaseEstimator._check_feature_names` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation._check_feature_names` instead.
#   warnings.warn(
# Accuracy  : 0.8319
# Precision : 0.7270
# Recall    : 0.9261
# F1 Score  : 0.8146
# F2 Score  : 0.8780
# Best Threshold  : 0.16999999999999998
# TP: 1116, TN: 1398, FP: 419, FN: 89
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.77      0.85      1817
#            1       0.73      0.93      0.81      1205
#
#     accuracy                           0.83      3022
#    macro avg       0.83      0.85      0.83      3022
# weighted avg       0.86      0.83      0.83      3022
#
# Model saved to models/svm\svm_under_over_sampled_residual_cnn_features_64.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/over_sampled_residual_cnn_features_128.csv...
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:484: FutureWarning: `BaseEstimator._check_n_features` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation._check_n_features` instead.
#   warnings.warn(
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:493: FutureWarning: `BaseEstimator._check_feature_names` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation._check_feature_names` instead.
#   warnings.warn(
# Accuracy  : 0.8246
# Precision : 0.7127
# Recall    : 0.9386
# F1 Score  : 0.8102
# F2 Score  : 0.8826
# Best Threshold  : 0.13
# TP: 1131, TN: 1361, FP: 456, FN: 74
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.95      0.75      0.84      1817
#            1       0.71      0.94      0.81      1205
#
#     accuracy                           0.82      3022
#    macro avg       0.83      0.84      0.82      3022
# weighted avg       0.85      0.82      0.83      3022
#
# Model saved to models/svm\svm_under_over_sampled_residual_cnn_features_128.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/over_sampled_residual_cnn_features_256.csv...
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:484: FutureWarning: `BaseEstimator._check_n_features` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation._check_n_features` instead.
#   warnings.warn(
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:493: FutureWarning: `BaseEstimator._check_feature_names` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation._check_feature_names` instead.
#   warnings.warn(
# Accuracy  : 0.8226
# Precision : 0.7102
# Recall    : 0.9378
# F1 Score  : 0.8083
# F2 Score  : 0.8813
# Best Threshold  : 0.13999999999999999
# TP: 1130, TN: 1356, FP: 461, FN: 75
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.95      0.75      0.83      1817
#            1       0.71      0.94      0.81      1205
#
#     accuracy                           0.82      3022
#    macro avg       0.83      0.84      0.82      3022
# weighted avg       0.85      0.82      0.82      3022
#
# Model saved to models/svm\svm_under_over_sampled_residual_cnn_features_256.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/under_sampled_residual_cnn_features_32.csv...
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:484: FutureWarning: `BaseEstimator._check_n_features` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation._check_n_features` instead.
#   warnings.warn(
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:493: FutureWarning: `BaseEstimator._check_feature_names` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation._check_feature_names` instead.
#   warnings.warn(
# Accuracy  : 0.7932
# Precision : 0.6726
# Recall    : 0.9378
# F1 Score  : 0.7834
# F2 Score  : 0.8692
# Best Threshold  : 0.13999999999999999
# TP: 1130, TN: 1267, FP: 550, FN: 75
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.70      0.80      1817
#            1       0.67      0.94      0.78      1205
#
#     accuracy                           0.79      3022
#    macro avg       0.81      0.82      0.79      3022
# weighted avg       0.84      0.79      0.79      3022
#
# Model saved to models/svm\svm_under_under_sampled_residual_cnn_features_32.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/under_sampled_residual_cnn_features_64.csv...
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:484: FutureWarning: `BaseEstimator._check_n_features` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation._check_n_features` instead.
#   warnings.warn(
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:493: FutureWarning: `BaseEstimator._check_feature_names` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation._check_feature_names` instead.
#   warnings.warn(
# Accuracy  : 0.8084
# Precision : 0.6918
# Recall    : 0.9369
# F1 Score  : 0.7959
# F2 Score  : 0.8749
# Best Threshold  : 0.13
# TP: 1129, TN: 1314, FP: 503, FN: 76
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.95      0.72      0.82      1817
#            1       0.69      0.94      0.80      1205
#
#     accuracy                           0.81      3022
#    macro avg       0.82      0.83      0.81      3022
# weighted avg       0.84      0.81      0.81      3022
#
# Model saved to models/svm\svm_under_under_sampled_residual_cnn_features_64.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/under_sampled_residual_cnn_features_128.csv...
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:484: FutureWarning: `BaseEstimator._check_n_features` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation._check_n_features` instead.
#   warnings.warn(
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:493: FutureWarning: `BaseEstimator._check_feature_names` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation._check_feature_names` instead.
#   warnings.warn(
# Accuracy  : 0.8250
# Precision : 0.7139
# Recall    : 0.9361
# F1 Score  : 0.8101
# F2 Score  : 0.8812
# Best Threshold  : 0.13
# TP: 1128, TN: 1365, FP: 452, FN: 77
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.95      0.75      0.84      1817
#            1       0.71      0.94      0.81      1205
#
#     accuracy                           0.82      3022
#    macro avg       0.83      0.84      0.82      3022
# weighted avg       0.85      0.82      0.83      3022
#
# Model saved to models/svm\svm_under_under_sampled_residual_cnn_features_128.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/under_sampled_residual_cnn_features_256.csv...
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:484: FutureWarning: `BaseEstimator._check_n_features` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation._check_n_features` instead.
#   warnings.warn(
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:493: FutureWarning: `BaseEstimator._check_feature_names` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation._check_feature_names` instead.
#   warnings.warn(
# Accuracy  : 0.8375
# Precision : 0.7349
# Recall    : 0.9270
# F1 Score  : 0.8198
# F2 Score  : 0.8809
# Best Threshold  : 0.14999999999999997
# TP: 1117, TN: 1414, FP: 403, FN: 88
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.78      0.85      1817
#            1       0.73      0.93      0.82      1205
#
#     accuracy                           0.84      3022
#    macro avg       0.84      0.85      0.84      3022
# weighted avg       0.86      0.84      0.84      3022
#
# Model saved to models/svm\svm_under_under_sampled_residual_cnn_features_256.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/weighted_residual_cnn_features_32.csv...
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:484: FutureWarning: `BaseEstimator._check_n_features` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation._check_n_features` instead.
#   warnings.warn(
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:493: FutureWarning: `BaseEstimator._check_feature_names` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation._check_feature_names` instead.
#   warnings.warn(
# Accuracy  : 0.8312
# Precision : 0.7215
# Recall    : 0.9394
# F1 Score  : 0.8161
# F2 Score  : 0.8859
# Best Threshold  : 0.13
# TP: 1132, TN: 1380, FP: 437, FN: 73
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.95      0.76      0.84      1817
#            1       0.72      0.94      0.82      1205
#
#     accuracy                           0.83      3022
#    macro avg       0.84      0.85      0.83      3022
# weighted avg       0.86      0.83      0.83      3022
#
# Model saved to models/svm\svm_under_weighted_residual_cnn_features_32.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/weighted_residual_cnn_features_64.csv...
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:484: FutureWarning: `BaseEstimator._check_n_features` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation._check_n_features` instead.
#   warnings.warn(
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:493: FutureWarning: `BaseEstimator._check_feature_names` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation._check_feature_names` instead.
#   warnings.warn(
# Accuracy  : 0.8147
# Precision : 0.7058
# Recall    : 0.9178
# F1 Score  : 0.7980
# F2 Score  : 0.8658
# Best Threshold  : 0.15999999999999998
# TP: 1106, TN: 1356, FP: 461, FN: 99
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.93      0.75      0.83      1817
#            1       0.71      0.92      0.80      1205
#
#     accuracy                           0.81      3022
#    macro avg       0.82      0.83      0.81      3022
# weighted avg       0.84      0.81      0.82      3022
#
# Model saved to models/svm\svm_under_weighted_residual_cnn_features_64.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/weighted_residual_cnn_features_128.csv...
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:484: FutureWarning: `BaseEstimator._check_n_features` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation._check_n_features` instead.
#   warnings.warn(
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:493: FutureWarning: `BaseEstimator._check_feature_names` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation._check_feature_names` instead.
#   warnings.warn(
# Accuracy  : 0.8544
# Precision : 0.7643
# Recall    : 0.9178
# F1 Score  : 0.8341
# F2 Score  : 0.8824
# Best Threshold  : 0.20999999999999996
# TP: 1106, TN: 1476, FP: 341, FN: 99
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.81      0.87      1817
#            1       0.76      0.92      0.83      1205
#
#     accuracy                           0.85      3022
#    macro avg       0.85      0.87      0.85      3022
# weighted avg       0.87      0.85      0.86      3022
#
# Model saved to models/svm\svm_under_weighted_residual_cnn_features_128.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/weighted_residual_cnn_features_256.csv...
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:484: FutureWarning: `BaseEstimator._check_n_features` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation._check_n_features` instead.
#   warnings.warn(
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:493: FutureWarning: `BaseEstimator._check_feature_names` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation._check_feature_names` instead.
#   warnings.warn(
# Accuracy  : 0.8170
# Precision : 0.7050
# Recall    : 0.9303
# F1 Score  : 0.8021
# F2 Score  : 0.8744
# Best Threshold  : 0.13999999999999999
# TP: 1121, TN: 1348, FP: 469, FN: 84
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.74      0.83      1817
#            1       0.71      0.93      0.80      1205
#
#     accuracy                           0.82      3022
#    macro avg       0.82      0.84      0.82      3022
# weighted avg       0.85      0.82      0.82      3022
#
# Model saved to models/svm\svm_under_weighted_residual_cnn_features_256.joblib
# Results saved to results_summary.csv

# %% [markdown]
# ### Over-Sampled

# %%
train(residual_dataset_paths, "svm", "over")
# Out:
# Processing ../feature-extraction/residual_cnn/datasets/normal_residual_cnn_features_32.csv...
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# Accuracy  : 0.8206
# Precision : 0.7058
# Recall    : 0.9436
# F1 Score  : 0.8075
# F2 Score  : 0.8840
# Best Threshold  : 0.12
# TP: 1137, TN: 1343, FP: 474, FN: 68
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.95      0.74      0.83      1817
#            1       0.71      0.94      0.81      1205
#
#     accuracy                           0.82      3022
#    macro avg       0.83      0.84      0.82      3022
# weighted avg       0.85      0.82      0.82      3022
#
# Model saved to models/svm\svm_over_normal_residual_cnn_features_32.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/normal_residual_cnn_features_64.csv...
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# Accuracy  : 0.8441
# Precision : 0.7473
# Recall    : 0.9203
# F1 Score  : 0.8248
# F2 Score  : 0.8796
# Best Threshold  : 0.16999999999999998
# TP: 1109, TN: 1442, FP: 375, FN: 96
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.79      0.86      1817
#            1       0.75      0.92      0.82      1205
#
#     accuracy                           0.84      3022
#    macro avg       0.84      0.86      0.84      3022
# weighted avg       0.86      0.84      0.85      3022
#
# Model saved to models/svm\svm_over_normal_residual_cnn_features_64.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/normal_residual_cnn_features_128.csv...
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# Accuracy  : 0.8028
# Precision : 0.6820
# Recall    : 0.9469
# F1 Score  : 0.7929
# F2 Score  : 0.8786
# Best Threshold  : 0.13
# TP: 1141, TN: 1285, FP: 532, FN: 64
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.95      0.71      0.81      1817
#            1       0.68      0.95      0.79      1205
#
#     accuracy                           0.80      3022
#    macro avg       0.82      0.83      0.80      3022
# weighted avg       0.84      0.80      0.80      3022
#
# Model saved to models/svm\svm_over_normal_residual_cnn_features_128.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/normal_residual_cnn_features_256.csv...
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# Accuracy  : 0.8087
# Precision : 0.6901
# Recall    : 0.9444
# F1 Score  : 0.7975
# F2 Score  : 0.8796
# Best Threshold  : 0.13
# TP: 1138, TN: 1306, FP: 511, FN: 67
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.95      0.72      0.82      1817
#            1       0.69      0.94      0.80      1205
#
#     accuracy                           0.81      3022
#    macro avg       0.82      0.83      0.81      3022
# weighted avg       0.85      0.81      0.81      3022
#
# Model saved to models/svm\svm_over_normal_residual_cnn_features_256.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/over_sampled_residual_cnn_features_32.csv...
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# Accuracy  : 0.8392
# Precision : 0.7315
# Recall    : 0.9427
# F1 Score  : 0.8238
# F2 Score  : 0.8913
# Best Threshold  : 0.1
# TP: 1136, TN: 1400, FP: 417, FN: 69
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.95      0.77      0.85      1817
#            1       0.73      0.94      0.82      1205
#
#     accuracy                           0.84      3022
#    macro avg       0.84      0.86      0.84      3022
# weighted avg       0.86      0.84      0.84      3022
#
# Model saved to models/svm\svm_over_over_sampled_residual_cnn_features_32.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/over_sampled_residual_cnn_features_64.csv...
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# Accuracy  : 0.8302
# Precision : 0.7232
# Recall    : 0.9303
# F1 Score  : 0.8138
# F2 Score  : 0.8799
# Best Threshold  : 0.15999999999999998
# TP: 1121, TN: 1388, FP: 429, FN: 84
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.76      0.84      1817
#            1       0.72      0.93      0.81      1205
#
#     accuracy                           0.83      3022
#    macro avg       0.83      0.85      0.83      3022
# weighted avg       0.86      0.83      0.83      3022
#
# Model saved to models/svm\svm_over_over_sampled_residual_cnn_features_64.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/over_sampled_residual_cnn_features_128.csv...
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# Accuracy  : 0.8216
# Precision : 0.7071
# Recall    : 0.9436
# F1 Score  : 0.8084
# F2 Score  : 0.8844
# Best Threshold  : 0.12
# TP: 1137, TN: 1346, FP: 471, FN: 68
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.95      0.74      0.83      1817
#            1       0.71      0.94      0.81      1205
#
#     accuracy                           0.82      3022
#    macro avg       0.83      0.84      0.82      3022
# weighted avg       0.85      0.82      0.82      3022
#
# Model saved to models/svm\svm_over_over_sampled_residual_cnn_features_128.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/over_sampled_residual_cnn_features_256.csv...
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# Accuracy  : 0.8170
# Precision : 0.7027
# Recall    : 0.9378
# F1 Score  : 0.8034
# F2 Score  : 0.8790
# Best Threshold  : 0.13
# TP: 1130, TN: 1339, FP: 478, FN: 75
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.95      0.74      0.83      1817
#            1       0.70      0.94      0.80      1205
#
#     accuracy                           0.82      3022
#    macro avg       0.82      0.84      0.82      3022
# weighted avg       0.85      0.82      0.82      3022
#
# Model saved to models/svm\svm_over_over_sampled_residual_cnn_features_256.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/under_sampled_residual_cnn_features_32.csv...
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# Accuracy  : 0.8008
# Precision : 0.6822
# Recall    : 0.9369
# F1 Score  : 0.7895
# F2 Score  : 0.8718
# Best Threshold  : 0.13999999999999999
# TP: 1129, TN: 1291, FP: 526, FN: 76
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.71      0.81      1817
#            1       0.68      0.94      0.79      1205
#
#     accuracy                           0.80      3022
#    macro avg       0.81      0.82      0.80      3022
# weighted avg       0.84      0.80      0.80      3022
#
# Model saved to models/svm\svm_over_under_sampled_residual_cnn_features_32.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/under_sampled_residual_cnn_features_64.csv...
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# Accuracy  : 0.8266
# Precision : 0.7198
# Recall    : 0.9253
# F1 Score  : 0.8097
# F2 Score  : 0.8753
# Best Threshold  : 0.13999999999999999
# TP: 1115, TN: 1383, FP: 434, FN: 90
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.76      0.84      1817
#            1       0.72      0.93      0.81      1205
#
#     accuracy                           0.83      3022
#    macro avg       0.83      0.84      0.83      3022
# weighted avg       0.85      0.83      0.83      3022
#
# Model saved to models/svm\svm_over_under_sampled_residual_cnn_features_64.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/under_sampled_residual_cnn_features_128.csv...
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# Accuracy  : 0.8210
# Precision : 0.7080
# Recall    : 0.9378
# F1 Score  : 0.8069
# F2 Score  : 0.8806
# Best Threshold  : 0.12
# TP: 1130, TN: 1351, FP: 466, FN: 75
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.95      0.74      0.83      1817
#            1       0.71      0.94      0.81      1205
#
#     accuracy                           0.82      3022
#    macro avg       0.83      0.84      0.82      3022
# weighted avg       0.85      0.82      0.82      3022
#
# Model saved to models/svm\svm_over_under_sampled_residual_cnn_features_128.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/under_sampled_residual_cnn_features_256.csv...
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# Accuracy  : 0.8309
# Precision : 0.7233
# Recall    : 0.9328
# F1 Score  : 0.8148
# F2 Score  : 0.8817
# Best Threshold  : 0.13
# TP: 1124, TN: 1387, FP: 430, FN: 81
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.76      0.84      1817
#            1       0.72      0.93      0.81      1205
#
#     accuracy                           0.83      3022
#    macro avg       0.83      0.85      0.83      3022
# weighted avg       0.86      0.83      0.83      3022
#
# Model saved to models/svm\svm_over_under_sampled_residual_cnn_features_256.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/weighted_residual_cnn_features_32.csv...
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# Accuracy  : 0.8269
# Precision : 0.7142
# Recall    : 0.9436
# F1 Score  : 0.8130
# F2 Score  : 0.8866
# Best Threshold  : 0.12
# TP: 1137, TN: 1362, FP: 455, FN: 68
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.95      0.75      0.84      1817
#            1       0.71      0.94      0.81      1205
#
#     accuracy                           0.83      3022
#    macro avg       0.83      0.85      0.83      3022
# weighted avg       0.86      0.83      0.83      3022
#
# Model saved to models/svm\svm_over_weighted_residual_cnn_features_32.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/weighted_residual_cnn_features_64.csv...
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# Accuracy  : 0.8140
# Precision : 0.7041
# Recall    : 0.9203
# F1 Score  : 0.7978
# F2 Score  : 0.8671
# Best Threshold  : 0.14999999999999997
# TP: 1109, TN: 1351, FP: 466, FN: 96
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.93      0.74      0.83      1817
#            1       0.70      0.92      0.80      1205
#
#     accuracy                           0.81      3022
#    macro avg       0.82      0.83      0.81      3022
# weighted avg       0.84      0.81      0.82      3022
#
# Model saved to models/svm\svm_over_weighted_residual_cnn_features_64.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/weighted_residual_cnn_features_128.csv...
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# Accuracy  : 0.8220
# Precision : 0.7086
# Recall    : 0.9402
# F1 Score  : 0.8081
# F2 Score  : 0.8825
# Best Threshold  : 0.13
# TP: 1133, TN: 1351, FP: 466, FN: 72
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.95      0.74      0.83      1817
#            1       0.71      0.94      0.81      1205
#
#     accuracy                           0.82      3022
#    macro avg       0.83      0.84      0.82      3022
# weighted avg       0.85      0.82      0.82      3022
#
# Model saved to models/svm\svm_over_weighted_residual_cnn_features_128.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/weighted_residual_cnn_features_256.csv...
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# Accuracy  : 0.8322
# Precision : 0.7290
# Recall    : 0.9220
# F1 Score  : 0.8142
# F2 Score  : 0.8756
# Best Threshold  : 0.14999999999999997
# TP: 1111, TN: 1404, FP: 413, FN: 94
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.77      0.85      1817
#            1       0.73      0.92      0.81      1205
#
#     accuracy                           0.83      3022
#    macro avg       0.83      0.85      0.83      3022
# weighted avg       0.85      0.83      0.83      3022
#
# Model saved to models/svm\svm_over_weighted_residual_cnn_features_256.joblib
# Results saved to results_summary.csv

# %% [markdown]
# ### Weighted

# %%
train(residual_dataset_paths, "svm", "weighted")
# Out:
# Processing ../feature-extraction/residual_cnn/datasets/normal_residual_cnn_features_32.csv...
# Accuracy  : 0.8458
# Precision : 0.7488
# Recall    : 0.9228
# F1 Score  : 0.8268
# F2 Score  : 0.8818
# Best Threshold  : 0.11
# TP: 1112, TN: 1444, FP: 373, FN: 93
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.79      0.86      1817
#            1       0.75      0.92      0.83      1205
#
#     accuracy                           0.85      3022
#    macro avg       0.84      0.86      0.84      3022
# weighted avg       0.86      0.85      0.85      3022
#
# Model saved to models/svm\svm_weighted_normal_residual_cnn_features_32.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/normal_residual_cnn_features_64.csv...
# Accuracy  : 0.8451
# Precision : 0.7485
# Recall    : 0.9212
# F1 Score  : 0.8259
# F2 Score  : 0.8805
# Best Threshold  : 0.12
# TP: 1110, TN: 1444, FP: 373, FN: 95
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.79      0.86      1817
#            1       0.75      0.92      0.83      1205
#
#     accuracy                           0.85      3022
#    macro avg       0.84      0.86      0.84      3022
# weighted avg       0.86      0.85      0.85      3022
#
# Model saved to models/svm\svm_weighted_normal_residual_cnn_features_64.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/normal_residual_cnn_features_128.csv...
# Accuracy  : 0.8183
# Precision : 0.7073
# Recall    : 0.9286
# F1 Score  : 0.8030
# F2 Score  : 0.8739
# Best Threshold  : 0.1
# TP: 1119, TN: 1354, FP: 463, FN: 86
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.75      0.83      1817
#            1       0.71      0.93      0.80      1205
#
#     accuracy                           0.82      3022
#    macro avg       0.82      0.84      0.82      3022
# weighted avg       0.85      0.82      0.82      3022
#
# Model saved to models/svm\svm_weighted_normal_residual_cnn_features_128.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/normal_residual_cnn_features_256.csv...
# Accuracy  : 0.8273
# Precision : 0.7191
# Recall    : 0.9303
# F1 Score  : 0.8111
# F2 Score  : 0.8787
# Best Threshold  : 0.1
# TP: 1121, TN: 1379, FP: 438, FN: 84
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.76      0.84      1817
#            1       0.72      0.93      0.81      1205
#
#     accuracy                           0.83      3022
#    macro avg       0.83      0.84      0.83      3022
# weighted avg       0.85      0.83      0.83      3022
#
# Model saved to models/svm\svm_weighted_normal_residual_cnn_features_256.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/over_sampled_residual_cnn_features_32.csv...
# Accuracy  : 0.8574
# Precision : 0.7673
# Recall    : 0.9220
# F1 Score  : 0.8375
# F2 Score  : 0.8862
# Best Threshold  : 0.1
# TP: 1111, TN: 1480, FP: 337, FN: 94
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.81      0.87      1817
#            1       0.77      0.92      0.84      1205
#
#     accuracy                           0.86      3022
#    macro avg       0.85      0.87      0.86      3022
# weighted avg       0.87      0.86      0.86      3022
#
# Model saved to models/svm\svm_weighted_over_sampled_residual_cnn_features_32.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/over_sampled_residual_cnn_features_64.csv...
# Accuracy  : 0.8342
# Precision : 0.7304
# Recall    : 0.9261
# F1 Score  : 0.8167
# F2 Score  : 0.8790
# Best Threshold  : 0.12
# TP: 1116, TN: 1405, FP: 412, FN: 89
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.77      0.85      1817
#            1       0.73      0.93      0.82      1205
#
#     accuracy                           0.83      3022
#    macro avg       0.84      0.85      0.83      3022
# weighted avg       0.86      0.83      0.84      3022
#
# Model saved to models/svm\svm_weighted_over_sampled_residual_cnn_features_64.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/over_sampled_residual_cnn_features_128.csv...
# Accuracy  : 0.8319
# Precision : 0.7259
# Recall    : 0.9295
# F1 Score  : 0.8151
# F2 Score  : 0.8801
# Best Threshold  : 0.1
# TP: 1120, TN: 1394, FP: 423, FN: 85
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.77      0.85      1817
#            1       0.73      0.93      0.82      1205
#
#     accuracy                           0.83      3022
#    macro avg       0.83      0.85      0.83      3022
# weighted avg       0.86      0.83      0.83      3022
#
# Model saved to models/svm\svm_weighted_over_sampled_residual_cnn_features_128.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/over_sampled_residual_cnn_features_256.csv...
# Accuracy  : 0.8332
# Precision : 0.7286
# Recall    : 0.9270
# F1 Score  : 0.8159
# F2 Score  : 0.8791
# Best Threshold  : 0.11
# TP: 1117, TN: 1401, FP: 416, FN: 88
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.77      0.85      1817
#            1       0.73      0.93      0.82      1205
#
#     accuracy                           0.83      3022
#    macro avg       0.83      0.85      0.83      3022
# weighted avg       0.86      0.83      0.83      3022
#
# Model saved to models/svm\svm_weighted_over_sampled_residual_cnn_features_256.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/under_sampled_residual_cnn_features_32.csv...
# Accuracy  : 0.8005
# Precision : 0.6822
# Recall    : 0.9353
# F1 Score  : 0.7889
# F2 Score  : 0.8707
# Best Threshold  : 0.1
# TP: 1127, TN: 1292, FP: 525, FN: 78
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.71      0.81      1817
#            1       0.68      0.94      0.79      1205
#
#     accuracy                           0.80      3022
#    macro avg       0.81      0.82      0.80      3022
# weighted avg       0.84      0.80      0.80      3022
#
# Model saved to models/svm\svm_weighted_under_sampled_residual_cnn_features_32.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/under_sampled_residual_cnn_features_64.csv...
# Accuracy  : 0.8269
# Precision : 0.7203
# Recall    : 0.9253
# F1 Score  : 0.8100
# F2 Score  : 0.8755
# Best Threshold  : 0.1
# TP: 1115, TN: 1384, FP: 433, FN: 90
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.76      0.84      1817
#            1       0.72      0.93      0.81      1205
#
#     accuracy                           0.83      3022
#    macro avg       0.83      0.84      0.83      3022
# weighted avg       0.85      0.83      0.83      3022
#
# Model saved to models/svm\svm_weighted_under_sampled_residual_cnn_features_64.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/under_sampled_residual_cnn_features_128.csv...
# Accuracy  : 0.8355
# Precision : 0.7323
# Recall    : 0.9261
# F1 Score  : 0.8179
# F2 Score  : 0.8796
# Best Threshold  : 0.1
# TP: 1116, TN: 1409, FP: 408, FN: 89
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.78      0.85      1817
#            1       0.73      0.93      0.82      1205
#
#     accuracy                           0.84      3022
#    macro avg       0.84      0.85      0.83      3022
# weighted avg       0.86      0.84      0.84      3022
#
# Model saved to models/svm\svm_weighted_under_sampled_residual_cnn_features_128.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/under_sampled_residual_cnn_features_256.csv...
# Accuracy  : 0.8359
# Precision : 0.7322
# Recall    : 0.9278
# F1 Score  : 0.8184
# F2 Score  : 0.8807
# Best Threshold  : 0.1
# TP: 1118, TN: 1408, FP: 409, FN: 87
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.77      0.85      1817
#            1       0.73      0.93      0.82      1205
#
#     accuracy                           0.84      3022
#    macro avg       0.84      0.85      0.83      3022
# weighted avg       0.86      0.84      0.84      3022
#
# Model saved to models/svm\svm_weighted_under_sampled_residual_cnn_features_256.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/weighted_residual_cnn_features_32.csv...
# Accuracy  : 0.8412
# Precision : 0.7390
# Recall    : 0.9303
# F1 Score  : 0.8237
# F2 Score  : 0.8845
# Best Threshold  : 0.1
# TP: 1121, TN: 1421, FP: 396, FN: 84
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.78      0.86      1817
#            1       0.74      0.93      0.82      1205
#
#     accuracy                           0.84      3022
#    macro avg       0.84      0.86      0.84      3022
# weighted avg       0.86      0.84      0.84      3022
#
# Model saved to models/svm\svm_weighted_weighted_residual_cnn_features_32.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/weighted_residual_cnn_features_64.csv...
# Accuracy  : 0.8160
# Precision : 0.7079
# Recall    : 0.9170
# F1 Score  : 0.7990
# F2 Score  : 0.8659
# Best Threshold  : 0.11
# TP: 1105, TN: 1361, FP: 456, FN: 100
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.93      0.75      0.83      1817
#            1       0.71      0.92      0.80      1205
#
#     accuracy                           0.82      3022
#    macro avg       0.82      0.83      0.81      3022
# weighted avg       0.84      0.82      0.82      3022
#
# Model saved to models/svm\svm_weighted_weighted_residual_cnn_features_64.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/weighted_residual_cnn_features_128.csv...
# Accuracy  : 0.8518
# Precision : 0.7601
# Recall    : 0.9178
# F1 Score  : 0.8316
# F2 Score  : 0.8813
# Best Threshold  : 0.13999999999999999
# TP: 1106, TN: 1468, FP: 349, FN: 99
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.81      0.87      1817
#            1       0.76      0.92      0.83      1205
#
#     accuracy                           0.85      3022
#    macro avg       0.85      0.86      0.85      3022
# weighted avg       0.87      0.85      0.85      3022
#
# Model saved to models/svm\svm_weighted_weighted_residual_cnn_features_128.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/weighted_residual_cnn_features_256.csv...
# Accuracy  : 0.8250
# Precision : 0.7169
# Recall    : 0.9270
# F1 Score  : 0.8085
# F2 Score  : 0.8757
# Best Threshold  : 0.1
# TP: 1117, TN: 1376, FP: 441, FN: 88
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.76      0.84      1817
#            1       0.72      0.93      0.81      1205
#
#     accuracy                           0.82      3022
#    macro avg       0.83      0.84      0.82      3022
# weighted avg       0.85      0.82      0.83      3022
#
# Model saved to models/svm\svm_weighted_weighted_residual_cnn_features_256.joblib
# Results saved to results_summary.csv
