# %% [markdown]
# # Imports

# %%
from data_utils import train

# %% [markdown]
# # Train Model

# %% [markdown]
# ## Residual

# %% [markdown]
# ### Datasets

# %%
residual_dataset_paths = [
    "../feature-extraction/residual_cnn/datasets/normal_residual_cnn_features_32.csv",
    "../feature-extraction/residual_cnn/datasets/normal_residual_cnn_features_64.csv",
    "../feature-extraction/residual_cnn/datasets/normal_residual_cnn_features_128.csv",
    "../feature-extraction/residual_cnn/datasets/normal_residual_cnn_features_256.csv",
    "../feature-extraction/residual_cnn/datasets/over_sampled_residual_cnn_features_32.csv",
    "../feature-extraction/residual_cnn/datasets/over_sampled_residual_cnn_features_64.csv",
    "../feature-extraction/residual_cnn/datasets/over_sampled_residual_cnn_features_128.csv",
    "../feature-extraction/residual_cnn/datasets/over_sampled_residual_cnn_features_256.csv",
    "../feature-extraction/residual_cnn/datasets/under_sampled_residual_cnn_features_32.csv",
    "../feature-extraction/residual_cnn/datasets/under_sampled_residual_cnn_features_64.csv",
    "../feature-extraction/residual_cnn/datasets/under_sampled_residual_cnn_features_128.csv",
    "../feature-extraction/residual_cnn/datasets/under_sampled_residual_cnn_features_256.csv",
    "../feature-extraction/residual_cnn/datasets/weighted_residual_cnn_features_32.csv",
    "../feature-extraction/residual_cnn/datasets/weighted_residual_cnn_features_64.csv",
    "../feature-extraction/residual_cnn/datasets/weighted_residual_cnn_features_128.csv",
    "../feature-extraction/residual_cnn/datasets/weighted_residual_cnn_features_256.csv",

]

# %% [markdown]
# ### Imbalanced

# %%
train(residual_dataset_paths, "svm", "normal")
# Out:
# Processing ../feature-extraction/residual_cnn/datasets/normal_residual_cnn_features_32.csv...
# Accuracy  : 0.8537
# Precision : 0.7640
# Recall    : 0.9162
# F1 Score  : 0.8332
# F2 Score  : 0.8811
# Best Threshold  : 0.11
# TP: 1104, TN: 1476, FP: 341, FN: 101
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.81      0.87      1817
#            1       0.76      0.92      0.83      1205
#
#     accuracy                           0.85      3022
#    macro avg       0.85      0.86      0.85      3022
# weighted avg       0.87      0.85      0.86      3022
#
# Model saved to models/svm\svm_normal_normal_residual_cnn_features_32.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/normal_residual_cnn_features_64.csv...
# Accuracy  : 0.8494
# Precision : 0.7622
# Recall    : 0.9046
# F1 Score  : 0.8273
# F2 Score  : 0.8720
# Best Threshold  : 0.12
# TP: 1090, TN: 1477, FP: 340, FN: 115
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.93      0.81      0.87      1817
#            1       0.76      0.90      0.83      1205
#
#     accuracy                           0.85      3022
#    macro avg       0.85      0.86      0.85      3022
# weighted avg       0.86      0.85      0.85      3022
#
# Model saved to models/svm\svm_normal_normal_residual_cnn_features_64.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/normal_residual_cnn_features_128.csv...
# Accuracy  : 0.8408
# Precision : 0.7456
# Recall    : 0.9120
# F1 Score  : 0.8205
# F2 Score  : 0.8731
# Best Threshold  : 0.12
# TP: 1099, TN: 1442, FP: 375, FN: 106
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.93      0.79      0.86      1817
#            1       0.75      0.91      0.82      1205
#
#     accuracy                           0.84      3022
#    macro avg       0.84      0.85      0.84      3022
# weighted avg       0.86      0.84      0.84      3022
#
# Model saved to models/svm\svm_normal_normal_residual_cnn_features_128.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/normal_residual_cnn_features_256.csv...
# Accuracy  : 0.8475
# Precision : 0.7583
# Recall    : 0.9062
# F1 Score  : 0.8257
# F2 Score  : 0.8722
# Best Threshold  : 0.12
# TP: 1092, TN: 1469, FP: 348, FN: 113
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.93      0.81      0.86      1817
#            1       0.76      0.91      0.83      1205
#
#     accuracy                           0.85      3022
#    macro avg       0.84      0.86      0.85      3022
# weighted avg       0.86      0.85      0.85      3022
#
# Model saved to models/svm\svm_normal_normal_residual_cnn_features_256.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/over_sampled_residual_cnn_features_32.csv...
# Accuracy  : 0.8653
# Precision : 0.7858
# Recall    : 0.9104
# F1 Score  : 0.8435
# F2 Score  : 0.8824
# Best Threshold  : 0.1
# TP: 1097, TN: 1518, FP: 299, FN: 108
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.93      0.84      0.88      1817
#            1       0.79      0.91      0.84      1205
#
#     accuracy                           0.87      3022
#    macro avg       0.86      0.87      0.86      3022
# weighted avg       0.87      0.87      0.87      3022
#
# Model saved to models/svm\svm_normal_over_sampled_residual_cnn_features_32.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/over_sampled_residual_cnn_features_64.csv...
# Accuracy  : 0.8422
# Precision : 0.7423
# Recall    : 0.9253
# F1 Score  : 0.8238
# F2 Score  : 0.8818
# Best Threshold  : 0.12
# TP: 1115, TN: 1430, FP: 387, FN: 90
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.79      0.86      1817
#            1       0.74      0.93      0.82      1205
#
#     accuracy                           0.84      3022
#    macro avg       0.84      0.86      0.84      3022
# weighted avg       0.86      0.84      0.84      3022
#
# Model saved to models/svm\svm_normal_over_sampled_residual_cnn_features_64.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/over_sampled_residual_cnn_features_128.csv...
# Accuracy  : 0.8445
# Precision : 0.7485
# Recall    : 0.9187
# F1 Score  : 0.8249
# F2 Score  : 0.8787
# Best Threshold  : 0.11
# TP: 1107, TN: 1445, FP: 372, FN: 98
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.80      0.86      1817
#            1       0.75      0.92      0.82      1205
#
#     accuracy                           0.84      3022
#    macro avg       0.84      0.86      0.84      3022
# weighted avg       0.86      0.84      0.85      3022
#
# Model saved to models/svm\svm_normal_over_sampled_residual_cnn_features_128.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/over_sampled_residual_cnn_features_256.csv...
# Accuracy  : 0.8415
# Precision : 0.7446
# Recall    : 0.9170
# F1 Score  : 0.8219
# F2 Score  : 0.8764
# Best Threshold  : 0.11
# TP: 1105, TN: 1438, FP: 379, FN: 100
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.93      0.79      0.86      1817
#            1       0.74      0.92      0.82      1205
#
#     accuracy                           0.84      3022
#    macro avg       0.84      0.85      0.84      3022
# weighted avg       0.86      0.84      0.84      3022
#
# Model saved to models/svm\svm_normal_over_sampled_residual_cnn_features_256.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/under_sampled_residual_cnn_features_32.csv...
# Accuracy  : 0.8355
# Precision : 0.7428
# Recall    : 0.8988
# F1 Score  : 0.8134
# F2 Score  : 0.8625
# Best Threshold  : 0.13
# TP: 1083, TN: 1442, FP: 375, FN: 122
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.92      0.79      0.85      1817
#            1       0.74      0.90      0.81      1205
#
#     accuracy                           0.84      3022
#    macro avg       0.83      0.85      0.83      3022
# weighted avg       0.85      0.84      0.84      3022
#
# Model saved to models/svm\svm_normal_under_sampled_residual_cnn_features_32.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/under_sampled_residual_cnn_features_64.csv...
# Accuracy  : 0.8508
# Precision : 0.7633
# Recall    : 0.9071
# F1 Score  : 0.8290
# F2 Score  : 0.8741
# Best Threshold  : 0.12
# TP: 1093, TN: 1478, FP: 339, FN: 112
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.93      0.81      0.87      1817
#            1       0.76      0.91      0.83      1205
#
#     accuracy                           0.85      3022
#    macro avg       0.85      0.86      0.85      3022
# weighted avg       0.86      0.85      0.85      3022
#
# Model saved to models/svm\svm_normal_under_sampled_residual_cnn_features_64.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/under_sampled_residual_cnn_features_128.csv...
# Accuracy  : 0.8488
# Precision : 0.7544
# Recall    : 0.9203
# F1 Score  : 0.8292
# F2 Score  : 0.8816
# Best Threshold  : 0.11
# TP: 1109, TN: 1456, FP: 361, FN: 96
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.80      0.86      1817
#            1       0.75      0.92      0.83      1205
#
#     accuracy                           0.85      3022
#    macro avg       0.85      0.86      0.85      3022
# weighted avg       0.86      0.85      0.85      3022
#
# Model saved to models/svm\svm_normal_under_sampled_residual_cnn_features_128.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/under_sampled_residual_cnn_features_256.csv...
# Accuracy  : 0.8491
# Precision : 0.7574
# Recall    : 0.9145
# F1 Score  : 0.8286
# F2 Score  : 0.8781
# Best Threshold  : 0.11
# TP: 1102, TN: 1464, FP: 353, FN: 103
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.93      0.81      0.87      1817
#            1       0.76      0.91      0.83      1205
#
#     accuracy                           0.85      3022
#    macro avg       0.85      0.86      0.85      3022
# weighted avg       0.86      0.85      0.85      3022
#
# Model saved to models/svm\svm_normal_under_sampled_residual_cnn_features_256.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/weighted_residual_cnn_features_32.csv...
# Accuracy  : 0.8564
# Precision : 0.7686
# Recall    : 0.9154
# F1 Score  : 0.8356
# F2 Score  : 0.8817
# Best Threshold  : 0.11
# TP: 1103, TN: 1485, FP: 332, FN: 102
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.82      0.87      1817
#            1       0.77      0.92      0.84      1205
#
#     accuracy                           0.86      3022
#    macro avg       0.85      0.87      0.85      3022
# weighted avg       0.87      0.86      0.86      3022
#
# Model saved to models/svm\svm_normal_weighted_residual_cnn_features_32.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/weighted_residual_cnn_features_64.csv...
# Accuracy  : 0.8395
# Precision : 0.7507
# Recall    : 0.8946
# F1 Score  : 0.8164
# F2 Score  : 0.8616
# Best Threshold  : 0.13
# TP: 1078, TN: 1459, FP: 358, FN: 127
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.92      0.80      0.86      1817
#            1       0.75      0.89      0.82      1205
#
#     accuracy                           0.84      3022
#    macro avg       0.84      0.85      0.84      3022
# weighted avg       0.85      0.84      0.84      3022
#
# Model saved to models/svm\svm_normal_weighted_residual_cnn_features_64.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/weighted_residual_cnn_features_128.csv...
# Accuracy  : 0.8504
# Precision : 0.7588
# Recall    : 0.9162
# F1 Score  : 0.8301
# F2 Score  : 0.8797
# Best Threshold  : 0.12
# TP: 1104, TN: 1466, FP: 351, FN: 101
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.81      0.87      1817
#            1       0.76      0.92      0.83      1205
#
#     accuracy                           0.85      3022
#    macro avg       0.85      0.86      0.85      3022
# weighted avg       0.87      0.85      0.85      3022
#
# Model saved to models/svm\svm_normal_weighted_residual_cnn_features_128.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/weighted_residual_cnn_features_256.csv...
# Accuracy  : 0.8445
# Precision : 0.7540
# Recall    : 0.9054
# F1 Score  : 0.8228
# F2 Score  : 0.8704
# Best Threshold  : 0.12
# TP: 1091, TN: 1461, FP: 356, FN: 114
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.93      0.80      0.86      1817
#            1       0.75      0.91      0.82      1205
#
#     accuracy                           0.84      3022
#    macro avg       0.84      0.85      0.84      3022
# weighted avg       0.86      0.84      0.85      3022
#
# Model saved to models/svm\svm_normal_weighted_residual_cnn_features_256.joblib
# Results saved to results_summary.csv

# %% [markdown]
# ### Under-Sampled

# %%
train(residual_dataset_paths, "svm", "under")
# Out:
# Processing ../feature-extraction/residual_cnn/datasets/normal_residual_cnn_features_32.csv...
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:484: FutureWarning: `BaseEstimator._check_n_features` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation._check_n_features` instead.
#   warnings.warn(
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:493: FutureWarning: `BaseEstimator._check_feature_names` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation._check_feature_names` instead.
#   warnings.warn(
# Accuracy  : 0.8342
# Precision : 0.7289
# Recall    : 0.9303
# F1 Score  : 0.8174
# F2 Score  : 0.8816
# Best Threshold  : 0.13999999999999999
# TP: 1121, TN: 1400, FP: 417, FN: 84
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.77      0.85      1817
#            1       0.73      0.93      0.82      1205
#
#     accuracy                           0.83      3022
#    macro avg       0.84      0.85      0.83      3022
# weighted avg       0.86      0.83      0.84      3022
#
# Model saved to models/svm\svm_under_normal_residual_cnn_features_32.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/normal_residual_cnn_features_64.csv...
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:484: FutureWarning: `BaseEstimator._check_n_features` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation._check_n_features` instead.
#   warnings.warn(
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:493: FutureWarning: `BaseEstimator._check_feature_names` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation._check_feature_names` instead.
#   warnings.warn(
# Accuracy  : 0.8412
# Precision : 0.7418
# Recall    : 0.9228
# F1 Score  : 0.8225
# F2 Score  : 0.8799
# Best Threshold  : 0.16999999999999998
# TP: 1112, TN: 1430, FP: 387, FN: 93
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.79      0.86      1817
#            1       0.74      0.92      0.82      1205
#
#     accuracy                           0.84      3022
#    macro avg       0.84      0.85      0.84      3022
# weighted avg       0.86      0.84      0.84      3022
#
# Model saved to models/svm\svm_under_normal_residual_cnn_features_64.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/normal_residual_cnn_features_128.csv...
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:484: FutureWarning: `BaseEstimator._check_n_features` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation._check_n_features` instead.
#   warnings.warn(
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:493: FutureWarning: `BaseEstimator._check_feature_names` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation._check_feature_names` instead.
#   warnings.warn(
# Accuracy  : 0.8104
# Precision : 0.6960
# Recall    : 0.9311
# F1 Score  : 0.7966
# F2 Score  : 0.8722
# Best Threshold  : 0.13999999999999999
# TP: 1122, TN: 1327, FP: 490, FN: 83
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.73      0.82      1817
#            1       0.70      0.93      0.80      1205
#
#     accuracy                           0.81      3022
#    macro avg       0.82      0.83      0.81      3022
# weighted avg       0.84      0.81      0.81      3022
#
# Model saved to models/svm\svm_under_normal_residual_cnn_features_128.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/normal_residual_cnn_features_256.csv...
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:484: FutureWarning: `BaseEstimator._check_n_features` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation._check_n_features` instead.
#   warnings.warn(
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:493: FutureWarning: `BaseEstimator._check_feature_names` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation._check_feature_names` instead.
#   warnings.warn(
# Accuracy  : 0.8028
# Precision : 0.6829
# Recall    : 0.9436
# F1 Score  : 0.7923
# F2 Score  : 0.8766
# Best Threshold  : 0.13
# TP: 1137, TN: 1289, FP: 528, FN: 68
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.95      0.71      0.81      1817
#            1       0.68      0.94      0.79      1205
#
#     accuracy                           0.80      3022
#    macro avg       0.82      0.83      0.80      3022
# weighted avg       0.84      0.80      0.80      3022
#
# Model saved to models/svm\svm_under_normal_residual_cnn_features_256.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/over_sampled_residual_cnn_features_32.csv...
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:484: FutureWarning: `BaseEstimator._check_n_features` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation._check_n_features` instead.
#   warnings.warn(
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:493: FutureWarning: `BaseEstimator._check_feature_names` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation._check_feature_names` instead.
#   warnings.warn(
# Accuracy  : 0.8365
# Precision : 0.7257
# Recall    : 0.9485
# F1 Score  : 0.8223
# F2 Score  : 0.8937
# Best Threshold  : 0.1
# TP: 1143, TN: 1385, FP: 432, FN: 62
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.96      0.76      0.85      1817
#            1       0.73      0.95      0.82      1205
#
#     accuracy                           0.84      3022
#    macro avg       0.84      0.86      0.84      3022
# weighted avg       0.86      0.84      0.84      3022
#
# Model saved to models/svm\svm_under_over_sampled_residual_cnn_features_32.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/over_sampled_residual_cnn_features_64.csv...
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:484: FutureWarning: `BaseEstimator._check_n_features` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation._check_n_features` instead.
#   warnings.warn(
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:493: FutureWarning: `BaseEstimator._check_feature_names` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation._check_feature_names` instead.
#   warnings.warn(
# Accuracy  : 0.8319
# Precision : 0.7270
# Recall    : 0.9261
# F1 Score  : 0.8146
# F2 Score  : 0.8780
# Best Threshold  : 0.16999999999999998
# TP: 1116, TN: 1398, FP: 419, FN: 89
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.77      0.85      1817
#            1       0.73      0.93      0.81      1205
#
#     accuracy                           0.83      3022
#    macro avg       0.83      0.85      0.83      3022
# weighted avg       0.86      0.83      0.83      3022
#
# Model saved to models/svm\svm_under_over_sampled_residual_cnn_features_64.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/over_sampled_residual_cnn_features_128.csv...
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:484: FutureWarning: `BaseEstimator._check_n_features` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation._check_n_features` instead.
#   warnings.warn(
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:493: FutureWarning: `BaseEstimator._check_feature_names` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation._check_feature_names` instead.
#   warnings.warn(
# Accuracy  : 0.8246
# Precision : 0.7127
# Recall    : 0.9386
# F1 Score  : 0.8102
# F2 Score  : 0.8826
# Best Threshold  : 0.13
# TP: 1131, TN: 1361, FP: 456, FN: 74
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.95      0.75      0.84      1817
#            1       0.71      0.94      0.81      1205
#
#     accuracy                           0.82      3022
#    macro avg       0.83      0.84      0.82      3022
# weighted avg       0.85      0.82      0.83      3022
#
# Model saved to models/svm\svm_under_over_sampled_residual_cnn_features_128.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/over_sampled_residual_cnn_features_256.csv...
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:484: FutureWarning: `BaseEstimator._check_n_features` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation._check_n_features` instead.
#   warnings.warn(
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:493: FutureWarning: `BaseEstimator._check_feature_names` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation._check_feature_names` instead.
#   warnings.warn(
# Accuracy  : 0.8226
# Precision : 0.7102
# Recall    : 0.9378
# F1 Score  : 0.8083
# F2 Score  : 0.8813
# Best Threshold  : 0.13999999999999999
# TP: 1130, TN: 1356, FP: 461, FN: 75
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.95      0.75      0.83      1817
#            1       0.71      0.94      0.81      1205
#
#     accuracy                           0.82      3022
#    macro avg       0.83      0.84      0.82      3022
# weighted avg       0.85      0.82      0.82      3022
#
# Model saved to models/svm\svm_under_over_sampled_residual_cnn_features_256.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/under_sampled_residual_cnn_features_32.csv...
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:484: FutureWarning: `BaseEstimator._check_n_features` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation._check_n_features` instead.
#   warnings.warn(
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:493: FutureWarning: `BaseEstimator._check_feature_names` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation._check_feature_names` instead.
#   warnings.warn(
# Accuracy  : 0.7932
# Precision : 0.6726
# Recall    : 0.9378
# F1 Score  : 0.7834
# F2 Score  : 0.8692
# Best Threshold  : 0.13999999999999999
# TP: 1130, TN: 1267, FP: 550, FN: 75
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.70      0.80      1817
#            1       0.67      0.94      0.78      1205
#
#     accuracy                           0.79      3022
#    macro avg       0.81      0.82      0.79      3022
# weighted avg       0.84      0.79      0.79      3022
#
# Model saved to models/svm\svm_under_under_sampled_residual_cnn_features_32.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/under_sampled_residual_cnn_features_64.csv...
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:484: FutureWarning: `BaseEstimator._check_n_features` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation._check_n_features` instead.
#   warnings.warn(
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:493: FutureWarning: `BaseEstimator._check_feature_names` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation._check_feature_names` instead.
#   warnings.warn(
# Accuracy  : 0.8084
# Precision : 0.6918
# Recall    : 0.9369
# F1 Score  : 0.7959
# F2 Score  : 0.8749
# Best Threshold  : 0.13
# TP: 1129, TN: 1314, FP: 503, FN: 76
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.95      0.72      0.82      1817
#            1       0.69      0.94      0.80      1205
#
#     accuracy                           0.81      3022
#    macro avg       0.82      0.83      0.81      3022
# weighted avg       0.84      0.81      0.81      3022
#
# Model saved to models/svm\svm_under_under_sampled_residual_cnn_features_64.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/under_sampled_residual_cnn_features_128.csv...
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:484: FutureWarning: `BaseEstimator._check_n_features` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation._check_n_features` instead.
#   warnings.warn(
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:493: FutureWarning: `BaseEstimator._check_feature_names` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation._check_feature_names` instead.
#   warnings.warn(
# Accuracy  : 0.8250
# Precision : 0.7139
# Recall    : 0.9361
# F1 Score  : 0.8101
# F2 Score  : 0.8812
# Best Threshold  : 0.13
# TP: 1128, TN: 1365, FP: 452, FN: 77
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.95      0.75      0.84      1817
#            1       0.71      0.94      0.81      1205
#
#     accuracy                           0.82      3022
#    macro avg       0.83      0.84      0.82      3022
# weighted avg       0.85      0.82      0.83      3022
#
# Model saved to models/svm\svm_under_under_sampled_residual_cnn_features_128.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/under_sampled_residual_cnn_features_256.csv...
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:484: FutureWarning: `BaseEstimator._check_n_features` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation._check_n_features` instead.
#   warnings.warn(
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:493: FutureWarning: `BaseEstimator._check_feature_names` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation._check_feature_names` instead.
#   warnings.warn(
# Accuracy  : 0.8375
# Precision : 0.7349
# Recall    : 0.9270
# F1 Score  : 0.8198
# F2 Score  : 0.8809
# Best Threshold  : 0.14999999999999997
# TP: 1117, TN: 1414, FP: 403, FN: 88
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.78      0.85      1817
#            1       0.73      0.93      0.82      1205
#
#     accuracy                           0.84      3022
#    macro avg       0.84      0.85      0.84      3022
# weighted avg       0.86      0.84      0.84      3022
#
# Model saved to models/svm\svm_under_under_sampled_residual_cnn_features_256.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/weighted_residual_cnn_features_32.csv...
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:484: FutureWarning: `BaseEstimator._check_n_features` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation._check_n_features` instead.
#   warnings.warn(
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:493: FutureWarning: `BaseEstimator._check_feature_names` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation._check_feature_names` instead.
#   warnings.warn(
# Accuracy  : 0.8312
# Precision : 0.7215
# Recall    : 0.9394
# F1 Score  : 0.8161
# F2 Score  : 0.8859
# Best Threshold  : 0.13
# TP: 1132, TN: 1380, FP: 437, FN: 73
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.95      0.76      0.84      1817
#            1       0.72      0.94      0.82      1205
#
#     accuracy                           0.83      3022
#    macro avg       0.84      0.85      0.83      3022
# weighted avg       0.86      0.83      0.83      3022
#
# Model saved to models/svm\svm_under_weighted_residual_cnn_features_32.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/weighted_residual_cnn_features_64.csv...
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:484: FutureWarning: `BaseEstimator._check_n_features` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation._check_n_features` instead.
#   warnings.warn(
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:493: FutureWarning: `BaseEstimator._check_feature_names` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation._check_feature_names` instead.
#   warnings.warn(
# Accuracy  : 0.8147
# Precision : 0.7058
# Recall    : 0.9178
# F1 Score  : 0.7980
# F2 Score  : 0.8658
# Best Threshold  : 0.15999999999999998
# TP: 1106, TN: 1356, FP: 461, FN: 99
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.93      0.75      0.83      1817
#            1       0.71      0.92      0.80      1205
#
#     accuracy                           0.81      3022
#    macro avg       0.82      0.83      0.81      3022
# weighted avg       0.84      0.81      0.82      3022
#
# Model saved to models/svm\svm_under_weighted_residual_cnn_features_64.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/weighted_residual_cnn_features_128.csv...
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:484: FutureWarning: `BaseEstimator._check_n_features` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation._check_n_features` instead.
#   warnings.warn(
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:493: FutureWarning: `BaseEstimator._check_feature_names` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation._check_feature_names` instead.
#   warnings.warn(
# Accuracy  : 0.8544
# Precision : 0.7643
# Recall    : 0.9178
# F1 Score  : 0.8341
# F2 Score  : 0.8824
# Best Threshold  : 0.20999999999999996
# TP: 1106, TN: 1476, FP: 341, FN: 99
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.81      0.87      1817
#            1       0.76      0.92      0.83      1205
#
#     accuracy                           0.85      3022
#    macro avg       0.85      0.87      0.85      3022
# weighted avg       0.87      0.85      0.86      3022
#
# Model saved to models/svm\svm_under_weighted_residual_cnn_features_128.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/weighted_residual_cnn_features_256.csv...
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:484: FutureWarning: `BaseEstimator._check_n_features` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation._check_n_features` instead.
#   warnings.warn(
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:493: FutureWarning: `BaseEstimator._check_feature_names` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation._check_feature_names` instead.
#   warnings.warn(
# Accuracy  : 0.8170
# Precision : 0.7050
# Recall    : 0.9303
# F1 Score  : 0.8021
# F2 Score  : 0.8744
# Best Threshold  : 0.13999999999999999
# TP: 1121, TN: 1348, FP: 469, FN: 84
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.74      0.83      1817
#            1       0.71      0.93      0.80      1205
#
#     accuracy                           0.82      3022
#    macro avg       0.82      0.84      0.82      3022
# weighted avg       0.85      0.82      0.82      3022
#
# Model saved to models/svm\svm_under_weighted_residual_cnn_features_256.joblib
# Results saved to results_summary.csv

# %% [markdown]
# ### Over-Sampled

# %%
train(residual_dataset_paths, "svm", "over")
# Out:
# Processing ../feature-extraction/residual_cnn/datasets/normal_residual_cnn_features_32.csv...
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# Accuracy  : 0.8206
# Precision : 0.7058
# Recall    : 0.9436
# F1 Score  : 0.8075
# F2 Score  : 0.8840
# Best Threshold  : 0.12
# TP: 1137, TN: 1343, FP: 474, FN: 68
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.95      0.74      0.83      1817
#            1       0.71      0.94      0.81      1205
#
#     accuracy                           0.82      3022
#    macro avg       0.83      0.84      0.82      3022
# weighted avg       0.85      0.82      0.82      3022
#
# Model saved to models/svm\svm_over_normal_residual_cnn_features_32.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/normal_residual_cnn_features_64.csv...
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# Accuracy  : 0.8441
# Precision : 0.7473
# Recall    : 0.9203
# F1 Score  : 0.8248
# F2 Score  : 0.8796
# Best Threshold  : 0.16999999999999998
# TP: 1109, TN: 1442, FP: 375, FN: 96
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.79      0.86      1817
#            1       0.75      0.92      0.82      1205
#
#     accuracy                           0.84      3022
#    macro avg       0.84      0.86      0.84      3022
# weighted avg       0.86      0.84      0.85      3022
#
# Model saved to models/svm\svm_over_normal_residual_cnn_features_64.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/normal_residual_cnn_features_128.csv...
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# Accuracy  : 0.8028
# Precision : 0.6820
# Recall    : 0.9469
# F1 Score  : 0.7929
# F2 Score  : 0.8786
# Best Threshold  : 0.13
# TP: 1141, TN: 1285, FP: 532, FN: 64
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.95      0.71      0.81      1817
#            1       0.68      0.95      0.79      1205
#
#     accuracy                           0.80      3022
#    macro avg       0.82      0.83      0.80      3022
# weighted avg       0.84      0.80      0.80      3022
#
# Model saved to models/svm\svm_over_normal_residual_cnn_features_128.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/normal_residual_cnn_features_256.csv...
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# Accuracy  : 0.8087
# Precision : 0.6901
# Recall    : 0.9444
# F1 Score  : 0.7975
# F2 Score  : 0.8796
# Best Threshold  : 0.13
# TP: 1138, TN: 1306, FP: 511, FN: 67
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.95      0.72      0.82      1817
#            1       0.69      0.94      0.80      1205
#
#     accuracy                           0.81      3022
#    macro avg       0.82      0.83      0.81      3022
# weighted avg       0.85      0.81      0.81      3022
#
# Model saved to models/svm\svm_over_normal_residual_cnn_features_256.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/over_sampled_residual_cnn_features_32.csv...
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# Accuracy  : 0.8392
# Precision : 0.7315
# Recall    : 0.9427
# F1 Score  : 0.8238
# F2 Score  : 0.8913
# Best Threshold  : 0.1
# TP: 1136, TN: 1400, FP: 417, FN: 69
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.95      0.77      0.85      1817
#            1       0.73      0.94      0.82      1205
#
#     accuracy                           0.84      3022
#    macro avg       0.84      0.86      0.84      3022
# weighted avg       0.86      0.84      0.84      3022
#
# Model saved to models/svm\svm_over_over_sampled_residual_cnn_features_32.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/over_sampled_residual_cnn_features_64.csv...
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# Accuracy  : 0.8302
# Precision : 0.7232
# Recall    : 0.9303
# F1 Score  : 0.8138
# F2 Score  : 0.8799
# Best Threshold  : 0.15999999999999998
# TP: 1121, TN: 1388, FP: 429, FN: 84
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.76      0.84      1817
#            1       0.72      0.93      0.81      1205
#
#     accuracy                           0.83      3022
#    macro avg       0.83      0.85      0.83      3022
# weighted avg       0.86      0.83      0.83      3022
#
# Model saved to models/svm\svm_over_over_sampled_residual_cnn_features_64.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/over_sampled_residual_cnn_features_128.csv...
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# Accuracy  : 0.8216
# Precision : 0.7071
# Recall    : 0.9436
# F1 Score  : 0.8084
# F2 Score  : 0.8844
# Best Threshold  : 0.12
# TP: 1137, TN: 1346, FP: 471, FN: 68
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.95      0.74      0.83      1817
#            1       0.71      0.94      0.81      1205
#
#     accuracy                           0.82      3022
#    macro avg       0.83      0.84      0.82      3022
# weighted avg       0.85      0.82      0.82      3022
#
# Model saved to models/svm\svm_over_over_sampled_residual_cnn_features_128.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/over_sampled_residual_cnn_features_256.csv...
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# Accuracy  : 0.8170
# Precision : 0.7027
# Recall    : 0.9378
# F1 Score  : 0.8034
# F2 Score  : 0.8790
# Best Threshold  : 0.13
# TP: 1130, TN: 1339, FP: 478, FN: 75
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.95      0.74      0.83      1817
#            1       0.70      0.94      0.80      1205
#
#     accuracy                           0.82      3022
#    macro avg       0.82      0.84      0.82      3022
# weighted avg       0.85      0.82      0.82      3022
#
# Model saved to models/svm\svm_over_over_sampled_residual_cnn_features_256.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/under_sampled_residual_cnn_features_32.csv...
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# Accuracy  : 0.8008
# Precision : 0.6822
# Recall    : 0.9369
# F1 Score  : 0.7895
# F2 Score  : 0.8718
# Best Threshold  : 0.13999999999999999
# TP: 1129, TN: 1291, FP: 526, FN: 76
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.71      0.81      1817
#            1       0.68      0.94      0.79      1205
#
#     accuracy                           0.80      3022
#    macro avg       0.81      0.82      0.80      3022
# weighted avg       0.84      0.80      0.80      3022
#
# Model saved to models/svm\svm_over_under_sampled_residual_cnn_features_32.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/under_sampled_residual_cnn_features_64.csv...
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# Accuracy  : 0.8266
# Precision : 0.7198
# Recall    : 0.9253
# F1 Score  : 0.8097
# F2 Score  : 0.8753
# Best Threshold  : 0.13999999999999999
# TP: 1115, TN: 1383, FP: 434, FN: 90
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.76      0.84      1817
#            1       0.72      0.93      0.81      1205
#
#     accuracy                           0.83      3022
#    macro avg       0.83      0.84      0.83      3022
# weighted avg       0.85      0.83      0.83      3022
#
# Model saved to models/svm\svm_over_under_sampled_residual_cnn_features_64.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/under_sampled_residual_cnn_features_128.csv...
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# Accuracy  : 0.8210
# Precision : 0.7080
# Recall    : 0.9378
# F1 Score  : 0.8069
# F2 Score  : 0.8806
# Best Threshold  : 0.12
# TP: 1130, TN: 1351, FP: 466, FN: 75
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.95      0.74      0.83      1817
#            1       0.71      0.94      0.81      1205
#
#     accuracy                           0.82      3022
#    macro avg       0.83      0.84      0.82      3022
# weighted avg       0.85      0.82      0.82      3022
#
# Model saved to models/svm\svm_over_under_sampled_residual_cnn_features_128.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/under_sampled_residual_cnn_features_256.csv...
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# Accuracy  : 0.8309
# Precision : 0.7233
# Recall    : 0.9328
# F1 Score  : 0.8148
# F2 Score  : 0.8817
# Best Threshold  : 0.13
# TP: 1124, TN: 1387, FP: 430, FN: 81
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.76      0.84      1817
#            1       0.72      0.93      0.81      1205
#
#     accuracy                           0.83      3022
#    macro avg       0.83      0.85      0.83      3022
# weighted avg       0.86      0.83      0.83      3022
#
# Model saved to models/svm\svm_over_under_sampled_residual_cnn_features_256.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/weighted_residual_cnn_features_32.csv...
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# Accuracy  : 0.8269
# Precision : 0.7142
# Recall    : 0.9436
# F1 Score  : 0.8130
# F2 Score  : 0.8866
# Best Threshold  : 0.12
# TP: 1137, TN: 1362, FP: 455, FN: 68
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.95      0.75      0.84      1817
#            1       0.71      0.94      0.81      1205
#
#     accuracy                           0.83      3022
#    macro avg       0.83      0.85      0.83      3022
# weighted avg       0.86      0.83      0.83      3022
#
# Model saved to models/svm\svm_over_weighted_residual_cnn_features_32.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/weighted_residual_cnn_features_64.csv...
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# Accuracy  : 0.8140
# Precision : 0.7041
# Recall    : 0.9203
# F1 Score  : 0.7978
# F2 Score  : 0.8671
# Best Threshold  : 0.14999999999999997
# TP: 1109, TN: 1351, FP: 466, FN: 96
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.93      0.74      0.83      1817
#            1       0.70      0.92      0.80      1205
#
#     accuracy                           0.81      3022
#    macro avg       0.82      0.83      0.81      3022
# weighted avg       0.84      0.81      0.82      3022
#
# Model saved to models/svm\svm_over_weighted_residual_cnn_features_64.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/weighted_residual_cnn_features_128.csv...
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# Accuracy  : 0.8220
# Precision : 0.7086
# Recall    : 0.9402
# F1 Score  : 0.8081
# F2 Score  : 0.8825
# Best Threshold  : 0.13
# TP: 1133, TN: 1351, FP: 466, FN: 72
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.95      0.74      0.83      1817
#            1       0.71      0.94      0.81      1205
#
#     accuracy                           0.82      3022
#    macro avg       0.83      0.84      0.82      3022
# weighted avg       0.85      0.82      0.82      3022
#
# Model saved to models/svm\svm_over_weighted_residual_cnn_features_128.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/weighted_residual_cnn_features_256.csv...
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# Accuracy  : 0.8322
# Precision : 0.7290
# Recall    : 0.9220
# F1 Score  : 0.8142
# F2 Score  : 0.8756
# Best Threshold  : 0.14999999999999997
# TP: 1111, TN: 1404, FP: 413, FN: 94
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.77      0.85      1817
#            1       0.73      0.92      0.81      1205
#
#     accuracy                           0.83      3022
#    macro avg       0.83      0.85      0.83      3022
# weighted avg       0.85      0.83      0.83      3022
#
# Model saved to models/svm\svm_over_weighted_residual_cnn_features_256.joblib
# Results saved to results_summary.csv

# %% [markdown]
# ### Weighted

# %%
train(residual_dataset_paths, "svm", "weighted")
# Out:
# Processing ../feature-extraction/residual_cnn/datasets/normal_residual_cnn_features_32.csv...
# Accuracy  : 0.8458
# Precision : 0.7488
# Recall    : 0.9228
# F1 Score  : 0.8268
# F2 Score  : 0.8818
# Best Threshold  : 0.11
# TP: 1112, TN: 1444, FP: 373, FN: 93
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.79      0.86      1817
#            1       0.75      0.92      0.83      1205
#
#     accuracy                           0.85      3022
#    macro avg       0.84      0.86      0.84      3022
# weighted avg       0.86      0.85      0.85      3022
#
# Model saved to models/svm\svm_weighted_normal_residual_cnn_features_32.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/normal_residual_cnn_features_64.csv...
# Accuracy  : 0.8451
# Precision : 0.7485
# Recall    : 0.9212
# F1 Score  : 0.8259
# F2 Score  : 0.8805
# Best Threshold  : 0.12
# TP: 1110, TN: 1444, FP: 373, FN: 95
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.79      0.86      1817
#            1       0.75      0.92      0.83      1205
#
#     accuracy                           0.85      3022
#    macro avg       0.84      0.86      0.84      3022
# weighted avg       0.86      0.85      0.85      3022
#
# Model saved to models/svm\svm_weighted_normal_residual_cnn_features_64.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/normal_residual_cnn_features_128.csv...
# Accuracy  : 0.8183
# Precision : 0.7073
# Recall    : 0.9286
# F1 Score  : 0.8030
# F2 Score  : 0.8739
# Best Threshold  : 0.1
# TP: 1119, TN: 1354, FP: 463, FN: 86
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.75      0.83      1817
#            1       0.71      0.93      0.80      1205
#
#     accuracy                           0.82      3022
#    macro avg       0.82      0.84      0.82      3022
# weighted avg       0.85      0.82      0.82      3022
#
# Model saved to models/svm\svm_weighted_normal_residual_cnn_features_128.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/normal_residual_cnn_features_256.csv...
# Accuracy  : 0.8273
# Precision : 0.7191
# Recall    : 0.9303
# F1 Score  : 0.8111
# F2 Score  : 0.8787
# Best Threshold  : 0.1
# TP: 1121, TN: 1379, FP: 438, FN: 84
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.76      0.84      1817
#            1       0.72      0.93      0.81      1205
#
#     accuracy                           0.83      3022
#    macro avg       0.83      0.84      0.83      3022
# weighted avg       0.85      0.83      0.83      3022
#
# Model saved to models/svm\svm_weighted_normal_residual_cnn_features_256.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/over_sampled_residual_cnn_features_32.csv...
# Accuracy  : 0.8574
# Precision : 0.7673
# Recall    : 0.9220
# F1 Score  : 0.8375
# F2 Score  : 0.8862
# Best Threshold  : 0.1
# TP: 1111, TN: 1480, FP: 337, FN: 94
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.81      0.87      1817
#            1       0.77      0.92      0.84      1205
#
#     accuracy                           0.86      3022
#    macro avg       0.85      0.87      0.86      3022
# weighted avg       0.87      0.86      0.86      3022
#
# Model saved to models/svm\svm_weighted_over_sampled_residual_cnn_features_32.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/over_sampled_residual_cnn_features_64.csv...
# Accuracy  : 0.8342
# Precision : 0.7304
# Recall    : 0.9261
# F1 Score  : 0.8167
# F2 Score  : 0.8790
# Best Threshold  : 0.12
# TP: 1116, TN: 1405, FP: 412, FN: 89
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.77      0.85      1817
#            1       0.73      0.93      0.82      1205
#
#     accuracy                           0.83      3022
#    macro avg       0.84      0.85      0.83      3022
# weighted avg       0.86      0.83      0.84      3022
#
# Model saved to models/svm\svm_weighted_over_sampled_residual_cnn_features_64.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/over_sampled_residual_cnn_features_128.csv...
# Accuracy  : 0.8319
# Precision : 0.7259
# Recall    : 0.9295
# F1 Score  : 0.8151
# F2 Score  : 0.8801
# Best Threshold  : 0.1
# TP: 1120, TN: 1394, FP: 423, FN: 85
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.77      0.85      1817
#            1       0.73      0.93      0.82      1205
#
#     accuracy                           0.83      3022
#    macro avg       0.83      0.85      0.83      3022
# weighted avg       0.86      0.83      0.83      3022
#
# Model saved to models/svm\svm_weighted_over_sampled_residual_cnn_features_128.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/over_sampled_residual_cnn_features_256.csv...
# Accuracy  : 0.8332
# Precision : 0.7286
# Recall    : 0.9270
# F1 Score  : 0.8159
# F2 Score  : 0.8791
# Best Threshold  : 0.11
# TP: 1117, TN: 1401, FP: 416, FN: 88
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.77      0.85      1817
#            1       0.73      0.93      0.82      1205
#
#     accuracy                           0.83      3022
#    macro avg       0.83      0.85      0.83      3022
# weighted avg       0.86      0.83      0.83      3022
#
# Model saved to models/svm\svm_weighted_over_sampled_residual_cnn_features_256.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/under_sampled_residual_cnn_features_32.csv...
# Accuracy  : 0.8005
# Precision : 0.6822
# Recall    : 0.9353
# F1 Score  : 0.7889
# F2 Score  : 0.8707
# Best Threshold  : 0.1
# TP: 1127, TN: 1292, FP: 525, FN: 78
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.71      0.81      1817
#            1       0.68      0.94      0.79      1205
#
#     accuracy                           0.80      3022
#    macro avg       0.81      0.82      0.80      3022
# weighted avg       0.84      0.80      0.80      3022
#
# Model saved to models/svm\svm_weighted_under_sampled_residual_cnn_features_32.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/under_sampled_residual_cnn_features_64.csv...
# Accuracy  : 0.8269
# Precision : 0.7203
# Recall    : 0.9253
# F1 Score  : 0.8100
# F2 Score  : 0.8755
# Best Threshold  : 0.1
# TP: 1115, TN: 1384, FP: 433, FN: 90
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.76      0.84      1817
#            1       0.72      0.93      0.81      1205
#
#     accuracy                           0.83      3022
#    macro avg       0.83      0.84      0.83      3022
# weighted avg       0.85      0.83      0.83      3022
#
# Model saved to models/svm\svm_weighted_under_sampled_residual_cnn_features_64.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/under_sampled_residual_cnn_features_128.csv...
# Accuracy  : 0.8355
# Precision : 0.7323
# Recall    : 0.9261
# F1 Score  : 0.8179
# F2 Score  : 0.8796
# Best Threshold  : 0.1
# TP: 1116, TN: 1409, FP: 408, FN: 89
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.78      0.85      1817
#            1       0.73      0.93      0.82      1205
#
#     accuracy                           0.84      3022
#    macro avg       0.84      0.85      0.83      3022
# weighted avg       0.86      0.84      0.84      3022
#
# Model saved to models/svm\svm_weighted_under_sampled_residual_cnn_features_128.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/under_sampled_residual_cnn_features_256.csv...
# Accuracy  : 0.8359
# Precision : 0.7322
# Recall    : 0.9278
# F1 Score  : 0.8184
# F2 Score  : 0.8807
# Best Threshold  : 0.1
# TP: 1118, TN: 1408, FP: 409, FN: 87
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.77      0.85      1817
#            1       0.73      0.93      0.82      1205
#
#     accuracy                           0.84      3022
#    macro avg       0.84      0.85      0.83      3022
# weighted avg       0.86      0.84      0.84      3022
#
# Model saved to models/svm\svm_weighted_under_sampled_residual_cnn_features_256.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/weighted_residual_cnn_features_32.csv...
# Accuracy  : 0.8412
# Precision : 0.7390
# Recall    : 0.9303
# F1 Score  : 0.8237
# F2 Score  : 0.8845
# Best Threshold  : 0.1
# TP: 1121, TN: 1421, FP: 396, FN: 84
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.78      0.86      1817
#            1       0.74      0.93      0.82      1205
#
#     accuracy                           0.84      3022
#    macro avg       0.84      0.86      0.84      3022
# weighted avg       0.86      0.84      0.84      3022
#
# Model saved to models/svm\svm_weighted_weighted_residual_cnn_features_32.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/weighted_residual_cnn_features_64.csv...
# Accuracy  : 0.8160
# Precision : 0.7079
# Recall    : 0.9170
# F1 Score  : 0.7990
# F2 Score  : 0.8659
# Best Threshold  : 0.11
# TP: 1105, TN: 1361, FP: 456, FN: 100
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.93      0.75      0.83      1817
#            1       0.71      0.92      0.80      1205
#
#     accuracy                           0.82      3022
#    macro avg       0.82      0.83      0.81      3022
# weighted avg       0.84      0.82      0.82      3022
#
# Model saved to models/svm\svm_weighted_weighted_residual_cnn_features_64.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/weighted_residual_cnn_features_128.csv...
# Accuracy  : 0.8518
# Precision : 0.7601
# Recall    : 0.9178
# F1 Score  : 0.8316
# F2 Score  : 0.8813
# Best Threshold  : 0.13999999999999999
# TP: 1106, TN: 1468, FP: 349, FN: 99
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.81      0.87      1817
#            1       0.76      0.92      0.83      1205
#
#     accuracy                           0.85      3022
#    macro avg       0.85      0.86      0.85      3022
# weighted avg       0.87      0.85      0.85      3022
#
# Model saved to models/svm\svm_weighted_weighted_residual_cnn_features_128.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/weighted_residual_cnn_features_256.csv...
# Accuracy  : 0.8250
# Precision : 0.7169
# Recall    : 0.9270
# F1 Score  : 0.8085
# F2 Score  : 0.8757
# Best Threshold  : 0.1
# TP: 1117, TN: 1376, FP: 441, FN: 88
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.76      0.84      1817
#            1       0.72      0.93      0.81      1205
#
#     accuracy                           0.82      3022
#    macro avg       0.83      0.84      0.82      3022
# weighted avg       0.85      0.82      0.83      3022
#
# Model saved to models/svm\svm_weighted_weighted_residual_cnn_features_256.joblib
# Results saved to results_summary.csv

# %% [markdown]
# ## 1D CNN

# %% [markdown]
# ### Datasets

# %%
cnn_1d_dataset_paths = [
    "../feature-extraction/1d_cnn/datasets/normal_1d_cnn_features_32.csv",
    "../feature-extraction/1d_cnn/datasets/normal_1d_cnn_features_64.csv",
    "../feature-extraction/1d_cnn/datasets/normal_1d_cnn_features_128.csv",
    "../feature-extraction/1d_cnn/datasets/normal_1d_cnn_features_256.csv",
    "../feature-extraction/1d_cnn/datasets/over_sampled_1d_cnn_features_32.csv",
    "../feature-extraction/1d_cnn/datasets/over_sampled_1d_cnn_features_64.csv",
    "../feature-extraction/1d_cnn/datasets/over_sampled_1d_cnn_features_128.csv",
    "../feature-extraction/1d_cnn/datasets/over_sampled_1d_cnn_features_256.csv",
    "../feature-extraction/1d_cnn/datasets/under_sampled_1d_cnn_features_32.csv",
    "../feature-extraction/1d_cnn/datasets/under_sampled_1d_cnn_features_64.csv",
    "../feature-extraction/1d_cnn/datasets/under_sampled_1d_cnn_features_128.csv",
    "../feature-extraction/1d_cnn/datasets/under_sampled_1d_cnn_features_256.csv",
    "../feature-extraction/1d_cnn/datasets/weighted_1d_cnn_features_32.csv",
    "../feature-extraction/1d_cnn/datasets/weighted_1d_cnn_features_64.csv",
    "../feature-extraction/1d_cnn/datasets/weighted_1d_cnn_features_128.csv",
    "../feature-extraction/1d_cnn/datasets/weighted_1d_cnn_features_256.csv",

]

# %% [markdown]
# ### Imbalanced

# %%
train(cnn_1d_dataset_paths, "svm", "normal")
# Out:
# Processing ../feature-extraction/1d_cnn/datasets/normal_1d_cnn_features_32.csv...
# Accuracy  : 0.8627
# Precision : 0.7765
# Recall    : 0.9201
# F1 Score  : 0.8422
# F2 Score  : 0.8873
# Best Threshold  : 0.1
# TP: 1105, TN: 1496, FP: 318, FN: 96
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.82      0.88      1814
#            1       0.78      0.92      0.84      1201
#
#     accuracy                           0.86      3015
#    macro avg       0.86      0.87      0.86      3015
# weighted avg       0.87      0.86      0.86      3015
#
# Model saved to models/svm\svm_normal_normal_1d_cnn_features_32.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/1d_cnn/datasets/normal_1d_cnn_features_64.csv...
# Accuracy  : 0.8839
# Precision : 0.8241
# Recall    : 0.9009
# F1 Score  : 0.8608
# F2 Score  : 0.8844
# Best Threshold  : 0.11
# TP: 1082, TN: 1583, FP: 231, FN: 119
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.93      0.87      0.90      1814
#            1       0.82      0.90      0.86      1201
#
#     accuracy                           0.88      3015
#    macro avg       0.88      0.89      0.88      3015
# weighted avg       0.89      0.88      0.88      3015
#
# Model saved to models/svm\svm_normal_normal_1d_cnn_features_64.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/1d_cnn/datasets/normal_1d_cnn_features_128.csv...
# Accuracy  : 0.8816
# Precision : 0.8187
# Recall    : 0.9026
# F1 Score  : 0.8586
# F2 Score  : 0.8845
# Best Threshold  : 0.11
# TP: 1084, TN: 1574, FP: 240, FN: 117
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.93      0.87      0.90      1814
#            1       0.82      0.90      0.86      1201
#
#     accuracy                           0.88      3015
#    macro avg       0.87      0.89      0.88      3015
# weighted avg       0.89      0.88      0.88      3015
#
# Model saved to models/svm\svm_normal_normal_1d_cnn_features_128.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/1d_cnn/datasets/normal_1d_cnn_features_256.csv...
# Accuracy  : 0.8166
# Precision : 0.7080
# Recall    : 0.9184
# F1 Score  : 0.7996
# F2 Score  : 0.8669
# Best Threshold  : 0.1
# TP: 1103, TN: 1359, FP: 455, FN: 98
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.93      0.75      0.83      1814
#            1       0.71      0.92      0.80      1201
#
#     accuracy                           0.82      3015
#    macro avg       0.82      0.83      0.82      3015
# weighted avg       0.84      0.82      0.82      3015
#
# Model saved to models/svm\svm_normal_normal_1d_cnn_features_256.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/1d_cnn/datasets/over_sampled_1d_cnn_features_32.csv...
# Accuracy  : 0.8713
# Precision : 0.7948
# Recall    : 0.9126
# F1 Score  : 0.8496
# F2 Score  : 0.8863
# Best Threshold  : 0.1
# TP: 1096, TN: 1531, FP: 283, FN: 105
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.84      0.89      1814
#            1       0.79      0.91      0.85      1201
#
#     accuracy                           0.87      3015
#    macro avg       0.87      0.88      0.87      3015
# weighted avg       0.88      0.87      0.87      3015
#
# Model saved to models/svm\svm_normal_over_sampled_1d_cnn_features_32.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/1d_cnn/datasets/over_sampled_1d_cnn_features_64.csv...
# Accuracy  : 0.8713
# Precision : 0.7974
# Recall    : 0.9076
# F1 Score  : 0.8489
# F2 Score  : 0.8832
# Best Threshold  : 0.1
# TP: 1090, TN: 1537, FP: 277, FN: 111
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.93      0.85      0.89      1814
#            1       0.80      0.91      0.85      1201
#
#     accuracy                           0.87      3015
#    macro avg       0.87      0.88      0.87      3015
# weighted avg       0.88      0.87      0.87      3015
#
# Model saved to models/svm\svm_normal_over_sampled_1d_cnn_features_64.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/1d_cnn/datasets/over_sampled_1d_cnn_features_128.csv...
# Accuracy  : 0.8786
# Precision : 0.8104
# Recall    : 0.9076
# F1 Score  : 0.8562
# F2 Score  : 0.8863
# Best Threshold  : 0.1
# TP: 1090, TN: 1559, FP: 255, FN: 111
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.93      0.86      0.89      1814
#            1       0.81      0.91      0.86      1201
#
#     accuracy                           0.88      3015
#    macro avg       0.87      0.88      0.88      3015
# weighted avg       0.88      0.88      0.88      3015
#
# Model saved to models/svm\svm_normal_over_sampled_1d_cnn_features_128.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/1d_cnn/datasets/over_sampled_1d_cnn_features_256.csv...
# Accuracy  : 0.8677
# Precision : 0.7877
# Recall    : 0.9142
# F1 Score  : 0.8462
# F2 Score  : 0.8858
# Best Threshold  : 0.1
# TP: 1098, TN: 1518, FP: 296, FN: 103
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.84      0.88      1814
#            1       0.79      0.91      0.85      1201
#
#     accuracy                           0.87      3015
#    macro avg       0.86      0.88      0.87      3015
# weighted avg       0.88      0.87      0.87      3015
#
# Model saved to models/svm\svm_normal_over_sampled_1d_cnn_features_256.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/1d_cnn/datasets/under_sampled_1d_cnn_features_32.csv...
# Accuracy  : 0.8670
# Precision : 0.7903
# Recall    : 0.9067
# F1 Score  : 0.8445
# F2 Score  : 0.8808
# Best Threshold  : 0.1
# TP: 1089, TN: 1525, FP: 289, FN: 112
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.93      0.84      0.88      1814
#            1       0.79      0.91      0.84      1201
#
#     accuracy                           0.87      3015
#    macro avg       0.86      0.87      0.86      3015
# weighted avg       0.88      0.87      0.87      3015
#
# Model saved to models/svm\svm_normal_under_sampled_1d_cnn_features_32.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/1d_cnn/datasets/under_sampled_1d_cnn_features_64.csv...
# Accuracy  : 0.8627
# Precision : 0.7813
# Recall    : 0.9101
# F1 Score  : 0.8408
# F2 Score  : 0.8810
# Best Threshold  : 0.1
# TP: 1093, TN: 1508, FP: 306, FN: 108
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.93      0.83      0.88      1814
#            1       0.78      0.91      0.84      1201
#
#     accuracy                           0.86      3015
#    macro avg       0.86      0.87      0.86      3015
# weighted avg       0.87      0.86      0.86      3015
#
# Model saved to models/svm\svm_normal_under_sampled_1d_cnn_features_64.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/1d_cnn/datasets/under_sampled_1d_cnn_features_128.csv...
# Accuracy  : 0.8587
# Precision : 0.7742
# Recall    : 0.9109
# F1 Score  : 0.8370
# F2 Score  : 0.8798
# Best Threshold  : 0.1
# TP: 1094, TN: 1495, FP: 319, FN: 107
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.93      0.82      0.88      1814
#            1       0.77      0.91      0.84      1201
#
#     accuracy                           0.86      3015
#    macro avg       0.85      0.87      0.86      3015
# weighted avg       0.87      0.86      0.86      3015
#
# Model saved to models/svm\svm_normal_under_sampled_1d_cnn_features_128.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/1d_cnn/datasets/under_sampled_1d_cnn_features_256.csv...
# Accuracy  : 0.8683
# Precision : 0.7905
# Recall    : 0.9109
# F1 Score  : 0.8464
# F2 Score  : 0.8840
# Best Threshold  : 0.1
# TP: 1094, TN: 1524, FP: 290, FN: 107
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.93      0.84      0.88      1814
#            1       0.79      0.91      0.85      1201
#
#     accuracy                           0.87      3015
#    macro avg       0.86      0.88      0.87      3015
# weighted avg       0.88      0.87      0.87      3015
#
# Model saved to models/svm\svm_normal_under_sampled_1d_cnn_features_256.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/1d_cnn/datasets/weighted_1d_cnn_features_32.csv...
# Accuracy  : 0.8630
# Precision : 0.7814
# Recall    : 0.9109
# F1 Score  : 0.8412
# F2 Score  : 0.8817
# Best Threshold  : 0.1
# TP: 1094, TN: 1508, FP: 306, FN: 107
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.93      0.83      0.88      1814
#            1       0.78      0.91      0.84      1201
#
#     accuracy                           0.86      3015
#    macro avg       0.86      0.87      0.86      3015
# weighted avg       0.87      0.86      0.86      3015
#
# Model saved to models/svm\svm_normal_weighted_1d_cnn_features_32.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/1d_cnn/datasets/weighted_1d_cnn_features_64.csv...
# Accuracy  : 0.8557
# Precision : 0.7709
# Recall    : 0.9076
# F1 Score  : 0.8337
# F2 Score  : 0.8765
# Best Threshold  : 0.1
# TP: 1090, TN: 1490, FP: 324, FN: 111
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.93      0.82      0.87      1814
#            1       0.77      0.91      0.83      1201
#
#     accuracy                           0.86      3015
#    macro avg       0.85      0.86      0.85      3015
# weighted avg       0.87      0.86      0.86      3015
#
# Model saved to models/svm\svm_normal_weighted_1d_cnn_features_64.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/1d_cnn/datasets/weighted_1d_cnn_features_128.csv...
# Accuracy  : 0.8693
# Precision : 0.7965
# Recall    : 0.9026
# F1 Score  : 0.8462
# F2 Score  : 0.8792
# Best Threshold  : 0.1
# TP: 1084, TN: 1537, FP: 277, FN: 117
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.93      0.85      0.89      1814
#            1       0.80      0.90      0.85      1201
#
#     accuracy                           0.87      3015
#    macro avg       0.86      0.87      0.87      3015
# weighted avg       0.88      0.87      0.87      3015
#
# Model saved to models/svm\svm_normal_weighted_1d_cnn_features_128.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/1d_cnn/datasets/weighted_1d_cnn_features_256.csv...
# Accuracy  : 0.8700
# Precision : 0.7946
# Recall    : 0.9084
# F1 Score  : 0.8477
# F2 Score  : 0.8831
# Best Threshold  : 0.1
# TP: 1091, TN: 1532, FP: 282, FN: 110
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.93      0.84      0.89      1814
#            1       0.79      0.91      0.85      1201
#
#     accuracy                           0.87      3015
#    macro avg       0.86      0.88      0.87      3015
# weighted avg       0.88      0.87      0.87      3015
#
# Model saved to models/svm\svm_normal_weighted_1d_cnn_features_256.joblib
# Results saved to results_summary.csv

# %% [markdown]
# ### Under-Sampled

# %%
train(cnn_1d_dataset_paths, "svm", "under")
# Out:
# Processing ../feature-extraction/1d_cnn/datasets/normal_1d_cnn_features_32.csv...
# Accuracy  : 0.8643
# Precision : 0.7801
# Recall    : 0.9184
# F1 Score  : 0.8436
# F2 Score  : 0.8869
# Best Threshold  : 0.16999999999999998
# TP: 1103, TN: 1503, FP: 311, FN: 98
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.83      0.88      1814
#            1       0.78      0.92      0.84      1201
#
#     accuracy                           0.86      3015
#    macro avg       0.86      0.87      0.86      3015
# weighted avg       0.88      0.86      0.87      3015
#
# Model saved to models/svm\svm_under_normal_1d_cnn_features_32.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/1d_cnn/datasets/normal_1d_cnn_features_64.csv...
# Accuracy  : 0.8673
# Precision : 0.7842
# Recall    : 0.9201
# F1 Score  : 0.8467
# F2 Score  : 0.8893
# Best Threshold  : 0.13
# TP: 1105, TN: 1510, FP: 304, FN: 96
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.83      0.88      1814
#            1       0.78      0.92      0.85      1201
#
#     accuracy                           0.87      3015
#    macro avg       0.86      0.88      0.86      3015
# weighted avg       0.88      0.87      0.87      3015
#
# Model saved to models/svm\svm_under_normal_1d_cnn_features_64.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/1d_cnn/datasets/normal_1d_cnn_features_128.csv...
# Accuracy  : 0.8590
# Precision : 0.7650
# Recall    : 0.9326
# F1 Score  : 0.8405
# F2 Score  : 0.8934
# Best Threshold  : 0.12
# TP: 1120, TN: 1470, FP: 344, FN: 81
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.95      0.81      0.87      1814
#            1       0.77      0.93      0.84      1201
#
#     accuracy                           0.86      3015
#    macro avg       0.86      0.87      0.86      3015
# weighted avg       0.87      0.86      0.86      3015
#
# Model saved to models/svm\svm_under_normal_1d_cnn_features_128.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/1d_cnn/datasets/normal_1d_cnn_features_256.csv...
# Accuracy  : 0.8428
# Precision : 0.7509
# Recall    : 0.9059
# F1 Score  : 0.8211
# F2 Score  : 0.8700
# Best Threshold  : 0.13999999999999999
# TP: 1088, TN: 1453, FP: 361, FN: 113
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.93      0.80      0.86      1814
#            1       0.75      0.91      0.82      1201
#
#     accuracy                           0.84      3015
#    macro avg       0.84      0.85      0.84      3015
# weighted avg       0.86      0.84      0.84      3015
#
# Model saved to models/svm\svm_under_normal_1d_cnn_features_256.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/1d_cnn/datasets/over_sampled_1d_cnn_features_32.csv...
# Accuracy  : 0.8484
# Precision : 0.7490
# Recall    : 0.9317
# F1 Score  : 0.8304
# F2 Score  : 0.8884
# Best Threshold  : 0.12
# TP: 1119, TN: 1439, FP: 375, FN: 82
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.95      0.79      0.86      1814
#            1       0.75      0.93      0.83      1201
#
#     accuracy                           0.85      3015
#    macro avg       0.85      0.86      0.85      3015
# weighted avg       0.87      0.85      0.85      3015
#
# Model saved to models/svm\svm_under_over_sampled_1d_cnn_features_32.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/1d_cnn/datasets/over_sampled_1d_cnn_features_64.csv...
# Accuracy  : 0.8448
# Precision : 0.7410
# Recall    : 0.9384
# F1 Score  : 0.8281
# F2 Score  : 0.8909
# Best Threshold  : 0.1
# TP: 1127, TN: 1420, FP: 394, FN: 74
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.95      0.78      0.86      1814
#            1       0.74      0.94      0.83      1201
#
#     accuracy                           0.84      3015
#    macro avg       0.85      0.86      0.84      3015
# weighted avg       0.87      0.84      0.85      3015
#
# Model saved to models/svm\svm_under_over_sampled_1d_cnn_features_64.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/1d_cnn/datasets/over_sampled_1d_cnn_features_128.csv...
# Accuracy  : 0.8720
# Precision : 0.7904
# Recall    : 0.9234
# F1 Score  : 0.8518
# F2 Score  : 0.8933
# Best Threshold  : 0.14999999999999997
# TP: 1109, TN: 1520, FP: 294, FN: 92
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.84      0.89      1814
#            1       0.79      0.92      0.85      1201
#
#     accuracy                           0.87      3015
#    macro avg       0.87      0.88      0.87      3015
# weighted avg       0.88      0.87      0.87      3015
#
# Model saved to models/svm\svm_under_over_sampled_1d_cnn_features_128.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/1d_cnn/datasets/over_sampled_1d_cnn_features_256.csv...
# Accuracy  : 0.8544
# Precision : 0.7595
# Recall    : 0.9284
# F1 Score  : 0.8355
# F2 Score  : 0.8889
# Best Threshold  : 0.13
# TP: 1115, TN: 1461, FP: 353, FN: 86
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.81      0.87      1814
#            1       0.76      0.93      0.84      1201
#
#     accuracy                           0.85      3015
#    macro avg       0.85      0.87      0.85      3015
# weighted avg       0.87      0.85      0.86      3015
#
# Model saved to models/svm\svm_under_over_sampled_1d_cnn_features_256.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/1d_cnn/datasets/under_sampled_1d_cnn_features_32.csv...
# Accuracy  : 0.8544
# Precision : 0.7602
# Recall    : 0.9267
# F1 Score  : 0.8353
# F2 Score  : 0.8878
# Best Threshold  : 0.13999999999999999
# TP: 1113, TN: 1463, FP: 351, FN: 88
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.81      0.87      1814
#            1       0.76      0.93      0.84      1201
#
#     accuracy                           0.85      3015
#    macro avg       0.85      0.87      0.85      3015
# weighted avg       0.87      0.85      0.86      3015
#
# Model saved to models/svm\svm_under_under_sampled_1d_cnn_features_32.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/1d_cnn/datasets/under_sampled_1d_cnn_features_64.csv...
# Accuracy  : 0.8604
# Precision : 0.7758
# Recall    : 0.9134
# F1 Score  : 0.8390
# F2 Score  : 0.8821
# Best Threshold  : 0.16999999999999998
# TP: 1097, TN: 1497, FP: 317, FN: 104
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.83      0.88      1814
#            1       0.78      0.91      0.84      1201
#
#     accuracy                           0.86      3015
#    macro avg       0.86      0.87      0.86      3015
# weighted avg       0.87      0.86      0.86      3015
#
# Model saved to models/svm\svm_under_under_sampled_1d_cnn_features_64.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/1d_cnn/datasets/under_sampled_1d_cnn_features_128.csv...
# Accuracy  : 0.8557
# Precision : 0.7660
# Recall    : 0.9184
# F1 Score  : 0.8353
# F2 Score  : 0.8832
# Best Threshold  : 0.15999999999999998
# TP: 1103, TN: 1477, FP: 337, FN: 98
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.81      0.87      1814
#            1       0.77      0.92      0.84      1201
#
#     accuracy                           0.86      3015
#    macro avg       0.85      0.87      0.85      3015
# weighted avg       0.87      0.86      0.86      3015
#
# Model saved to models/svm\svm_under_under_sampled_1d_cnn_features_128.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/1d_cnn/datasets/under_sampled_1d_cnn_features_256.csv...
# Accuracy  : 0.8567
# Precision : 0.7661
# Recall    : 0.9217
# F1 Score  : 0.8367
# F2 Score  : 0.8857
# Best Threshold  : 0.13999999999999999
# TP: 1107, TN: 1476, FP: 338, FN: 94
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.81      0.87      1814
#            1       0.77      0.92      0.84      1201
#
#     accuracy                           0.86      3015
#    macro avg       0.85      0.87      0.85      3015
# weighted avg       0.87      0.86      0.86      3015
#
# Model saved to models/svm\svm_under_under_sampled_1d_cnn_features_256.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/1d_cnn/datasets/weighted_1d_cnn_features_32.csv...
# Accuracy  : 0.8474
# Precision : 0.7512
# Recall    : 0.9226
# F1 Score  : 0.8281
# F2 Score  : 0.8823
# Best Threshold  : 0.13
# TP: 1108, TN: 1447, FP: 367, FN: 93
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.80      0.86      1814
#            1       0.75      0.92      0.83      1201
#
#     accuracy                           0.85      3015
#    macro avg       0.85      0.86      0.85      3015
# weighted avg       0.86      0.85      0.85      3015
#
# Model saved to models/svm\svm_under_weighted_1d_cnn_features_32.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/1d_cnn/datasets/weighted_1d_cnn_features_64.csv...
# Accuracy  : 0.8594
# Precision : 0.7769
# Recall    : 0.9076
# F1 Score  : 0.8372
# F2 Score  : 0.8780
# Best Threshold  : 0.17999999999999997
# TP: 1090, TN: 1501, FP: 313, FN: 111
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.93      0.83      0.88      1814
#            1       0.78      0.91      0.84      1201
#
#     accuracy                           0.86      3015
#    macro avg       0.85      0.87      0.86      3015
# weighted avg       0.87      0.86      0.86      3015
#
# Model saved to models/svm\svm_under_weighted_1d_cnn_features_64.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/1d_cnn/datasets/weighted_1d_cnn_features_128.csv...
# Accuracy  : 0.8401
# Precision : 0.7376
# Recall    : 0.9292
# F1 Score  : 0.8224
# F2 Score  : 0.8833
# Best Threshold  : 0.11
# TP: 1116, TN: 1417, FP: 397, FN: 85
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.78      0.85      1814
#            1       0.74      0.93      0.82      1201
#
#     accuracy                           0.84      3015
#    macro avg       0.84      0.86      0.84      3015
# weighted avg       0.86      0.84      0.84      3015
#
# Model saved to models/svm\svm_under_weighted_1d_cnn_features_128.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/1d_cnn/datasets/weighted_1d_cnn_features_256.csv...
# Accuracy  : 0.8570
# Precision : 0.7670
# Recall    : 0.9209
# F1 Score  : 0.8369
# F2 Score  : 0.8854
# Best Threshold  : 0.13
# TP: 1106, TN: 1478, FP: 336, FN: 95
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.81      0.87      1814
#            1       0.77      0.92      0.84      1201
#
#     accuracy                           0.86      3015
#    macro avg       0.85      0.87      0.85      3015
# weighted avg       0.87      0.86      0.86      3015
#
# Model saved to models/svm\svm_under_weighted_1d_cnn_features_256.joblib
# Results saved to results_summary.csv

# %% [markdown]
# ### Over-Sampled

# %%
train(cnn_1d_dataset_paths, "svm", "over")
# Out:
# Processing ../feature-extraction/1d_cnn/datasets/normal_1d_cnn_features_32.csv...
# Accuracy  : 0.8680
# Precision : 0.7862
# Recall    : 0.9184
# F1 Score  : 0.8472
# F2 Score  : 0.8885
# Best Threshold  : 0.16999999999999998
# TP: 1103, TN: 1514, FP: 300, FN: 98
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.83      0.88      1814
#            1       0.79      0.92      0.85      1201
#
#     accuracy                           0.87      3015
#    macro avg       0.86      0.88      0.87      3015
# weighted avg       0.88      0.87      0.87      3015
#
# Model saved to models/svm\svm_over_normal_1d_cnn_features_32.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/1d_cnn/datasets/normal_1d_cnn_features_64.csv...
# Accuracy  : 0.8663
# Precision : 0.7830
# Recall    : 0.9192
# F1 Score  : 0.8457
# F2 Score  : 0.8883
# Best Threshold  : 0.12
# TP: 1104, TN: 1508, FP: 306, FN: 97
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.83      0.88      1814
#            1       0.78      0.92      0.85      1201
#
#     accuracy                           0.87      3015
#    macro avg       0.86      0.88      0.86      3015
# weighted avg       0.88      0.87      0.87      3015
#
# Model saved to models/svm\svm_over_normal_1d_cnn_features_64.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/1d_cnn/datasets/normal_1d_cnn_features_128.csv...
# Accuracy  : 0.8653
# Precision : 0.7770
# Recall    : 0.9284
# F1 Score  : 0.8460
# F2 Score  : 0.8936
# Best Threshold  : 0.12
# TP: 1115, TN: 1494, FP: 320, FN: 86
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.95      0.82      0.88      1814
#            1       0.78      0.93      0.85      1201
#
#     accuracy                           0.87      3015
#    macro avg       0.86      0.88      0.86      3015
# weighted avg       0.88      0.87      0.87      3015
#
# Model saved to models/svm\svm_over_normal_1d_cnn_features_128.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/1d_cnn/datasets/normal_1d_cnn_features_256.csv...
# Accuracy  : 0.8391
# Precision : 0.7449
# Recall    : 0.9067
# F1 Score  : 0.8179
# F2 Score  : 0.8690
# Best Threshold  : 0.13
# TP: 1089, TN: 1441, FP: 373, FN: 112
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.93      0.79      0.86      1814
#            1       0.74      0.91      0.82      1201
#
#     accuracy                           0.84      3015
#    macro avg       0.84      0.85      0.84      3015
# weighted avg       0.85      0.84      0.84      3015
#
# Model saved to models/svm\svm_over_normal_1d_cnn_features_256.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/1d_cnn/datasets/over_sampled_1d_cnn_features_32.csv...
# Accuracy  : 0.8594
# Precision : 0.7685
# Recall    : 0.9259
# F1 Score  : 0.8399
# F2 Score  : 0.8895
# Best Threshold  : 0.13
# TP: 1112, TN: 1479, FP: 335, FN: 89
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.82      0.87      1814
#            1       0.77      0.93      0.84      1201
#
#     accuracy                           0.86      3015
#    macro avg       0.86      0.87      0.86      3015
# weighted avg       0.87      0.86      0.86      3015
#
# Model saved to models/svm\svm_over_over_sampled_1d_cnn_features_32.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/1d_cnn/datasets/over_sampled_1d_cnn_features_64.csv...
# Accuracy  : 0.8557
# Precision : 0.7623
# Recall    : 0.9267
# F1 Score  : 0.8365
# F2 Score  : 0.8884
# Best Threshold  : 0.11
# TP: 1113, TN: 1467, FP: 347, FN: 88
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.81      0.87      1814
#            1       0.76      0.93      0.84      1201
#
#     accuracy                           0.86      3015
#    macro avg       0.85      0.87      0.85      3015
# weighted avg       0.87      0.86      0.86      3015
#
# Model saved to models/svm\svm_over_over_sampled_1d_cnn_features_64.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/1d_cnn/datasets/over_sampled_1d_cnn_features_128.csv...
# Accuracy  : 0.8703
# Precision : 0.7868
# Recall    : 0.9251
# F1 Score  : 0.8504
# F2 Score  : 0.8937
# Best Threshold  : 0.13
# TP: 1111, TN: 1513, FP: 301, FN: 90
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.83      0.89      1814
#            1       0.79      0.93      0.85      1201
#
#     accuracy                           0.87      3015
#    macro avg       0.87      0.88      0.87      3015
# weighted avg       0.88      0.87      0.87      3015
#
# Model saved to models/svm\svm_over_over_sampled_1d_cnn_features_128.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/1d_cnn/datasets/over_sampled_1d_cnn_features_256.csv...
# Accuracy  : 0.8524
# Precision : 0.7540
# Recall    : 0.9342
# F1 Score  : 0.8345
# F2 Score  : 0.8916
# Best Threshold  : 0.11
# TP: 1122, TN: 1448, FP: 366, FN: 79
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.95      0.80      0.87      1814
#            1       0.75      0.93      0.83      1201
#
#     accuracy                           0.85      3015
#    macro avg       0.85      0.87      0.85      3015
# weighted avg       0.87      0.85      0.85      3015
#
# Model saved to models/svm\svm_over_over_sampled_1d_cnn_features_256.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/1d_cnn/datasets/under_sampled_1d_cnn_features_32.csv...
# Accuracy  : 0.8498
# Precision : 0.7537
# Recall    : 0.9251
# F1 Score  : 0.8307
# F2 Score  : 0.8848
# Best Threshold  : 0.13
# TP: 1111, TN: 1451, FP: 363, FN: 90
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.80      0.86      1814
#            1       0.75      0.93      0.83      1201
#
#     accuracy                           0.85      3015
#    macro avg       0.85      0.86      0.85      3015
# weighted avg       0.87      0.85      0.85      3015
#
# Model saved to models/svm\svm_over_under_sampled_1d_cnn_features_32.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/1d_cnn/datasets/under_sampled_1d_cnn_features_64.csv...
# Accuracy  : 0.8580
# Precision : 0.7701
# Recall    : 0.9176
# F1 Score  : 0.8374
# F2 Score  : 0.8837
# Best Threshold  : 0.14999999999999997
# TP: 1102, TN: 1485, FP: 329, FN: 99
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.82      0.87      1814
#            1       0.77      0.92      0.84      1201
#
#     accuracy                           0.86      3015
#    macro avg       0.85      0.87      0.86      3015
# weighted avg       0.87      0.86      0.86      3015
#
# Model saved to models/svm\svm_over_under_sampled_1d_cnn_features_64.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/1d_cnn/datasets/under_sampled_1d_cnn_features_128.csv...
# Accuracy  : 0.8517
# Precision : 0.7593
# Recall    : 0.9192
# F1 Score  : 0.8316
# F2 Score  : 0.8821
# Best Threshold  : 0.13999999999999999
# TP: 1104, TN: 1464, FP: 350, FN: 97
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.81      0.87      1814
#            1       0.76      0.92      0.83      1201
#
#     accuracy                           0.85      3015
#    macro avg       0.85      0.86      0.85      3015
# weighted avg       0.87      0.85      0.85      3015
#
# Model saved to models/svm\svm_over_under_sampled_1d_cnn_features_128.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/1d_cnn/datasets/under_sampled_1d_cnn_features_256.csv...
# Accuracy  : 0.8527
# Precision : 0.7577
# Recall    : 0.9267
# F1 Score  : 0.8337
# F2 Score  : 0.8871
# Best Threshold  : 0.12
# TP: 1113, TN: 1458, FP: 356, FN: 88
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.80      0.87      1814
#            1       0.76      0.93      0.83      1201
#
#     accuracy                           0.85      3015
#    macro avg       0.85      0.87      0.85      3015
# weighted avg       0.87      0.85      0.85      3015
#
# Model saved to models/svm\svm_over_under_sampled_1d_cnn_features_256.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/1d_cnn/datasets/weighted_1d_cnn_features_32.csv...
# Accuracy  : 0.8633
# Precision : 0.7812
# Recall    : 0.9126
# F1 Score  : 0.8418
# F2 Score  : 0.8829
# Best Threshold  : 0.16999999999999998
# TP: 1096, TN: 1507, FP: 307, FN: 105
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.93      0.83      0.88      1814
#            1       0.78      0.91      0.84      1201
#
#     accuracy                           0.86      3015
#    macro avg       0.86      0.87      0.86      3015
# weighted avg       0.87      0.86      0.86      3015
#
# Model saved to models/svm\svm_over_weighted_1d_cnn_features_32.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/1d_cnn/datasets/weighted_1d_cnn_features_64.csv...
# Accuracy  : 0.8527
# Precision : 0.7638
# Recall    : 0.9126
# F1 Score  : 0.8316
# F2 Score  : 0.8783
# Best Threshold  : 0.14999999999999997
# TP: 1096, TN: 1475, FP: 339, FN: 105
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.93      0.81      0.87      1814
#            1       0.76      0.91      0.83      1201
#
#     accuracy                           0.85      3015
#    macro avg       0.85      0.86      0.85      3015
# weighted avg       0.87      0.85      0.85      3015
#
# Model saved to models/svm\svm_over_weighted_1d_cnn_features_64.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/1d_cnn/datasets/weighted_1d_cnn_features_128.csv...
# Accuracy  : 0.8468
# Precision : 0.7488
# Recall    : 0.9259
# F1 Score  : 0.8280
# F2 Score  : 0.8841
# Best Threshold  : 0.11
# TP: 1112, TN: 1441, FP: 373, FN: 89
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.79      0.86      1814
#            1       0.75      0.93      0.83      1201
#
#     accuracy                           0.85      3015
#    macro avg       0.85      0.86      0.84      3015
# weighted avg       0.86      0.85      0.85      3015
#
# Model saved to models/svm\svm_over_weighted_1d_cnn_features_128.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/1d_cnn/datasets/weighted_1d_cnn_features_256.csv...
# Accuracy  : 0.8627
# Precision : 0.7769
# Recall    : 0.9192
# F1 Score  : 0.8421
# F2 Score  : 0.8867
# Best Threshold  : 0.13
# TP: 1104, TN: 1497, FP: 317, FN: 97
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.83      0.88      1814
#            1       0.78      0.92      0.84      1201
#
#     accuracy                           0.86      3015
#    macro avg       0.86      0.87      0.86      3015
# weighted avg       0.87      0.86      0.86      3015
#
# Model saved to models/svm\svm_over_weighted_1d_cnn_features_256.joblib
# Results saved to results_summary.csv

# %% [markdown]
# ### Weighted

# %%
train(cnn_1d_dataset_paths, "svm", "weighted")
# Out:
# Processing ../feature-extraction/1d_cnn/datasets/normal_1d_cnn_features_32.csv...
# Accuracy  : 0.8614
# Precision : 0.7736
# Recall    : 0.9217
# F1 Score  : 0.8412
# F2 Score  : 0.8877
# Best Threshold  : 0.11
# TP: 1107, TN: 1490, FP: 324, FN: 94
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.82      0.88      1814
#            1       0.77      0.92      0.84      1201
#
#     accuracy                           0.86      3015
#    macro avg       0.86      0.87      0.86      3015
# weighted avg       0.87      0.86      0.86      3015
#
# Model saved to models/svm\svm_weighted_normal_1d_cnn_features_32.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/1d_cnn/datasets/normal_1d_cnn_features_64.csv...
# Accuracy  : 0.8733
# Precision : 0.7987
# Recall    : 0.9117
# F1 Score  : 0.8515
# F2 Score  : 0.8866
# Best Threshold  : 0.1
# TP: 1095, TN: 1538, FP: 276, FN: 106
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.85      0.89      1814
#            1       0.80      0.91      0.85      1201
#
#     accuracy                           0.87      3015
#    macro avg       0.87      0.88      0.87      3015
# weighted avg       0.88      0.87      0.87      3015
#
# Model saved to models/svm\svm_weighted_normal_1d_cnn_features_64.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/1d_cnn/datasets/normal_1d_cnn_features_128.csv...
# Accuracy  : 0.8687
# Precision : 0.7865
# Recall    : 0.9201
# F1 Score  : 0.8480
# F2 Score  : 0.8898
# Best Threshold  : 0.1
# TP: 1105, TN: 1514, FP: 300, FN: 96
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.83      0.88      1814
#            1       0.79      0.92      0.85      1201
#
#     accuracy                           0.87      3015
#    macro avg       0.86      0.88      0.87      3015
# weighted avg       0.88      0.87      0.87      3015
#
# Model saved to models/svm\svm_weighted_normal_1d_cnn_features_128.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/1d_cnn/datasets/normal_1d_cnn_features_256.csv...
# Accuracy  : 0.8478
# Precision : 0.7613
# Recall    : 0.9001
# F1 Score  : 0.8249
# F2 Score  : 0.8684
# Best Threshold  : 0.1
# TP: 1081, TN: 1475, FP: 339, FN: 120
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.92      0.81      0.87      1814
#            1       0.76      0.90      0.82      1201
#
#     accuracy                           0.85      3015
#    macro avg       0.84      0.86      0.85      3015
# weighted avg       0.86      0.85      0.85      3015
#
# Model saved to models/svm\svm_weighted_normal_1d_cnn_features_256.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/1d_cnn/datasets/over_sampled_1d_cnn_features_32.csv...
# Accuracy  : 0.8637
# Precision : 0.7778
# Recall    : 0.9209
# F1 Score  : 0.8433
# F2 Score  : 0.8882
# Best Threshold  : 0.1
# TP: 1106, TN: 1498, FP: 316, FN: 95
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.83      0.88      1814
#            1       0.78      0.92      0.84      1201
#
#     accuracy                           0.86      3015
#    macro avg       0.86      0.87      0.86      3015
# weighted avg       0.88      0.86      0.87      3015
#
# Model saved to models/svm\svm_weighted_over_sampled_1d_cnn_features_32.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/1d_cnn/datasets/over_sampled_1d_cnn_features_64.csv...
# Accuracy  : 0.8693
# Precision : 0.7909
# Recall    : 0.9134
# F1 Score  : 0.8478
# F2 Score  : 0.8860
# Best Threshold  : 0.11
# TP: 1097, TN: 1524, FP: 290, FN: 104
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.84      0.89      1814
#            1       0.79      0.91      0.85      1201
#
#     accuracy                           0.87      3015
#    macro avg       0.86      0.88      0.87      3015
# weighted avg       0.88      0.87      0.87      3015
#
# Model saved to models/svm\svm_weighted_over_sampled_1d_cnn_features_64.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/1d_cnn/datasets/over_sampled_1d_cnn_features_128.csv...
# Accuracy  : 0.8703
# Precision : 0.7889
# Recall    : 0.9209
# F1 Score  : 0.8498
# F2 Score  : 0.8911
# Best Threshold  : 0.1
# TP: 1106, TN: 1518, FP: 296, FN: 95
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.84      0.89      1814
#            1       0.79      0.92      0.85      1201
#
#     accuracy                           0.87      3015
#    macro avg       0.86      0.88      0.87      3015
# weighted avg       0.88      0.87      0.87      3015
#
# Model saved to models/svm\svm_weighted_over_sampled_1d_cnn_features_128.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/1d_cnn/datasets/over_sampled_1d_cnn_features_256.csv...
# Accuracy  : 0.8617
# Precision : 0.7741
# Recall    : 0.9217
# F1 Score  : 0.8415
# F2 Score  : 0.8879
# Best Threshold  : 0.1
# TP: 1107, TN: 1491, FP: 323, FN: 94
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.82      0.88      1814
#            1       0.77      0.92      0.84      1201
#
#     accuracy                           0.86      3015
#    macro avg       0.86      0.87      0.86      3015
# weighted avg       0.87      0.86      0.86      3015
#
# Model saved to models/svm\svm_weighted_over_sampled_1d_cnn_features_256.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/1d_cnn/datasets/under_sampled_1d_cnn_features_32.csv...
# Accuracy  : 0.8557
# Precision : 0.7656
# Recall    : 0.9192
# F1 Score  : 0.8354
# F2 Score  : 0.8838
# Best Threshold  : 0.1
# TP: 1104, TN: 1476, FP: 338, FN: 97
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.81      0.87      1814
#            1       0.77      0.92      0.84      1201
#
#     accuracy                           0.86      3015
#    macro avg       0.85      0.87      0.85      3015
# weighted avg       0.87      0.86      0.86      3015
#
# Model saved to models/svm\svm_weighted_under_sampled_1d_cnn_features_32.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/1d_cnn/datasets/under_sampled_1d_cnn_features_64.csv...
# Accuracy  : 0.8547
# Precision : 0.7647
# Recall    : 0.9176
# F1 Score  : 0.8342
# F2 Score  : 0.8823
# Best Threshold  : 0.1
# TP: 1102, TN: 1475, FP: 339, FN: 99
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.81      0.87      1814
#            1       0.76      0.92      0.83      1201
#
#     accuracy                           0.85      3015
#    macro avg       0.85      0.87      0.85      3015
# weighted avg       0.87      0.85      0.86      3015
#
# Model saved to models/svm\svm_weighted_under_sampled_1d_cnn_features_64.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/1d_cnn/datasets/under_sampled_1d_cnn_features_128.csv...
# Accuracy  : 0.8580
# Precision : 0.7712
# Recall    : 0.9151
# F1 Score  : 0.8370
# F2 Score  : 0.8822
# Best Threshold  : 0.11
# TP: 1099, TN: 1488, FP: 326, FN: 102
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.82      0.87      1814
#            1       0.77      0.92      0.84      1201
#
#     accuracy                           0.86      3015
#    macro avg       0.85      0.87      0.86      3015
# weighted avg       0.87      0.86      0.86      3015
#
# Model saved to models/svm\svm_weighted_under_sampled_1d_cnn_features_128.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/1d_cnn/datasets/under_sampled_1d_cnn_features_256.csv...
# Accuracy  : 0.8597
# Precision : 0.7713
# Recall    : 0.9209
# F1 Score  : 0.8395
# F2 Score  : 0.8865
# Best Threshold  : 0.1
# TP: 1106, TN: 1486, FP: 328, FN: 95
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.82      0.88      1814
#            1       0.77      0.92      0.84      1201
#
#     accuracy                           0.86      3015
#    macro avg       0.86      0.87      0.86      3015
# weighted avg       0.87      0.86      0.86      3015
#
# Model saved to models/svm\svm_weighted_under_sampled_1d_cnn_features_256.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/1d_cnn/datasets/weighted_1d_cnn_features_32.csv...
# Accuracy  : 0.8716
# Precision : 0.7993
# Recall    : 0.9051
# F1 Score  : 0.8489
# F2 Score  : 0.8817
# Best Threshold  : 0.15999999999999998
# TP: 1087, TN: 1541, FP: 273, FN: 114
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.93      0.85      0.89      1814
#            1       0.80      0.91      0.85      1201
#
#     accuracy                           0.87      3015
#    macro avg       0.87      0.88      0.87      3015
# weighted avg       0.88      0.87      0.87      3015
#
# Model saved to models/svm\svm_weighted_weighted_1d_cnn_features_32.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/1d_cnn/datasets/weighted_1d_cnn_features_64.csv...
# Accuracy  : 0.8541
# Precision : 0.7670
# Recall    : 0.9101
# F1 Score  : 0.8324
# F2 Score  : 0.8773
# Best Threshold  : 0.11
# TP: 1093, TN: 1482, FP: 332, FN: 108
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.93      0.82      0.87      1814
#            1       0.77      0.91      0.83      1201
#
#     accuracy                           0.85      3015
#    macro avg       0.85      0.86      0.85      3015
# weighted avg       0.87      0.85      0.86      3015
#
# Model saved to models/svm\svm_weighted_weighted_1d_cnn_features_64.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/1d_cnn/datasets/weighted_1d_cnn_features_128.csv...
# Accuracy  : 0.8584
# Precision : 0.7733
# Recall    : 0.9117
# F1 Score  : 0.8368
# F2 Score  : 0.8802
# Best Threshold  : 0.1
# TP: 1095, TN: 1493, FP: 321, FN: 106
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.93      0.82      0.87      1814
#            1       0.77      0.91      0.84      1201
#
#     accuracy                           0.86      3015
#    macro avg       0.85      0.87      0.86      3015
# weighted avg       0.87      0.86      0.86      3015
#
# Model saved to models/svm\svm_weighted_weighted_1d_cnn_features_128.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/1d_cnn/datasets/weighted_1d_cnn_features_256.csv...
# Accuracy  : 0.8637
# Precision : 0.7797
# Recall    : 0.9167
# F1 Score  : 0.8427
# F2 Score  : 0.8856
# Best Threshold  : 0.1
# TP: 1101, TN: 1503, FP: 311, FN: 100
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.83      0.88      1814
#            1       0.78      0.92      0.84      1201
#
#     accuracy                           0.86      3015
#    macro avg       0.86      0.87      0.86      3015
# weighted avg       0.87      0.86      0.86      3015
#
# Model saved to models/svm\svm_weighted_weighted_1d_cnn_features_256.joblib
# Results saved to results_summary.csv
