# %% [markdown]
# # Imports

# %%
# !pip install imbalanced-learn
# !pip install xgboost
# Out:
# Requirement already satisfied: imbalanced-learn in c:\users\chanuka athalage\appdata\local\programs\python\python312\lib\site-packages (0.14.0)
# Requirement already satisfied: numpy<3,>=1.25.2 in c:\users\chanuka athalage\appdata\local\programs\python\python312\lib\site-packages (from imbalanced-learn) (1.26.4)
# Requirement already satisfied: scipy<2,>=1.11.4 in c:\users\chanuka athalage\appdata\local\programs\python\python312\lib\site-packages (from imbalanced-learn) (1.15.2)
# Requirement already satisfied: scikit-learn<2,>=1.4.2 in c:\users\chanuka athalage\appdata\local\programs\python\python312\lib\site-packages (from imbalanced-learn) (1.6.1)
# Requirement already satisfied: joblib<2,>=1.2.0 in c:\users\chanuka athalage\appdata\local\programs\python\python312\lib\site-packages (from imbalanced-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl<4,>=2.0.0 in c:\users\chanuka athalage\appdata\local\programs\python\python312\lib\site-packages (from imbalanced-learn) (3.6.0)
# [notice] A new release of pip is available: 23.2.1 -> 25.2
# [notice] To update, run: C:\Users\CHANUKA ATHALAGE\AppData\Local\Programs\Python\Python312\python.exe -m pip install --upgrade pip
# Requirement already satisfied: xgboost in c:\users\chanuka athalage\appdata\local\programs\python\python312\lib\site-packages (3.0.4)
# Requirement already satisfied: numpy in c:\users\chanuka athalage\appdata\local\programs\python\python312\lib\site-packages (from xgboost) (1.26.4)
# Requirement already satisfied: scipy in c:\users\chanuka athalage\appdata\local\programs\python\python312\lib\site-packages (from xgboost) (1.15.2)
# [notice] A new release of pip is available: 23.2.1 -> 25.2
# [notice] To update, run: C:\Users\CHANUKA ATHALAGE\AppData\Local\Programs\Python\Python312\python.exe -m pip install --upgrade pip

# %%
from data_utils import train

# %% [markdown]
# # Train Model

# %% [markdown]
# ## 2D_CNN

# %% [markdown]
# ### Datasets

# %%
cnn_2d_dataset_paths = [
    "../feature-extraction/2D_cnn/datasets/features_with_metadata_base_dense32.csv",
    "../feature-extraction/2D_cnn/datasets/features_with_metadata_base_dense64.csv",
    "../feature-extraction/2D_cnn/datasets/features_with_metadata_base_dense128.csv",
    "../feature-extraction/2D_cnn/datasets/features_with_metadata_base_dense256.csv",
    "../feature-extraction/2D_cnn/datasets/features_with_metadata_oversampling_dense32.csv",
    "../feature-extraction/2D_cnn/datasets/features_with_metadata_oversampling_dense64.csv",
    "../feature-extraction/2D_cnn/datasets/features_with_metadata_oversampling_dense128.csv",
    "../feature-extraction/2D_cnn/datasets/features_with_metadata_oversampling_dense256.csv",
    "../feature-extraction/2D_cnn/datasets/features_with_metadata_undersampling_dense32.csv",
    "../feature-extraction/2D_cnn/datasets/features_with_metadata_undersampling_dense64.csv",
    "../feature-extraction/2D_cnn/datasets/features_with_metadata_undersampling_dense128.csv",
    "../feature-extraction/2D_cnn/datasets/features_with_metadata_undersampling_dense256.csv",
    "../feature-extraction/2D_cnn/datasets/features_with_metadata_weighted_dense32.csv",
    "../feature-extraction/2D_cnn/datasets/features_with_metadata_weighted_dense64.csv",
    "../feature-extraction/2D_cnn/datasets/features_with_metadata_weighted_dense128.csv",
    "../feature-extraction/2D_cnn/datasets/features_with_metadata_weighted_dense256.csv",

]

# %% [markdown]
# ### Imbalanced

# %%
train(cnn_2d_dataset_paths, "rf", "normal")
# Out:
# Processing ../feature-extraction/2D_cnn/datasets/features_with_metadata_base_dense32.csv...
# Accuracy  : 0.7743
# Precision : 0.6518
# Recall    : 0.9320
# F1 Score  : 0.7671
# F2 Score  : 0.8582
# Best Threshold  : 0.1
# TP: 1123, TN: 1217, FP: 600, FN: 82
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.67      0.78      1817
#            1       0.65      0.93      0.77      1205
#
#     accuracy                           0.77      3022
#    macro avg       0.79      0.80      0.77      3022
# weighted avg       0.82      0.77      0.78      3022
#
# Model saved to models/rf\rf_normal_features_with_metadata_base_dense32.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/2D_cnn/datasets/features_with_metadata_base_dense64.csv...
# Accuracy  : 0.8620
# Precision : 0.7936
# Recall    : 0.8838
# F1 Score  : 0.8363
# F2 Score  : 0.8642
# Best Threshold  : 0.1
# TP: 1065, TN: 1540, FP: 277, FN: 140
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.92      0.85      0.88      1817
#            1       0.79      0.88      0.84      1205
#
#     accuracy                           0.86      3022
#    macro avg       0.86      0.87      0.86      3022
# weighted avg       0.87      0.86      0.86      3022
#
# Model saved to models/rf\rf_normal_features_with_metadata_base_dense64.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/2D_cnn/datasets/features_with_metadata_base_dense128.csv...
# Accuracy  : 0.8680
# Precision : 0.8261
# Recall    : 0.8473
# F1 Score  : 0.8365
# F2 Score  : 0.8430
# Best Threshold  : 0.1
# TP: 1021, TN: 1602, FP: 215, FN: 184
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.90      0.88      0.89      1817
#            1       0.83      0.85      0.84      1205
#
#     accuracy                           0.87      3022
#    macro avg       0.86      0.86      0.86      3022
# weighted avg       0.87      0.87      0.87      3022
#
# Model saved to models/rf\rf_normal_features_with_metadata_base_dense128.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/2D_cnn/datasets/features_with_metadata_base_dense256.csv...
# Accuracy  : 0.8213
# Precision : 0.7177
# Recall    : 0.9095
# F1 Score  : 0.8023
# F2 Score  : 0.8634
# Best Threshold  : 0.12
# TP: 1096, TN: 1386, FP: 431, FN: 109
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.93      0.76      0.84      1817
#            1       0.72      0.91      0.80      1205
#
#     accuracy                           0.82      3022
#    macro avg       0.82      0.84      0.82      3022
# weighted avg       0.84      0.82      0.82      3022
#
# Model saved to models/rf\rf_normal_features_with_metadata_base_dense256.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/2D_cnn/datasets/features_with_metadata_oversampling_dense32.csv...
# Accuracy  : 0.8183
# Precision : 0.7108
# Recall    : 0.9178
# F1 Score  : 0.8012
# F2 Score  : 0.8673
# Best Threshold  : 0.1
# TP: 1106, TN: 1367, FP: 450, FN: 99
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.93      0.75      0.83      1817
#            1       0.71      0.92      0.80      1205
#
#     accuracy                           0.82      3022
#    macro avg       0.82      0.84      0.82      3022
# weighted avg       0.84      0.82      0.82      3022
#
# Model saved to models/rf\rf_normal_features_with_metadata_oversampling_dense32.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/2D_cnn/datasets/features_with_metadata_oversampling_dense64.csv...
# Accuracy  : 0.8319
# Precision : 0.7363
# Recall    : 0.9012
# F1 Score  : 0.8104
# F2 Score  : 0.8626
# Best Threshold  : 0.1
# TP: 1086, TN: 1428, FP: 389, FN: 119
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.92      0.79      0.85      1817
#            1       0.74      0.90      0.81      1205
#
#     accuracy                           0.83      3022
#    macro avg       0.83      0.84      0.83      3022
# weighted avg       0.85      0.83      0.83      3022
#
# Model saved to models/rf\rf_normal_features_with_metadata_oversampling_dense64.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/2D_cnn/datasets/features_with_metadata_oversampling_dense128.csv...
# Accuracy  : 0.8024
# Precision : 0.6872
# Recall    : 0.9261
# F1 Score  : 0.7890
# F2 Score  : 0.8659
# Best Threshold  : 0.1
# TP: 1116, TN: 1309, FP: 508, FN: 89
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.72      0.81      1817
#            1       0.69      0.93      0.79      1205
#
#     accuracy                           0.80      3022
#    macro avg       0.81      0.82      0.80      3022
# weighted avg       0.84      0.80      0.80      3022
#
# Model saved to models/rf\rf_normal_features_with_metadata_oversampling_dense128.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/2D_cnn/datasets/features_with_metadata_oversampling_dense256.csv...
# Accuracy  : 0.7869
# Precision : 0.6681
# Recall    : 0.9253
# F1 Score  : 0.7759
# F2 Score  : 0.8591
# Best Threshold  : 0.12
# TP: 1115, TN: 1263, FP: 554, FN: 90
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.93      0.70      0.80      1817
#            1       0.67      0.93      0.78      1205
#
#     accuracy                           0.79      3022
#    macro avg       0.80      0.81      0.79      3022
# weighted avg       0.83      0.79      0.79      3022
#
# Model saved to models/rf\rf_normal_features_with_metadata_oversampling_dense256.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/2D_cnn/datasets/features_with_metadata_undersampling_dense32.csv...
# Accuracy  : 0.7478
# Precision : 0.6226
# Recall    : 0.9336
# F1 Score  : 0.7470
# F2 Score  : 0.8488
# Best Threshold  : 0.12
# TP: 1125, TN: 1135, FP: 682, FN: 80
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.93      0.62      0.75      1817
#            1       0.62      0.93      0.75      1205
#
#     accuracy                           0.75      3022
#    macro avg       0.78      0.78      0.75      3022
# weighted avg       0.81      0.75      0.75      3022
#
# Model saved to models/rf\rf_normal_features_with_metadata_undersampling_dense32.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/2D_cnn/datasets/features_with_metadata_undersampling_dense64.csv...
# Accuracy  : 0.7727
# Precision : 0.6553
# Recall    : 0.9071
# F1 Score  : 0.7609
# F2 Score  : 0.8423
# Best Threshold  : 0.12
# TP: 1093, TN: 1242, FP: 575, FN: 112
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.92      0.68      0.78      1817
#            1       0.66      0.91      0.76      1205
#
#     accuracy                           0.77      3022
#    macro avg       0.79      0.80      0.77      3022
# weighted avg       0.81      0.77      0.77      3022
#
# Model saved to models/rf\rf_normal_features_with_metadata_undersampling_dense64.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/2D_cnn/datasets/features_with_metadata_undersampling_dense128.csv...
# Accuracy  : 0.8269
# Precision : 0.7255
# Recall    : 0.9104
# F1 Score  : 0.8075
# F2 Score  : 0.8662
# Best Threshold  : 0.1
# TP: 1097, TN: 1402, FP: 415, FN: 108
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.93      0.77      0.84      1817
#            1       0.73      0.91      0.81      1205
#
#     accuracy                           0.83      3022
#    macro avg       0.83      0.84      0.83      3022
# weighted avg       0.85      0.83      0.83      3022
#
# Model saved to models/rf\rf_normal_features_with_metadata_undersampling_dense128.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/2D_cnn/datasets/features_with_metadata_undersampling_dense256.csv...
# Accuracy  : 0.8514
# Precision : 0.7859
# Recall    : 0.8622
# F1 Score  : 0.8223
# F2 Score  : 0.8458
# Best Threshold  : 0.1
# TP: 1039, TN: 1534, FP: 283, FN: 166
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.90      0.84      0.87      1817
#            1       0.79      0.86      0.82      1205
#
#     accuracy                           0.85      3022
#    macro avg       0.84      0.85      0.85      3022
# weighted avg       0.86      0.85      0.85      3022
#
# Model saved to models/rf\rf_normal_features_with_metadata_undersampling_dense256.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/2D_cnn/datasets/features_with_metadata_weighted_dense32.csv...
# Accuracy  : 0.7687
# Precision : 0.6462
# Recall    : 0.9278
# F1 Score  : 0.7618
# F2 Score  : 0.8534
# Best Threshold  : 0.1
# TP: 1118, TN: 1205, FP: 612, FN: 87
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.93      0.66      0.78      1817
#            1       0.65      0.93      0.76      1205
#
#     accuracy                           0.77      3022
#    macro avg       0.79      0.80      0.77      3022
# weighted avg       0.82      0.77      0.77      3022
#
# Model saved to models/rf\rf_normal_features_with_metadata_weighted_dense32.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/2D_cnn/datasets/features_with_metadata_weighted_dense64.csv...
# Accuracy  : 0.8445
# Precision : 0.7594
# Recall    : 0.8929
# F1 Score  : 0.8207
# F2 Score  : 0.8626
# Best Threshold  : 0.1
# TP: 1076, TN: 1476, FP: 341, FN: 129
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.92      0.81      0.86      1817
#            1       0.76      0.89      0.82      1205
#
#     accuracy                           0.84      3022
#    macro avg       0.84      0.85      0.84      3022
# weighted avg       0.86      0.84      0.85      3022
#
# Model saved to models/rf\rf_normal_features_with_metadata_weighted_dense64.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/2D_cnn/datasets/features_with_metadata_weighted_dense128.csv...
# Accuracy  : 0.8498
# Precision : 0.7755
# Recall    : 0.8772
# F1 Score  : 0.8232
# F2 Score  : 0.8548
# Best Threshold  : 0.1
# TP: 1057, TN: 1511, FP: 306, FN: 148
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.91      0.83      0.87      1817
#            1       0.78      0.88      0.82      1205
#
#     accuracy                           0.85      3022
#    macro avg       0.84      0.85      0.85      3022
# weighted avg       0.86      0.85      0.85      3022
#
# Model saved to models/rf\rf_normal_features_with_metadata_weighted_dense128.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/2D_cnn/datasets/features_with_metadata_weighted_dense256.csv...
# Accuracy  : 0.7998
# Precision : 0.6866
# Recall    : 0.9162
# F1 Score  : 0.7849
# F2 Score  : 0.8587
# Best Threshold  : 0.11
# TP: 1104, TN: 1313, FP: 504, FN: 101
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.93      0.72      0.81      1817
#            1       0.69      0.92      0.78      1205
#
#     accuracy                           0.80      3022
#    macro avg       0.81      0.82      0.80      3022
# weighted avg       0.83      0.80      0.80      3022
#
# Model saved to models/rf\rf_normal_features_with_metadata_weighted_dense256.joblib
# Results saved to results_summary.csv

# %% [markdown]
# ### Under-sampling

# %%
train(cnn_2d_dataset_paths, "rf", "under")
# Out:
# Processing ../feature-extraction/2D_cnn/datasets/features_with_metadata_base_dense32.csv...
# Accuracy  : 0.7697
# Precision : 0.6462
# Recall    : 0.9336
# F1 Score  : 0.7637
# F2 Score  : 0.8573
# Best Threshold  : 0.13999999999999999
# TP: 1125, TN: 1201, FP: 616, FN: 80
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.66      0.78      1817
#            1       0.65      0.93      0.76      1205
#
#     accuracy                           0.77      3022
#    macro avg       0.79      0.80      0.77      3022
# weighted avg       0.82      0.77      0.77      3022
#
# Model saved to models/rf\rf_under_features_with_metadata_base_dense32.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/2D_cnn/datasets/features_with_metadata_base_dense64.csv...
# Accuracy  : 0.8537
# Precision : 0.7685
# Recall    : 0.9062
# F1 Score  : 0.8317
# F2 Score  : 0.8749
# Best Threshold  : 0.11
# TP: 1092, TN: 1488, FP: 329, FN: 113
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.93      0.82      0.87      1817
#            1       0.77      0.91      0.83      1205
#
#     accuracy                           0.85      3022
#    macro avg       0.85      0.86      0.85      3022
# weighted avg       0.87      0.85      0.86      3022
#
# Model saved to models/rf\rf_under_features_with_metadata_base_dense64.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/2D_cnn/datasets/features_with_metadata_base_dense128.csv...
# Accuracy  : 0.8657
# Precision : 0.8109
# Recall    : 0.8647
# F1 Score  : 0.8369
# F2 Score  : 0.8534
# Best Threshold  : 0.1
# TP: 1042, TN: 1574, FP: 243, FN: 163
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.91      0.87      0.89      1817
#            1       0.81      0.86      0.84      1205
#
#     accuracy                           0.87      3022
#    macro avg       0.86      0.87      0.86      3022
# weighted avg       0.87      0.87      0.87      3022
#
# Model saved to models/rf\rf_under_features_with_metadata_base_dense128.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/2D_cnn/datasets/features_with_metadata_base_dense256.csv...
# Accuracy  : 0.8021
# Precision : 0.6868
# Recall    : 0.9261
# F1 Score  : 0.7887
# F2 Score  : 0.8658
# Best Threshold  : 0.14999999999999997
# TP: 1116, TN: 1308, FP: 509, FN: 89
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.72      0.81      1817
#            1       0.69      0.93      0.79      1205
#
#     accuracy                           0.80      3022
#    macro avg       0.81      0.82      0.80      3022
# weighted avg       0.84      0.80      0.80      3022
#
# Model saved to models/rf\rf_under_features_with_metadata_base_dense256.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/2D_cnn/datasets/features_with_metadata_oversampling_dense32.csv...
# Accuracy  : 0.7965
# Precision : 0.6760
# Recall    : 0.9402
# F1 Score  : 0.7865
# F2 Score  : 0.8721
# Best Threshold  : 0.1
# TP: 1133, TN: 1274, FP: 543, FN: 72
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.95      0.70      0.81      1817
#            1       0.68      0.94      0.79      1205
#
#     accuracy                           0.80      3022
#    macro avg       0.81      0.82      0.80      3022
# weighted avg       0.84      0.80      0.80      3022
#
# Model saved to models/rf\rf_under_features_with_metadata_oversampling_dense32.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/2D_cnn/datasets/features_with_metadata_oversampling_dense64.csv...
# Accuracy  : 0.8058
# Precision : 0.6919
# Recall    : 0.9245
# F1 Score  : 0.7915
# F2 Score  : 0.8663
# Best Threshold  : 0.1
# TP: 1114, TN: 1321, FP: 496, FN: 91
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.73      0.82      1817
#            1       0.69      0.92      0.79      1205
#
#     accuracy                           0.81      3022
#    macro avg       0.81      0.83      0.80      3022
# weighted avg       0.84      0.81      0.81      3022
#
# Model saved to models/rf\rf_under_features_with_metadata_oversampling_dense64.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/2D_cnn/datasets/features_with_metadata_oversampling_dense128.csv...
# Accuracy  : 0.8028
# Precision : 0.6867
# Recall    : 0.9295
# F1 Score  : 0.7898
# F2 Score  : 0.8681
# Best Threshold  : 0.14999999999999997
# TP: 1120, TN: 1306, FP: 511, FN: 85
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.72      0.81      1817
#            1       0.69      0.93      0.79      1205
#
#     accuracy                           0.80      3022
#    macro avg       0.81      0.82      0.80      3022
# weighted avg       0.84      0.80      0.80      3022
#
# Model saved to models/rf\rf_under_features_with_metadata_oversampling_dense128.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/2D_cnn/datasets/features_with_metadata_oversampling_dense256.csv...
# Accuracy  : 0.7803
# Precision : 0.6594
# Recall    : 0.9286
# F1 Score  : 0.7712
# F2 Score  : 0.8585
# Best Threshold  : 0.16999999999999998
# TP: 1119, TN: 1239, FP: 578, FN: 86
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.68      0.79      1817
#            1       0.66      0.93      0.77      1205
#
#     accuracy                           0.78      3022
#    macro avg       0.80      0.81      0.78      3022
# weighted avg       0.83      0.78      0.78      3022
#
# Model saved to models/rf\rf_under_features_with_metadata_oversampling_dense256.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/2D_cnn/datasets/features_with_metadata_undersampling_dense32.csv...
# Accuracy  : 0.7535
# Precision : 0.6282
# Recall    : 0.9353
# F1 Score  : 0.7516
# F2 Score  : 0.8520
# Best Threshold  : 0.17999999999999997
# TP: 1127, TN: 1150, FP: 667, FN: 78
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.63      0.76      1817
#            1       0.63      0.94      0.75      1205
#
#     accuracy                           0.75      3022
#    macro avg       0.78      0.78      0.75      3022
# weighted avg       0.81      0.75      0.75      3022
#
# Model saved to models/rf\rf_under_features_with_metadata_undersampling_dense32.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/2D_cnn/datasets/features_with_metadata_undersampling_dense64.csv...
# Accuracy  : 0.7469
# Precision : 0.6228
# Recall    : 0.9261
# F1 Score  : 0.7447
# F2 Score  : 0.8439
# Best Threshold  : 0.13999999999999999
# TP: 1116, TN: 1141, FP: 676, FN: 89
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.93      0.63      0.75      1817
#            1       0.62      0.93      0.74      1205
#
#     accuracy                           0.75      3022
#    macro avg       0.78      0.78      0.75      3022
# weighted avg       0.81      0.75      0.75      3022
#
# Model saved to models/rf\rf_under_features_with_metadata_undersampling_dense64.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/2D_cnn/datasets/features_with_metadata_undersampling_dense128.csv...
# Accuracy  : 0.8154
# Precision : 0.7046
# Recall    : 0.9245
# F1 Score  : 0.7997
# F2 Score  : 0.8702
# Best Threshold  : 0.12
# TP: 1114, TN: 1350, FP: 467, FN: 91
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.74      0.83      1817
#            1       0.70      0.92      0.80      1205
#
#     accuracy                           0.82      3022
#    macro avg       0.82      0.83      0.81      3022
# weighted avg       0.84      0.82      0.82      3022
#
# Model saved to models/rf\rf_under_features_with_metadata_undersampling_dense128.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/2D_cnn/datasets/features_with_metadata_undersampling_dense256.csv...
# Accuracy  : 0.8405
# Precision : 0.7551
# Recall    : 0.8880
# F1 Score  : 0.8162
# F2 Score  : 0.8578
# Best Threshold  : 0.1
# TP: 1070, TN: 1470, FP: 347, FN: 135
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.92      0.81      0.86      1817
#            1       0.76      0.89      0.82      1205
#
#     accuracy                           0.84      3022
#    macro avg       0.84      0.85      0.84      3022
# weighted avg       0.85      0.84      0.84      3022
#
# Model saved to models/rf\rf_under_features_with_metadata_undersampling_dense256.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/2D_cnn/datasets/features_with_metadata_weighted_dense32.csv...
# Accuracy  : 0.7641
# Precision : 0.6404
# Recall    : 0.9311
# F1 Score  : 0.7589
# F2 Score  : 0.8536
# Best Threshold  : 0.13999999999999999
# TP: 1122, TN: 1187, FP: 630, FN: 83
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.93      0.65      0.77      1817
#            1       0.64      0.93      0.76      1205
#
#     accuracy                           0.76      3022
#    macro avg       0.79      0.79      0.76      3022
# weighted avg       0.82      0.76      0.76      3022
#
# Model saved to models/rf\rf_under_features_with_metadata_weighted_dense32.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/2D_cnn/datasets/features_with_metadata_weighted_dense64.csv...
# Accuracy  : 0.8375
# Precision : 0.7435
# Recall    : 0.9046
# F1 Score  : 0.8162
# F2 Score  : 0.8670
# Best Threshold  : 0.12
# TP: 1090, TN: 1441, FP: 376, FN: 115
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.93      0.79      0.85      1817
#            1       0.74      0.90      0.82      1205
#
#     accuracy                           0.84      3022
#    macro avg       0.83      0.85      0.84      3022
# weighted avg       0.85      0.84      0.84      3022
#
# Model saved to models/rf\rf_under_features_with_metadata_weighted_dense64.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/2D_cnn/datasets/features_with_metadata_weighted_dense128.csv...
# Accuracy  : 0.8385
# Precision : 0.7461
# Recall    : 0.9021
# F1 Score  : 0.8167
# F2 Score  : 0.8659
# Best Threshold  : 0.1
# TP: 1087, TN: 1447, FP: 370, FN: 118
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.92      0.80      0.86      1817
#            1       0.75      0.90      0.82      1205
#
#     accuracy                           0.84      3022
#    macro avg       0.84      0.85      0.84      3022
# weighted avg       0.85      0.84      0.84      3022
#
# Model saved to models/rf\rf_under_features_with_metadata_weighted_dense128.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/2D_cnn/datasets/features_with_metadata_weighted_dense256.csv...
# Accuracy  : 0.7806
# Precision : 0.6581
# Recall    : 0.9361
# F1 Score  : 0.7729
# F2 Score  : 0.8632
# Best Threshold  : 0.13
# TP: 1128, TN: 1231, FP: 586, FN: 77
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.68      0.79      1817
#            1       0.66      0.94      0.77      1205
#
#     accuracy                           0.78      3022
#    macro avg       0.80      0.81      0.78      3022
# weighted avg       0.83      0.78      0.78      3022
#
# Model saved to models/rf\rf_under_features_with_metadata_weighted_dense256.joblib
# Results saved to results_summary.csv

# %% [markdown]
# ### Over-sampling

# %%
train(cnn_2d_dataset_paths, "rf", "over")
# Out:
# Processing ../feature-extraction/2D_cnn/datasets/features_with_metadata_base_dense32.csv...
# Accuracy  : 0.7727
# Precision : 0.6497
# Recall    : 0.9328
# F1 Score  : 0.7659
# F2 Score  : 0.8580
# Best Threshold  : 0.1
# TP: 1124, TN: 1211, FP: 606, FN: 81
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.67      0.78      1817
#            1       0.65      0.93      0.77      1205
#
#     accuracy                           0.77      3022
#    macro avg       0.79      0.80      0.77      3022
# weighted avg       0.82      0.77      0.77      3022
#
# Model saved to models/rf\rf_over_features_with_metadata_base_dense32.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/2D_cnn/datasets/features_with_metadata_base_dense64.csv...
# Accuracy  : 0.8587
# Precision : 0.7811
# Recall    : 0.8971
# F1 Score  : 0.8351
# F2 Score  : 0.8712
# Best Threshold  : 0.1
# TP: 1081, TN: 1514, FP: 303, FN: 124
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.92      0.83      0.88      1817
#            1       0.78      0.90      0.84      1205
#
#     accuracy                           0.86      3022
#    macro avg       0.85      0.87      0.86      3022
# weighted avg       0.87      0.86      0.86      3022
#
# Model saved to models/rf\rf_over_features_with_metadata_base_dense64.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/2D_cnn/datasets/features_with_metadata_base_dense128.csv...
# Accuracy  : 0.8657
# Precision : 0.8071
# Recall    : 0.8714
# F1 Score  : 0.8380
# F2 Score  : 0.8577
# Best Threshold  : 0.1
# TP: 1050, TN: 1566, FP: 251, FN: 155
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.91      0.86      0.89      1817
#            1       0.81      0.87      0.84      1205
#
#     accuracy                           0.87      3022
#    macro avg       0.86      0.87      0.86      3022
# weighted avg       0.87      0.87      0.87      3022
#
# Model saved to models/rf\rf_over_features_with_metadata_base_dense128.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/2D_cnn/datasets/features_with_metadata_base_dense256.csv...
# Accuracy  : 0.8167
# Precision : 0.7080
# Recall    : 0.9195
# F1 Score  : 0.8000
# F2 Score  : 0.8677
# Best Threshold  : 0.13
# TP: 1108, TN: 1360, FP: 457, FN: 97
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.93      0.75      0.83      1817
#            1       0.71      0.92      0.80      1205
#
#     accuracy                           0.82      3022
#    macro avg       0.82      0.83      0.82      3022
# weighted avg       0.84      0.82      0.82      3022
#
# Model saved to models/rf\rf_over_features_with_metadata_base_dense256.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/2D_cnn/datasets/features_with_metadata_oversampling_dense32.csv...
# Accuracy  : 0.8147
# Precision : 0.7045
# Recall    : 0.9220
# F1 Score  : 0.7987
# F2 Score  : 0.8684
# Best Threshold  : 0.1
# TP: 1111, TN: 1351, FP: 466, FN: 94
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.93      0.74      0.83      1817
#            1       0.70      0.92      0.80      1205
#
#     accuracy                           0.81      3022
#    macro avg       0.82      0.83      0.81      3022
# weighted avg       0.84      0.81      0.82      3022
#
# Model saved to models/rf\rf_over_features_with_metadata_oversampling_dense32.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/2D_cnn/datasets/features_with_metadata_oversampling_dense64.csv...
# Accuracy  : 0.8250
# Precision : 0.7235
# Recall    : 0.9079
# F1 Score  : 0.8053
# F2 Score  : 0.8639
# Best Threshold  : 0.1
# TP: 1094, TN: 1399, FP: 418, FN: 111
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.93      0.77      0.84      1817
#            1       0.72      0.91      0.81      1205
#
#     accuracy                           0.82      3022
#    macro avg       0.83      0.84      0.82      3022
# weighted avg       0.85      0.82      0.83      3022
#
# Model saved to models/rf\rf_over_features_with_metadata_oversampling_dense64.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/2D_cnn/datasets/features_with_metadata_oversampling_dense128.csv...
# Accuracy  : 0.7955
# Precision : 0.6769
# Recall    : 0.9320
# F1 Score  : 0.7842
# F2 Score  : 0.8666
# Best Threshold  : 0.1
# TP: 1123, TN: 1281, FP: 536, FN: 82
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.71      0.81      1817
#            1       0.68      0.93      0.78      1205
#
#     accuracy                           0.80      3022
#    macro avg       0.81      0.82      0.79      3022
# weighted avg       0.83      0.80      0.80      3022
#
# Model saved to models/rf\rf_over_features_with_metadata_oversampling_dense128.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/2D_cnn/datasets/features_with_metadata_oversampling_dense256.csv...
# Accuracy  : 0.7919
# Precision : 0.6758
# Recall    : 0.9187
# F1 Score  : 0.7788
# F2 Score  : 0.8571
# Best Threshold  : 0.13999999999999999
# TP: 1107, TN: 1286, FP: 531, FN: 98
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.93      0.71      0.80      1817
#            1       0.68      0.92      0.78      1205
#
#     accuracy                           0.79      3022
#    macro avg       0.80      0.81      0.79      3022
# weighted avg       0.83      0.79      0.79      3022
#
# Model saved to models/rf\rf_over_features_with_metadata_oversampling_dense256.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/2D_cnn/datasets/features_with_metadata_undersampling_dense32.csv...
# Accuracy  : 0.7498
# Precision : 0.6231
# Recall    : 0.9427
# F1 Score  : 0.7503
# F2 Score  : 0.8550
# Best Threshold  : 0.12
# TP: 1136, TN: 1130, FP: 687, FN: 69
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.62      0.75      1817
#            1       0.62      0.94      0.75      1205
#
#     accuracy                           0.75      3022
#    macro avg       0.78      0.78      0.75      3022
# weighted avg       0.82      0.75      0.75      3022
#
# Model saved to models/rf\rf_over_features_with_metadata_undersampling_dense32.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/2D_cnn/datasets/features_with_metadata_undersampling_dense64.csv...
# Accuracy  : 0.7531
# Precision : 0.6300
# Recall    : 0.9228
# F1 Score  : 0.7488
# F2 Score  : 0.8443
# Best Threshold  : 0.1
# TP: 1112, TN: 1164, FP: 653, FN: 93
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.93      0.64      0.76      1817
#            1       0.63      0.92      0.75      1205
#
#     accuracy                           0.75      3022
#    macro avg       0.78      0.78      0.75      3022
# weighted avg       0.81      0.75      0.75      3022
#
# Model saved to models/rf\rf_over_features_with_metadata_undersampling_dense64.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/2D_cnn/datasets/features_with_metadata_undersampling_dense128.csv...
# Accuracy  : 0.8256
# Precision : 0.7230
# Recall    : 0.9120
# F1 Score  : 0.8066
# F2 Score  : 0.8667
# Best Threshold  : 0.1
# TP: 1099, TN: 1396, FP: 421, FN: 106
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.93      0.77      0.84      1817
#            1       0.72      0.91      0.81      1205
#
#     accuracy                           0.83      3022
#    macro avg       0.83      0.84      0.82      3022
# weighted avg       0.85      0.83      0.83      3022
#
# Model saved to models/rf\rf_over_features_with_metadata_undersampling_dense128.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/2D_cnn/datasets/features_with_metadata_undersampling_dense256.csv...
# Accuracy  : 0.8458
# Precision : 0.7637
# Recall    : 0.8880
# F1 Score  : 0.8212
# F2 Score  : 0.8600
# Best Threshold  : 0.1
# TP: 1070, TN: 1486, FP: 331, FN: 135
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.92      0.82      0.86      1817
#            1       0.76      0.89      0.82      1205
#
#     accuracy                           0.85      3022
#    macro avg       0.84      0.85      0.84      3022
# weighted avg       0.86      0.85      0.85      3022
#
# Model saved to models/rf\rf_over_features_with_metadata_undersampling_dense256.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/2D_cnn/datasets/features_with_metadata_weighted_dense32.csv...
# Accuracy  : 0.7578
# Precision : 0.6329
# Recall    : 0.9344
# F1 Score  : 0.7547
# F2 Score  : 0.8532
# Best Threshold  : 0.1
# TP: 1126, TN: 1164, FP: 653, FN: 79
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.64      0.76      1817
#            1       0.63      0.93      0.75      1205
#
#     accuracy                           0.76      3022
#    macro avg       0.78      0.79      0.76      3022
# weighted avg       0.82      0.76      0.76      3022
#
# Model saved to models/rf\rf_over_features_with_metadata_weighted_dense32.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/2D_cnn/datasets/features_with_metadata_weighted_dense64.csv...
# Accuracy  : 0.8432
# Precision : 0.7558
# Recall    : 0.8963
# F1 Score  : 0.8200
# F2 Score  : 0.8641
# Best Threshold  : 0.11
# TP: 1080, TN: 1468, FP: 349, FN: 125
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.92      0.81      0.86      1817
#            1       0.76      0.90      0.82      1205
#
#     accuracy                           0.84      3022
#    macro avg       0.84      0.85      0.84      3022
# weighted avg       0.86      0.84      0.84      3022
#
# Model saved to models/rf\rf_over_features_with_metadata_weighted_dense64.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/2D_cnn/datasets/features_with_metadata_weighted_dense128.csv...
# Accuracy  : 0.8451
# Precision : 0.7604
# Recall    : 0.8929
# F1 Score  : 0.8214
# F2 Score  : 0.8629
# Best Threshold  : 0.1
# TP: 1076, TN: 1478, FP: 339, FN: 129
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.92      0.81      0.86      1817
#            1       0.76      0.89      0.82      1205
#
#     accuracy                           0.85      3022
#    macro avg       0.84      0.85      0.84      3022
# weighted avg       0.86      0.85      0.85      3022
#
# Model saved to models/rf\rf_over_features_with_metadata_weighted_dense128.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/2D_cnn/datasets/features_with_metadata_weighted_dense256.csv...
# Accuracy  : 0.7922
# Precision : 0.6733
# Recall    : 0.9303
# F1 Score  : 0.7812
# F2 Score  : 0.8643
# Best Threshold  : 0.1
# TP: 1121, TN: 1273, FP: 544, FN: 84
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.70      0.80      1817
#            1       0.67      0.93      0.78      1205
#
#     accuracy                           0.79      3022
#    macro avg       0.81      0.82      0.79      3022
# weighted avg       0.83      0.79      0.79      3022
#
# Model saved to models/rf\rf_over_features_with_metadata_weighted_dense256.joblib
# Results saved to results_summary.csv

# %% [markdown]
# ### Weighted

# %%
train(cnn_2d_dataset_paths, "rf", "weighted")
# Out:
# Processing ../feature-extraction/2D_cnn/datasets/features_with_metadata_base_dense32.csv...
# Accuracy  : 0.7905
# Precision : 0.6744
# Recall    : 0.9178
# F1 Score  : 0.7775
# F2 Score  : 0.8560
# Best Threshold  : 0.12
# TP: 1106, TN: 1283, FP: 534, FN: 99
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.93      0.71      0.80      1817
#            1       0.67      0.92      0.78      1205
#
#     accuracy                           0.79      3022
#    macro avg       0.80      0.81      0.79      3022
# weighted avg       0.83      0.79      0.79      3022
#
# Model saved to models/rf\rf_weighted_features_with_metadata_base_dense32.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/2D_cnn/datasets/features_with_metadata_base_dense64.csv...
# Accuracy  : 0.8597
# Precision : 0.7890
# Recall    : 0.8846
# F1 Score  : 0.8341
# F2 Score  : 0.8637
# Best Threshold  : 0.1
# TP: 1066, TN: 1532, FP: 285, FN: 139
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.92      0.84      0.88      1817
#            1       0.79      0.88      0.83      1205
#
#     accuracy                           0.86      3022
#    macro avg       0.85      0.86      0.86      3022
# weighted avg       0.87      0.86      0.86      3022
#
# Model saved to models/rf\rf_weighted_features_with_metadata_base_dense64.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/2D_cnn/datasets/features_with_metadata_base_dense128.csv...
# Accuracy  : 0.8690
# Precision : 0.8270
# Recall    : 0.8490
# F1 Score  : 0.8378
# F2 Score  : 0.8445
# Best Threshold  : 0.11
# TP: 1023, TN: 1603, FP: 214, FN: 182
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.90      0.88      0.89      1817
#            1       0.83      0.85      0.84      1205
#
#     accuracy                           0.87      3022
#    macro avg       0.86      0.87      0.86      3022
# weighted avg       0.87      0.87      0.87      3022
#
# Model saved to models/rf\rf_weighted_features_with_metadata_base_dense128.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/2D_cnn/datasets/features_with_metadata_base_dense256.csv...
# Accuracy  : 0.8206
# Precision : 0.7165
# Recall    : 0.9104
# F1 Score  : 0.8019
# F2 Score  : 0.8636
# Best Threshold  : 0.12
# TP: 1097, TN: 1383, FP: 434, FN: 108
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.93      0.76      0.84      1817
#            1       0.72      0.91      0.80      1205
#
#     accuracy                           0.82      3022
#    macro avg       0.82      0.84      0.82      3022
# weighted avg       0.84      0.82      0.82      3022
#
# Model saved to models/rf\rf_weighted_features_with_metadata_base_dense256.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/2D_cnn/datasets/features_with_metadata_oversampling_dense32.csv...
# Accuracy  : 0.8187
# Precision : 0.7115
# Recall    : 0.9170
# F1 Score  : 0.8013
# F2 Score  : 0.8669
# Best Threshold  : 0.1
# TP: 1105, TN: 1369, FP: 448, FN: 100
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.93      0.75      0.83      1817
#            1       0.71      0.92      0.80      1205
#
#     accuracy                           0.82      3022
#    macro avg       0.82      0.84      0.82      3022
# weighted avg       0.84      0.82      0.82      3022
#
# Model saved to models/rf\rf_weighted_features_with_metadata_oversampling_dense32.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/2D_cnn/datasets/features_with_metadata_oversampling_dense64.csv...
# Accuracy  : 0.8309
# Precision : 0.7348
# Recall    : 0.9012
# F1 Score  : 0.8095
# F2 Score  : 0.8622
# Best Threshold  : 0.1
# TP: 1086, TN: 1425, FP: 392, FN: 119
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.92      0.78      0.85      1817
#            1       0.73      0.90      0.81      1205
#
#     accuracy                           0.83      3022
#    macro avg       0.83      0.84      0.83      3022
# weighted avg       0.85      0.83      0.83      3022
#
# Model saved to models/rf\rf_weighted_features_with_metadata_oversampling_dense64.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/2D_cnn/datasets/features_with_metadata_oversampling_dense128.csv...
# Accuracy  : 0.7985
# Precision : 0.6813
# Recall    : 0.9295
# F1 Score  : 0.7862
# F2 Score  : 0.8663
# Best Threshold  : 0.1
# TP: 1120, TN: 1293, FP: 524, FN: 85
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.71      0.81      1817
#            1       0.68      0.93      0.79      1205
#
#     accuracy                           0.80      3022
#    macro avg       0.81      0.82      0.80      3022
# weighted avg       0.84      0.80      0.80      3022
#
# Model saved to models/rf\rf_weighted_features_with_metadata_oversampling_dense128.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/2D_cnn/datasets/features_with_metadata_oversampling_dense256.csv...
# Accuracy  : 0.7942
# Precision : 0.6776
# Recall    : 0.9228
# F1 Score  : 0.7814
# F2 Score  : 0.8605
# Best Threshold  : 0.13
# TP: 1112, TN: 1288, FP: 529, FN: 93
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.93      0.71      0.81      1817
#            1       0.68      0.92      0.78      1205
#
#     accuracy                           0.79      3022
#    macro avg       0.81      0.82      0.79      3022
# weighted avg       0.83      0.79      0.80      3022
#
# Model saved to models/rf\rf_weighted_features_with_metadata_oversampling_dense256.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/2D_cnn/datasets/features_with_metadata_undersampling_dense32.csv...
# Accuracy  : 0.7210
# Precision : 0.5938
# Recall    : 0.9510
# F1 Score  : 0.7311
# F2 Score  : 0.8489
# Best Threshold  : 0.1
# TP: 1146, TN: 1033, FP: 784, FN: 59
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.95      0.57      0.71      1817
#            1       0.59      0.95      0.73      1205
#
#     accuracy                           0.72      3022
#    macro avg       0.77      0.76      0.72      3022
# weighted avg       0.81      0.72      0.72      3022
#
# Model saved to models/rf\rf_weighted_features_with_metadata_undersampling_dense32.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/2D_cnn/datasets/features_with_metadata_undersampling_dense64.csv...
# Accuracy  : 0.7528
# Precision : 0.6297
# Recall    : 0.9228
# F1 Score  : 0.7486
# F2 Score  : 0.8442
# Best Threshold  : 0.1
# TP: 1112, TN: 1163, FP: 654, FN: 93
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.93      0.64      0.76      1817
#            1       0.63      0.92      0.75      1205
#
#     accuracy                           0.75      3022
#    macro avg       0.78      0.78      0.75      3022
# weighted avg       0.81      0.75      0.75      3022
#
# Model saved to models/rf\rf_weighted_features_with_metadata_undersampling_dense64.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/2D_cnn/datasets/features_with_metadata_undersampling_dense128.csv...
# Accuracy  : 0.8266
# Precision : 0.7259
# Recall    : 0.9079
# F1 Score  : 0.8068
# F2 Score  : 0.8645
# Best Threshold  : 0.1
# TP: 1094, TN: 1404, FP: 413, FN: 111
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.93      0.77      0.84      1817
#            1       0.73      0.91      0.81      1205
#
#     accuracy                           0.83      3022
#    macro avg       0.83      0.84      0.82      3022
# weighted avg       0.85      0.83      0.83      3022
#
# Model saved to models/rf\rf_weighted_features_with_metadata_undersampling_dense128.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/2D_cnn/datasets/features_with_metadata_undersampling_dense256.csv...
# Accuracy  : 0.8527
# Precision : 0.7866
# Recall    : 0.8656
# F1 Score  : 0.8242
# F2 Score  : 0.8485
# Best Threshold  : 0.11
# TP: 1043, TN: 1534, FP: 283, FN: 162
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.90      0.84      0.87      1817
#            1       0.79      0.87      0.82      1205
#
#     accuracy                           0.85      3022
#    macro avg       0.85      0.85      0.85      3022
# weighted avg       0.86      0.85      0.85      3022
#
# Model saved to models/rf\rf_weighted_features_with_metadata_undersampling_dense256.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/2D_cnn/datasets/features_with_metadata_weighted_dense32.csv...
# Accuracy  : 0.7677
# Precision : 0.6455
# Recall    : 0.9261
# F1 Score  : 0.7607
# F2 Score  : 0.8520
# Best Threshold  : 0.1
# TP: 1116, TN: 1204, FP: 613, FN: 89
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.93      0.66      0.77      1817
#            1       0.65      0.93      0.76      1205
#
#     accuracy                           0.77      3022
#    macro avg       0.79      0.79      0.77      3022
# weighted avg       0.82      0.77      0.77      3022
#
# Model saved to models/rf\rf_weighted_features_with_metadata_weighted_dense32.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/2D_cnn/datasets/features_with_metadata_weighted_dense64.csv...
# Accuracy  : 0.8455
# Precision : 0.7610
# Recall    : 0.8929
# F1 Score  : 0.8217
# F2 Score  : 0.8630
# Best Threshold  : 0.1
# TP: 1076, TN: 1479, FP: 338, FN: 129
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.92      0.81      0.86      1817
#            1       0.76      0.89      0.82      1205
#
#     accuracy                           0.85      3022
#    macro avg       0.84      0.85      0.84      3022
# weighted avg       0.86      0.85      0.85      3022
#
# Model saved to models/rf\rf_weighted_features_with_metadata_weighted_dense64.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/2D_cnn/datasets/features_with_metadata_weighted_dense128.csv...
# Accuracy  : 0.8484
# Precision : 0.7716
# Recall    : 0.8805
# F1 Score  : 0.8225
# F2 Score  : 0.8563
# Best Threshold  : 0.1
# TP: 1061, TN: 1503, FP: 314, FN: 144
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.91      0.83      0.87      1817
#            1       0.77      0.88      0.82      1205
#
#     accuracy                           0.85      3022
#    macro avg       0.84      0.85      0.85      3022
# weighted avg       0.86      0.85      0.85      3022
#
# Model saved to models/rf\rf_weighted_features_with_metadata_weighted_dense128.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/2D_cnn/datasets/features_with_metadata_weighted_dense256.csv...
# Accuracy  : 0.7919
# Precision : 0.6743
# Recall    : 0.9245
# F1 Score  : 0.7798
# F2 Score  : 0.8606
# Best Threshold  : 0.1
# TP: 1114, TN: 1279, FP: 538, FN: 91
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.93      0.70      0.80      1817
#            1       0.67      0.92      0.78      1205
#
#     accuracy                           0.79      3022
#    macro avg       0.80      0.81      0.79      3022
# weighted avg       0.83      0.79      0.79      3022
#
# Model saved to models/rf\rf_weighted_features_with_metadata_weighted_dense256.joblib
# Results saved to results_summary.csv

# %% [markdown]
# ## Residual

# %% [markdown]
# ### Datasets

# %%
residual_dataset_paths = [
    "../feature-extraction/residual_cnn/datasets/normal_residual_cnn_features_32.csv",
    "../feature-extraction/residual_cnn/datasets/normal_residual_cnn_features_64.csv",
    "../feature-extraction/residual_cnn/datasets/normal_residual_cnn_features_128.csv",
    "../feature-extraction/residual_cnn/datasets/normal_residual_cnn_features_256.csv",
    "../feature-extraction/residual_cnn/datasets/over_sampled_residual_cnn_features_32.csv",
    "../feature-extraction/residual_cnn/datasets/over_sampled_residual_cnn_features_64.csv",
    "../feature-extraction/residual_cnn/datasets/over_sampled_residual_cnn_features_128.csv",
    "../feature-extraction/residual_cnn/datasets/over_sampled_residual_cnn_features_256.csv",
    "../feature-extraction/residual_cnn/datasets/under_sampled_residual_cnn_features_32.csv",
    "../feature-extraction/residual_cnn/datasets/under_sampled_residual_cnn_features_64.csv",
    "../feature-extraction/residual_cnn/datasets/under_sampled_residual_cnn_features_128.csv",
    "../feature-extraction/residual_cnn/datasets/under_sampled_residual_cnn_features_256.csv",
    "../feature-extraction/residual_cnn/datasets/weighted_residual_cnn_features_32.csv",
    "../feature-extraction/residual_cnn/datasets/weighted_residual_cnn_features_64.csv",
    "../feature-extraction/residual_cnn/datasets/weighted_residual_cnn_features_128.csv",
    "../feature-extraction/residual_cnn/datasets/weighted_residual_cnn_features_256.csv",

]

# %% [markdown]
# ### Imbalanced

# %%
train(residual_dataset_paths, "rf", "normal")
# Out:
# Processing ../feature-extraction/residual_cnn/datasets/normal_residual_cnn_features_32.csv...
# Accuracy  : 0.8451
# Precision : 0.7509
# Recall    : 0.9154
# F1 Score  : 0.8250
# F2 Score  : 0.8769
# Best Threshold  : 0.16999999999999998
# TP: 1103, TN: 1451, FP: 366, FN: 102
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.93      0.80      0.86      1817
#            1       0.75      0.92      0.82      1205
#
#     accuracy                           0.85      3022
#    macro avg       0.84      0.86      0.84      3022
# weighted avg       0.86      0.85      0.85      3022
#
# Model saved to models/rf\rf_normal_normal_residual_cnn_features_32.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/normal_residual_cnn_features_64.csv...
# Accuracy  : 0.8319
# Precision : 0.7264
# Recall    : 0.9278
# F1 Score  : 0.8149
# F2 Score  : 0.8791
# Best Threshold  : 0.15999999999999998
# TP: 1118, TN: 1396, FP: 421, FN: 87
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.77      0.85      1817
#            1       0.73      0.93      0.81      1205
#
#     accuracy                           0.83      3022
#    macro avg       0.83      0.85      0.83      3022
# weighted avg       0.86      0.83      0.83      3022
#
# Model saved to models/rf\rf_normal_normal_residual_cnn_features_64.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/normal_residual_cnn_features_128.csv...
# Accuracy  : 0.8167
# Precision : 0.7046
# Recall    : 0.9303
# F1 Score  : 0.8019
# F2 Score  : 0.8743
# Best Threshold  : 0.14999999999999997
# TP: 1121, TN: 1347, FP: 470, FN: 84
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.74      0.83      1817
#            1       0.70      0.93      0.80      1205
#
#     accuracy                           0.82      3022
#    macro avg       0.82      0.84      0.82      3022
# weighted avg       0.85      0.82      0.82      3022
#
# Model saved to models/rf\rf_normal_normal_residual_cnn_features_128.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/normal_residual_cnn_features_256.csv...
# Accuracy  : 0.8048
# Precision : 0.6854
# Recall    : 0.9436
# F1 Score  : 0.7940
# F2 Score  : 0.8775
# Best Threshold  : 0.12
# TP: 1137, TN: 1295, FP: 522, FN: 68
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.95      0.71      0.81      1817
#            1       0.69      0.94      0.79      1205
#
#     accuracy                           0.80      3022
#    macro avg       0.82      0.83      0.80      3022
# weighted avg       0.84      0.80      0.81      3022
#
# Model saved to models/rf\rf_normal_normal_residual_cnn_features_256.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/over_sampled_residual_cnn_features_32.csv...
# Accuracy  : 0.8286
# Precision : 0.7124
# Recall    : 0.9560
# F1 Score  : 0.8164
# F2 Score  : 0.8948
# Best Threshold  : 0.1
# TP: 1152, TN: 1352, FP: 465, FN: 53
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.96      0.74      0.84      1817
#            1       0.71      0.96      0.82      1205
#
#     accuracy                           0.83      3022
#    macro avg       0.84      0.85      0.83      3022
# weighted avg       0.86      0.83      0.83      3022
#
# Model saved to models/rf\rf_normal_over_sampled_residual_cnn_features_32.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/over_sampled_residual_cnn_features_64.csv...
# Accuracy  : 0.8547
# Precision : 0.7675
# Recall    : 0.9120
# F1 Score  : 0.8335
# F2 Score  : 0.8789
# Best Threshold  : 0.21999999999999995
# TP: 1099, TN: 1484, FP: 333, FN: 106
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.93      0.82      0.87      1817
#            1       0.77      0.91      0.83      1205
#
#     accuracy                           0.85      3022
#    macro avg       0.85      0.86      0.85      3022
# weighted avg       0.87      0.85      0.86      3022
#
# Model saved to models/rf\rf_normal_over_sampled_residual_cnn_features_64.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/over_sampled_residual_cnn_features_128.csv...
# Accuracy  : 0.8263
# Precision : 0.7141
# Recall    : 0.9411
# F1 Score  : 0.8120
# F2 Score  : 0.8848
# Best Threshold  : 0.13999999999999999
# TP: 1134, TN: 1363, FP: 454, FN: 71
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.95      0.75      0.84      1817
#            1       0.71      0.94      0.81      1205
#
#     accuracy                           0.83      3022
#    macro avg       0.83      0.85      0.83      3022
# weighted avg       0.86      0.83      0.83      3022
#
# Model saved to models/rf\rf_normal_over_sampled_residual_cnn_features_128.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/over_sampled_residual_cnn_features_256.csv...
# Accuracy  : 0.8144
# Precision : 0.6983
# Recall    : 0.9411
# F1 Score  : 0.8017
# F2 Score  : 0.8799
# Best Threshold  : 0.12
# TP: 1134, TN: 1327, FP: 490, FN: 71
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.95      0.73      0.83      1817
#            1       0.70      0.94      0.80      1205
#
#     accuracy                           0.81      3022
#    macro avg       0.82      0.84      0.81      3022
# weighted avg       0.85      0.81      0.82      3022
#
# Model saved to models/rf\rf_normal_over_sampled_residual_cnn_features_256.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/under_sampled_residual_cnn_features_32.csv...
# Accuracy  : 0.8087
# Precision : 0.6924
# Recall    : 0.9361
# F1 Score  : 0.7960
# F2 Score  : 0.8746
# Best Threshold  : 0.14999999999999997
# TP: 1128, TN: 1316, FP: 501, FN: 77
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.72      0.82      1817
#            1       0.69      0.94      0.80      1205
#
#     accuracy                           0.81      3022
#    macro avg       0.82      0.83      0.81      3022
# weighted avg       0.84      0.81      0.81      3022
#
# Model saved to models/rf\rf_normal_under_sampled_residual_cnn_features_32.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/under_sampled_residual_cnn_features_64.csv...
# Accuracy  : 0.7895
# Precision : 0.6659
# Recall    : 0.9477
# F1 Score  : 0.7822
# F2 Score  : 0.8738
# Best Threshold  : 0.11
# TP: 1142, TN: 1244, FP: 573, FN: 63
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.95      0.68      0.80      1817
#            1       0.67      0.95      0.78      1205
#
#     accuracy                           0.79      3022
#    macro avg       0.81      0.82      0.79      3022
# weighted avg       0.84      0.79      0.79      3022
#
# Model saved to models/rf\rf_normal_under_sampled_residual_cnn_features_64.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/under_sampled_residual_cnn_features_128.csv...
# Accuracy  : 0.8273
# Precision : 0.7196
# Recall    : 0.9286
# F1 Score  : 0.8109
# F2 Score  : 0.8776
# Best Threshold  : 0.13999999999999999
# TP: 1119, TN: 1381, FP: 436, FN: 86
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.76      0.84      1817
#            1       0.72      0.93      0.81      1205
#
#     accuracy                           0.83      3022
#    macro avg       0.83      0.84      0.83      3022
# weighted avg       0.85      0.83      0.83      3022
#
# Model saved to models/rf\rf_normal_under_sampled_residual_cnn_features_128.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/under_sampled_residual_cnn_features_256.csv...
# Accuracy  : 0.8425
# Precision : 0.7403
# Recall    : 0.9320
# F1 Score  : 0.8251
# F2 Score  : 0.8861
# Best Threshold  : 0.14999999999999997
# TP: 1123, TN: 1423, FP: 394, FN: 82
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.95      0.78      0.86      1817
#            1       0.74      0.93      0.83      1205
#
#     accuracy                           0.84      3022
#    macro avg       0.84      0.86      0.84      3022
# weighted avg       0.86      0.84      0.84      3022
#
# Model saved to models/rf\rf_normal_under_sampled_residual_cnn_features_256.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/weighted_residual_cnn_features_32.csv...
# Accuracy  : 0.8074
# Precision : 0.6875
# Recall    : 0.9477
# F1 Score  : 0.7969
# F2 Score  : 0.8810
# Best Threshold  : 0.11
# TP: 1142, TN: 1298, FP: 519, FN: 63
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.95      0.71      0.82      1817
#            1       0.69      0.95      0.80      1205
#
#     accuracy                           0.81      3022
#    macro avg       0.82      0.83      0.81      3022
# weighted avg       0.85      0.81      0.81      3022
#
# Model saved to models/rf\rf_normal_weighted_residual_cnn_features_32.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/weighted_residual_cnn_features_64.csv...
# Accuracy  : 0.7892
# Precision : 0.6675
# Recall    : 0.9394
# F1 Score  : 0.7804
# F2 Score  : 0.8686
# Best Threshold  : 0.13999999999999999
# TP: 1132, TN: 1253, FP: 564, FN: 73
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.69      0.80      1817
#            1       0.67      0.94      0.78      1205
#
#     accuracy                           0.79      3022
#    macro avg       0.81      0.81      0.79      3022
# weighted avg       0.83      0.79      0.79      3022
#
# Model saved to models/rf\rf_normal_weighted_residual_cnn_features_64.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/weighted_residual_cnn_features_128.csv...
# Accuracy  : 0.8071
# Precision : 0.6865
# Recall    : 0.9502
# F1 Score  : 0.7971
# F2 Score  : 0.8824
# Best Threshold  : 0.12
# TP: 1145, TN: 1294, FP: 523, FN: 60
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.96      0.71      0.82      1817
#            1       0.69      0.95      0.80      1205
#
#     accuracy                           0.81      3022
#    macro avg       0.82      0.83      0.81      3022
# weighted avg       0.85      0.81      0.81      3022
#
# Model saved to models/rf\rf_normal_weighted_residual_cnn_features_128.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/weighted_residual_cnn_features_256.csv...
# Accuracy  : 0.8024
# Precision : 0.6829
# Recall    : 0.9419
# F1 Score  : 0.7918
# F2 Score  : 0.8755
# Best Threshold  : 0.13
# TP: 1135, TN: 1290, FP: 527, FN: 70
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.95      0.71      0.81      1817
#            1       0.68      0.94      0.79      1205
#
#     accuracy                           0.80      3022
#    macro avg       0.82      0.83      0.80      3022
# weighted avg       0.84      0.80      0.80      3022
#
# Model saved to models/rf\rf_normal_weighted_residual_cnn_features_256.joblib
# Results saved to results_summary.csv

# %% [markdown]
# ### Under-Sampled

# %%
train(residual_dataset_paths, "rf", "under")
# Out:
# Processing ../feature-extraction/residual_cnn/datasets/normal_residual_cnn_features_32.csv...
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:484: FutureWarning: `BaseEstimator._check_n_features` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation._check_n_features` instead.
#   warnings.warn(
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:493: FutureWarning: `BaseEstimator._check_feature_names` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation._check_feature_names` instead.
#   warnings.warn(
# Accuracy  : 0.8263
# Precision : 0.7171
# Recall    : 0.9320
# F1 Score  : 0.8105
# F2 Score  : 0.8793
# Best Threshold  : 0.19999999999999996
# TP: 1123, TN: 1374, FP: 443, FN: 82
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.76      0.84      1817
#            1       0.72      0.93      0.81      1205
#
#     accuracy                           0.83      3022
#    macro avg       0.83      0.84      0.83      3022
# weighted avg       0.85      0.83      0.83      3022
#
# Model saved to models/rf\rf_under_normal_residual_cnn_features_32.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/normal_residual_cnn_features_64.csv...
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:484: FutureWarning: `BaseEstimator._check_n_features` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation._check_n_features` instead.
#   warnings.warn(
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:493: FutureWarning: `BaseEstimator._check_feature_names` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation._check_feature_names` instead.
#   warnings.warn(
# Accuracy  : 0.8402
# Precision : 0.7416
# Recall    : 0.9195
# F1 Score  : 0.8210
# F2 Score  : 0.8774
# Best Threshold  : 0.2599999999999999
# TP: 1108, TN: 1431, FP: 386, FN: 97
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.79      0.86      1817
#            1       0.74      0.92      0.82      1205
#
#     accuracy                           0.84      3022
#    macro avg       0.84      0.85      0.84      3022
# weighted avg       0.86      0.84      0.84      3022
#
# Model saved to models/rf\rf_under_normal_residual_cnn_features_64.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/normal_residual_cnn_features_128.csv...
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:484: FutureWarning: `BaseEstimator._check_n_features` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation._check_n_features` instead.
#   warnings.warn(
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:493: FutureWarning: `BaseEstimator._check_feature_names` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation._check_feature_names` instead.
#   warnings.warn(
# Accuracy  : 0.8147
# Precision : 0.7009
# Recall    : 0.9336
# F1 Score  : 0.8007
# F2 Score  : 0.8755
# Best Threshold  : 0.21999999999999995
# TP: 1125, TN: 1337, FP: 480, FN: 80
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.74      0.83      1817
#            1       0.70      0.93      0.80      1205
#
#     accuracy                           0.81      3022
#    macro avg       0.82      0.83      0.81      3022
# weighted avg       0.85      0.81      0.82      3022
#
# Model saved to models/rf\rf_under_normal_residual_cnn_features_128.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/normal_residual_cnn_features_256.csv...
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:484: FutureWarning: `BaseEstimator._check_n_features` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation._check_n_features` instead.
#   warnings.warn(
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:493: FutureWarning: `BaseEstimator._check_feature_names` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation._check_feature_names` instead.
#   warnings.warn(
# Accuracy  : 0.7952
# Precision : 0.6724
# Recall    : 0.9485
# F1 Score  : 0.7869
# F2 Score  : 0.8765
# Best Threshold  : 0.15999999999999998
# TP: 1143, TN: 1260, FP: 557, FN: 62
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.95      0.69      0.80      1817
#            1       0.67      0.95      0.79      1205
#
#     accuracy                           0.80      3022
#    macro avg       0.81      0.82      0.79      3022
# weighted avg       0.84      0.80      0.80      3022
#
# Model saved to models/rf\rf_under_normal_residual_cnn_features_256.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/over_sampled_residual_cnn_features_32.csv...
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:484: FutureWarning: `BaseEstimator._check_n_features` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation._check_n_features` instead.
#   warnings.warn(
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:493: FutureWarning: `BaseEstimator._check_feature_names` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation._check_feature_names` instead.
#   warnings.warn(
# Accuracy  : 0.8220
# Precision : 0.7035
# Recall    : 0.9568
# F1 Score  : 0.8108
# F2 Score  : 0.8926
# Best Threshold  : 0.13999999999999999
# TP: 1153, TN: 1331, FP: 486, FN: 52
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.96      0.73      0.83      1817
#            1       0.70      0.96      0.81      1205
#
#     accuracy                           0.82      3022
#    macro avg       0.83      0.84      0.82      3022
# weighted avg       0.86      0.82      0.82      3022
#
# Model saved to models/rf\rf_under_over_sampled_residual_cnn_features_32.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/over_sampled_residual_cnn_features_64.csv...
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:484: FutureWarning: `BaseEstimator._check_n_features` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation._check_n_features` instead.
#   warnings.warn(
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:493: FutureWarning: `BaseEstimator._check_feature_names` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation._check_feature_names` instead.
#   warnings.warn(
# Accuracy  : 0.8428
# Precision : 0.7450
# Recall    : 0.9212
# F1 Score  : 0.8237
# F2 Score  : 0.8796
# Best Threshold  : 0.2899999999999999
# TP: 1110, TN: 1437, FP: 380, FN: 95
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.79      0.86      1817
#            1       0.74      0.92      0.82      1205
#
#     accuracy                           0.84      3022
#    macro avg       0.84      0.86      0.84      3022
# weighted avg       0.86      0.84      0.84      3022
#
# Model saved to models/rf\rf_under_over_sampled_residual_cnn_features_64.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/over_sampled_residual_cnn_features_128.csv...
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:484: FutureWarning: `BaseEstimator._check_n_features` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation._check_n_features` instead.
#   warnings.warn(
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:493: FutureWarning: `BaseEstimator._check_feature_names` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation._check_feature_names` instead.
#   warnings.warn(
# Accuracy  : 0.8226
# Precision : 0.7095
# Recall    : 0.9402
# F1 Score  : 0.8087
# F2 Score  : 0.8828
# Best Threshold  : 0.19999999999999996
# TP: 1133, TN: 1353, FP: 464, FN: 72
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.95      0.74      0.83      1817
#            1       0.71      0.94      0.81      1205
#
#     accuracy                           0.82      3022
#    macro avg       0.83      0.84      0.82      3022
# weighted avg       0.85      0.82      0.82      3022
#
# Model saved to models/rf\rf_under_over_sampled_residual_cnn_features_128.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/over_sampled_residual_cnn_features_256.csv...
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:484: FutureWarning: `BaseEstimator._check_n_features` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation._check_n_features` instead.
#   warnings.warn(
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:493: FutureWarning: `BaseEstimator._check_feature_names` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation._check_feature_names` instead.
#   warnings.warn(
# Accuracy  : 0.7978
# Precision : 0.6739
# Recall    : 0.9552
# F1 Score  : 0.7903
# F2 Score  : 0.8816
# Best Threshold  : 0.14999999999999997
# TP: 1151, TN: 1260, FP: 557, FN: 54
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.96      0.69      0.80      1817
#            1       0.67      0.96      0.79      1205
#
#     accuracy                           0.80      3022
#    macro avg       0.82      0.82      0.80      3022
# weighted avg       0.85      0.80      0.80      3022
#
# Model saved to models/rf\rf_under_over_sampled_residual_cnn_features_256.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/under_sampled_residual_cnn_features_32.csv...
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:484: FutureWarning: `BaseEstimator._check_n_features` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation._check_n_features` instead.
#   warnings.warn(
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:493: FutureWarning: `BaseEstimator._check_feature_names` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation._check_feature_names` instead.
#   warnings.warn(
# Accuracy  : 0.8120
# Precision : 0.6982
# Recall    : 0.9311
# F1 Score  : 0.7980
# F2 Score  : 0.8729
# Best Threshold  : 0.22999999999999995
# TP: 1122, TN: 1332, FP: 485, FN: 83
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.73      0.82      1817
#            1       0.70      0.93      0.80      1205
#
#     accuracy                           0.81      3022
#    macro avg       0.82      0.83      0.81      3022
# weighted avg       0.84      0.81      0.81      3022
#
# Model saved to models/rf\rf_under_under_sampled_residual_cnn_features_32.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/under_sampled_residual_cnn_features_64.csv...
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:484: FutureWarning: `BaseEstimator._check_n_features` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation._check_n_features` instead.
#   warnings.warn(
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:493: FutureWarning: `BaseEstimator._check_feature_names` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation._check_feature_names` instead.
#   warnings.warn(
# Accuracy  : 0.8147
# Precision : 0.7019
# Recall    : 0.9303
# F1 Score  : 0.8001
# F2 Score  : 0.8735
# Best Threshold  : 0.20999999999999996
# TP: 1121, TN: 1341, FP: 476, FN: 84
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.74      0.83      1817
#            1       0.70      0.93      0.80      1205
#
#     accuracy                           0.81      3022
#    macro avg       0.82      0.83      0.81      3022
# weighted avg       0.85      0.81      0.82      3022
#
# Model saved to models/rf\rf_under_under_sampled_residual_cnn_features_64.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/under_sampled_residual_cnn_features_128.csv...
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:484: FutureWarning: `BaseEstimator._check_n_features` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation._check_n_features` instead.
#   warnings.warn(
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:493: FutureWarning: `BaseEstimator._check_feature_names` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation._check_feature_names` instead.
#   warnings.warn(
# Accuracy  : 0.8236
# Precision : 0.7129
# Recall    : 0.9336
# F1 Score  : 0.8085
# F2 Score  : 0.8792
# Best Threshold  : 0.19999999999999996
# TP: 1125, TN: 1364, FP: 453, FN: 80
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.75      0.84      1817
#            1       0.71      0.93      0.81      1205
#
#     accuracy                           0.82      3022
#    macro avg       0.83      0.84      0.82      3022
# weighted avg       0.85      0.82      0.83      3022
#
# Model saved to models/rf\rf_under_under_sampled_residual_cnn_features_128.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/under_sampled_residual_cnn_features_256.csv...
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:484: FutureWarning: `BaseEstimator._check_n_features` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation._check_n_features` instead.
#   warnings.warn(
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:493: FutureWarning: `BaseEstimator._check_feature_names` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation._check_feature_names` instead.
#   warnings.warn(
# Accuracy  : 0.8223
# Precision : 0.7093
# Recall    : 0.9394
# F1 Score  : 0.8083
# F2 Score  : 0.8822
# Best Threshold  : 0.19999999999999996
# TP: 1132, TN: 1353, FP: 464, FN: 73
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.95      0.74      0.83      1817
#            1       0.71      0.94      0.81      1205
#
#     accuracy                           0.82      3022
#    macro avg       0.83      0.84      0.82      3022
# weighted avg       0.85      0.82      0.82      3022
#
# Model saved to models/rf\rf_under_under_sampled_residual_cnn_features_256.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/weighted_residual_cnn_features_32.csv...
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:484: FutureWarning: `BaseEstimator._check_n_features` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation._check_n_features` instead.
#   warnings.warn(
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:493: FutureWarning: `BaseEstimator._check_feature_names` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation._check_feature_names` instead.
#   warnings.warn(
# Accuracy  : 0.8210
# Precision : 0.7067
# Recall    : 0.9419
# F1 Score  : 0.8075
# F2 Score  : 0.8831
# Best Threshold  : 0.18999999999999995
# TP: 1135, TN: 1346, FP: 471, FN: 70
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.95      0.74      0.83      1817
#            1       0.71      0.94      0.81      1205
#
#     accuracy                           0.82      3022
#    macro avg       0.83      0.84      0.82      3022
# weighted avg       0.85      0.82      0.82      3022
#
# Model saved to models/rf\rf_under_weighted_residual_cnn_features_32.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/weighted_residual_cnn_features_64.csv...
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:484: FutureWarning: `BaseEstimator._check_n_features` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation._check_n_features` instead.
#   warnings.warn(
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:493: FutureWarning: `BaseEstimator._check_feature_names` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation._check_feature_names` instead.
#   warnings.warn(
# Accuracy  : 0.7803
# Precision : 0.6555
# Recall    : 0.9461
# F1 Score  : 0.7745
# F2 Score  : 0.8690
# Best Threshold  : 0.18999999999999995
# TP: 1140, TN: 1218, FP: 599, FN: 65
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.95      0.67      0.79      1817
#            1       0.66      0.95      0.77      1205
#
#     accuracy                           0.78      3022
#    macro avg       0.80      0.81      0.78      3022
# weighted avg       0.83      0.78      0.78      3022
#
# Model saved to models/rf\rf_under_weighted_residual_cnn_features_64.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/weighted_residual_cnn_features_128.csv...
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:484: FutureWarning: `BaseEstimator._check_n_features` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation._check_n_features` instead.
#   warnings.warn(
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:493: FutureWarning: `BaseEstimator._check_feature_names` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation._check_feature_names` instead.
#   warnings.warn(
# Accuracy  : 0.7905
# Precision : 0.6636
# Recall    : 0.9627
# F1 Score  : 0.7856
# F2 Score  : 0.8831
# Best Threshold  : 0.14999999999999997
# TP: 1160, TN: 1229, FP: 588, FN: 45
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.96      0.68      0.80      1817
#            1       0.66      0.96      0.79      1205
#
#     accuracy                           0.79      3022
#    macro avg       0.81      0.82      0.79      3022
# weighted avg       0.84      0.79      0.79      3022
#
# Model saved to models/rf\rf_under_weighted_residual_cnn_features_128.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/weighted_residual_cnn_features_256.csv...
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:484: FutureWarning: `BaseEstimator._check_n_features` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation._check_n_features` instead.
#   warnings.warn(
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:493: FutureWarning: `BaseEstimator._check_feature_names` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation._check_feature_names` instead.
#   warnings.warn(
# Accuracy  : 0.8008
# Precision : 0.6800
# Recall    : 0.9452
# F1 Score  : 0.7910
# F2 Score  : 0.8768
# Best Threshold  : 0.18999999999999995
# TP: 1139, TN: 1281, FP: 536, FN: 66
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.95      0.71      0.81      1817
#            1       0.68      0.95      0.79      1205
#
#     accuracy                           0.80      3022
#    macro avg       0.82      0.83      0.80      3022
# weighted avg       0.84      0.80      0.80      3022
#
# Model saved to models/rf\rf_under_weighted_residual_cnn_features_256.joblib
# Results saved to results_summary.csv

# %% [markdown]
# ### Over-Sampled

# %%
train(residual_dataset_paths, "rf", "over")
# Out:
# Processing ../feature-extraction/residual_cnn/datasets/normal_residual_cnn_features_32.csv...
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# Accuracy  : 0.8216
# Precision : 0.7105
# Recall    : 0.9328
# F1 Score  : 0.8066
# F2 Score  : 0.8779
# Best Threshold  : 0.13
# TP: 1124, TN: 1359, FP: 458, FN: 81
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.75      0.83      1817
#            1       0.71      0.93      0.81      1205
#
#     accuracy                           0.82      3022
#    macro avg       0.83      0.84      0.82      3022
# weighted avg       0.85      0.82      0.82      3022
#
# Model saved to models/rf\rf_over_normal_residual_cnn_features_32.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/normal_residual_cnn_features_64.csv...
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# Accuracy  : 0.8379
# Precision : 0.7391
# Recall    : 0.9170
# F1 Score  : 0.8185
# F2 Score  : 0.8749
# Best Threshold  : 0.18999999999999995
# TP: 1105, TN: 1427, FP: 390, FN: 100
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.93      0.79      0.85      1817
#            1       0.74      0.92      0.82      1205
#
#     accuracy                           0.84      3022
#    macro avg       0.84      0.85      0.84      3022
# weighted avg       0.86      0.84      0.84      3022
#
# Model saved to models/rf\rf_over_normal_residual_cnn_features_64.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/normal_residual_cnn_features_128.csv...
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# Accuracy  : 0.8226
# Precision : 0.7148
# Recall    : 0.9237
# F1 Score  : 0.8059
# F2 Score  : 0.8727
# Best Threshold  : 0.16999999999999998
# TP: 1113, TN: 1373, FP: 444, FN: 92
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.76      0.84      1817
#            1       0.71      0.92      0.81      1205
#
#     accuracy                           0.82      3022
#    macro avg       0.83      0.84      0.82      3022
# weighted avg       0.85      0.82      0.82      3022
#
# Model saved to models/rf\rf_over_normal_residual_cnn_features_128.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/normal_residual_cnn_features_256.csv...
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# Accuracy  : 0.7879
# Precision : 0.6628
# Recall    : 0.9527
# F1 Score  : 0.7818
# F2 Score  : 0.8761
# Best Threshold  : 0.1
# TP: 1148, TN: 1233, FP: 584, FN: 57
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.96      0.68      0.79      1817
#            1       0.66      0.95      0.78      1205
#
#     accuracy                           0.79      3022
#    macro avg       0.81      0.82      0.79      3022
# weighted avg       0.84      0.79      0.79      3022
#
# Model saved to models/rf\rf_over_normal_residual_cnn_features_256.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/over_sampled_residual_cnn_features_32.csv...
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# Accuracy  : 0.8236
# Precision : 0.7066
# Recall    : 0.9535
# F1 Score  : 0.8117
# F2 Score  : 0.8913
# Best Threshold  : 0.1
# TP: 1149, TN: 1340, FP: 477, FN: 56
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.96      0.74      0.83      1817
#            1       0.71      0.95      0.81      1205
#
#     accuracy                           0.82      3022
#    macro avg       0.83      0.85      0.82      3022
# weighted avg       0.86      0.82      0.83      3022
#
# Model saved to models/rf\rf_over_over_sampled_residual_cnn_features_32.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/over_sampled_residual_cnn_features_64.csv...
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# Accuracy  : 0.8316
# Precision : 0.7254
# Recall    : 0.9295
# F1 Score  : 0.8148
# F2 Score  : 0.8799
# Best Threshold  : 0.17999999999999997
# TP: 1120, TN: 1393, FP: 424, FN: 85
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.77      0.85      1817
#            1       0.73      0.93      0.81      1205
#
#     accuracy                           0.83      3022
#    macro avg       0.83      0.85      0.83      3022
# weighted avg       0.86      0.83      0.83      3022
#
# Model saved to models/rf\rf_over_over_sampled_residual_cnn_features_64.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/over_sampled_residual_cnn_features_128.csv...
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# Accuracy  : 0.8021
# Precision : 0.6795
# Recall    : 0.9535
# F1 Score  : 0.7935
# F2 Score  : 0.8824
# Best Threshold  : 0.11
# TP: 1149, TN: 1275, FP: 542, FN: 56
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.96      0.70      0.81      1817
#            1       0.68      0.95      0.79      1205
#
#     accuracy                           0.80      3022
#    macro avg       0.82      0.83      0.80      3022
# weighted avg       0.85      0.80      0.80      3022
#
# Model saved to models/rf\rf_over_over_sampled_residual_cnn_features_128.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/over_sampled_residual_cnn_features_256.csv...
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# Accuracy  : 0.7952
# Precision : 0.6717
# Recall    : 0.9510
# F1 Score  : 0.7874
# F2 Score  : 0.8780
# Best Threshold  : 0.1
# TP: 1146, TN: 1257, FP: 560, FN: 59
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.96      0.69      0.80      1817
#            1       0.67      0.95      0.79      1205
#
#     accuracy                           0.80      3022
#    macro avg       0.81      0.82      0.79      3022
# weighted avg       0.84      0.80      0.80      3022
#
# Model saved to models/rf\rf_over_over_sampled_residual_cnn_features_256.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/under_sampled_residual_cnn_features_32.csv...
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# Accuracy  : 0.7955
# Precision : 0.6742
# Recall    : 0.9427
# F1 Score  : 0.7862
# F2 Score  : 0.8732
# Best Threshold  : 0.13999999999999999
# TP: 1136, TN: 1268, FP: 549, FN: 69
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.95      0.70      0.80      1817
#            1       0.67      0.94      0.79      1205
#
#     accuracy                           0.80      3022
#    macro avg       0.81      0.82      0.80      3022
# weighted avg       0.84      0.80      0.80      3022
#
# Model saved to models/rf\rf_over_under_sampled_residual_cnn_features_32.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/under_sampled_residual_cnn_features_64.csv...
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# Accuracy  : 0.8312
# Precision : 0.7258
# Recall    : 0.9270
# F1 Score  : 0.8141
# F2 Score  : 0.8783
# Best Threshold  : 0.16999999999999998
# TP: 1117, TN: 1395, FP: 422, FN: 88
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.77      0.85      1817
#            1       0.73      0.93      0.81      1205
#
#     accuracy                           0.83      3022
#    macro avg       0.83      0.85      0.83      3022
# weighted avg       0.85      0.83      0.83      3022
#
# Model saved to models/rf\rf_over_under_sampled_residual_cnn_features_64.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/under_sampled_residual_cnn_features_128.csv...
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# Accuracy  : 0.8289
# Precision : 0.7228
# Recall    : 0.9261
# F1 Score  : 0.8119
# F2 Score  : 0.8768
# Best Threshold  : 0.14999999999999997
# TP: 1116, TN: 1389, FP: 428, FN: 89
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.76      0.84      1817
#            1       0.72      0.93      0.81      1205
#
#     accuracy                           0.83      3022
#    macro avg       0.83      0.85      0.83      3022
# weighted avg       0.85      0.83      0.83      3022
#
# Model saved to models/rf\rf_over_under_sampled_residual_cnn_features_128.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/under_sampled_residual_cnn_features_256.csv...
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# Accuracy  : 0.8170
# Precision : 0.7017
# Recall    : 0.9411
# F1 Score  : 0.8040
# F2 Score  : 0.8810
# Best Threshold  : 0.13
# TP: 1134, TN: 1335, FP: 482, FN: 71
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.95      0.73      0.83      1817
#            1       0.70      0.94      0.80      1205
#
#     accuracy                           0.82      3022
#    macro avg       0.83      0.84      0.82      3022
# weighted avg       0.85      0.82      0.82      3022
#
# Model saved to models/rf\rf_over_under_sampled_residual_cnn_features_256.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/weighted_residual_cnn_features_32.csv...
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# Accuracy  : 0.8134
# Precision : 0.6946
# Recall    : 0.9494
# F1 Score  : 0.8022
# F2 Score  : 0.8845
# Best Threshold  : 0.12
# TP: 1144, TN: 1314, FP: 503, FN: 61
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.96      0.72      0.82      1817
#            1       0.69      0.95      0.80      1205
#
#     accuracy                           0.81      3022
#    macro avg       0.83      0.84      0.81      3022
# weighted avg       0.85      0.81      0.81      3022
#
# Model saved to models/rf\rf_over_weighted_residual_cnn_features_32.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/weighted_residual_cnn_features_64.csv...
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# Accuracy  : 0.7925
# Precision : 0.6704
# Recall    : 0.9436
# F1 Score  : 0.7839
# F2 Score  : 0.8725
# Best Threshold  : 0.13999999999999999
# TP: 1137, TN: 1258, FP: 559, FN: 68
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.95      0.69      0.80      1817
#            1       0.67      0.94      0.78      1205
#
#     accuracy                           0.79      3022
#    macro avg       0.81      0.82      0.79      3022
# weighted avg       0.84      0.79      0.79      3022
#
# Model saved to models/rf\rf_over_weighted_residual_cnn_features_64.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/weighted_residual_cnn_features_128.csv...
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# Accuracy  : 0.8011
# Precision : 0.6785
# Recall    : 0.9527
# F1 Score  : 0.7925
# F2 Score  : 0.8814
# Best Threshold  : 0.11
# TP: 1148, TN: 1273, FP: 544, FN: 57
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.96      0.70      0.81      1817
#            1       0.68      0.95      0.79      1205
#
#     accuracy                           0.80      3022
#    macro avg       0.82      0.83      0.80      3022
# weighted avg       0.85      0.80      0.80      3022
#
# Model saved to models/rf\rf_over_weighted_residual_cnn_features_128.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/weighted_residual_cnn_features_256.csv...
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# Accuracy  : 0.8233
# Precision : 0.7149
# Recall    : 0.9261
# F1 Score  : 0.8069
# F2 Score  : 0.8745
# Best Threshold  : 0.15999999999999998
# TP: 1116, TN: 1372, FP: 445, FN: 89
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.76      0.84      1817
#            1       0.71      0.93      0.81      1205
#
#     accuracy                           0.82      3022
#    macro avg       0.83      0.84      0.82      3022
# weighted avg       0.85      0.82      0.83      3022
#
# Model saved to models/rf\rf_over_weighted_residual_cnn_features_256.joblib
# Results saved to results_summary.csv

# %% [markdown]
# ### Weighted

# %%
train(residual_dataset_paths, "rf", "weighted")
# Out:
# Processing ../feature-extraction/residual_cnn/datasets/normal_residual_cnn_features_32.csv...
# Accuracy  : 0.8213
# Precision : 0.7106
# Recall    : 0.9311
# F1 Score  : 0.8060
# F2 Score  : 0.8767
# Best Threshold  : 0.13
# TP: 1122, TN: 1360, FP: 457, FN: 83
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.75      0.83      1817
#            1       0.71      0.93      0.81      1205
#
#     accuracy                           0.82      3022
#    macro avg       0.83      0.84      0.82      3022
# weighted avg       0.85      0.82      0.82      3022
#
# Model saved to models/rf\rf_weighted_normal_residual_cnn_features_32.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/normal_residual_cnn_features_64.csv...
# Accuracy  : 0.8200
# Precision : 0.7083
# Recall    : 0.9328
# F1 Score  : 0.8052
# F2 Score  : 0.8772
# Best Threshold  : 0.13999999999999999
# TP: 1124, TN: 1354, FP: 463, FN: 81
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.75      0.83      1817
#            1       0.71      0.93      0.81      1205
#
#     accuracy                           0.82      3022
#    macro avg       0.83      0.84      0.82      3022
# weighted avg       0.85      0.82      0.82      3022
#
# Model saved to models/rf\rf_weighted_normal_residual_cnn_features_64.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/normal_residual_cnn_features_128.csv...
# Accuracy  : 0.8177
# Precision : 0.7059
# Recall    : 0.9303
# F1 Score  : 0.8027
# F2 Score  : 0.8747
# Best Threshold  : 0.14999999999999997
# TP: 1121, TN: 1350, FP: 467, FN: 84
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.74      0.83      1817
#            1       0.71      0.93      0.80      1205
#
#     accuracy                           0.82      3022
#    macro avg       0.82      0.84      0.82      3022
# weighted avg       0.85      0.82      0.82      3022
#
# Model saved to models/rf\rf_weighted_normal_residual_cnn_features_128.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/normal_residual_cnn_features_256.csv...
# Accuracy  : 0.8051
# Precision : 0.6860
# Recall    : 0.9427
# F1 Score  : 0.7941
# F2 Score  : 0.8771
# Best Threshold  : 0.12
# TP: 1136, TN: 1297, FP: 520, FN: 69
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.95      0.71      0.81      1817
#            1       0.69      0.94      0.79      1205
#
#     accuracy                           0.81      3022
#    macro avg       0.82      0.83      0.80      3022
# weighted avg       0.84      0.81      0.81      3022
#
# Model saved to models/rf\rf_weighted_normal_residual_cnn_features_256.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/over_sampled_residual_cnn_features_32.csv...
# Accuracy  : 0.8332
# Precision : 0.7200
# Recall    : 0.9519
# F1 Score  : 0.8199
# F2 Score  : 0.8943
# Best Threshold  : 0.11
# TP: 1147, TN: 1371, FP: 446, FN: 58
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.96      0.75      0.84      1817
#            1       0.72      0.95      0.82      1205
#
#     accuracy                           0.83      3022
#    macro avg       0.84      0.85      0.83      3022
# weighted avg       0.86      0.83      0.83      3022
#
# Model saved to models/rf\rf_weighted_over_sampled_residual_cnn_features_32.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/over_sampled_residual_cnn_features_64.csv...
# Accuracy  : 0.8339
# Precision : 0.7281
# Recall    : 0.9311
# F1 Score  : 0.8172
# F2 Score  : 0.8819
# Best Threshold  : 0.16999999999999998
# TP: 1122, TN: 1398, FP: 419, FN: 83
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.77      0.85      1817
#            1       0.73      0.93      0.82      1205
#
#     accuracy                           0.83      3022
#    macro avg       0.84      0.85      0.83      3022
# weighted avg       0.86      0.83      0.84      3022
#
# Model saved to models/rf\rf_weighted_over_sampled_residual_cnn_features_64.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/over_sampled_residual_cnn_features_128.csv...
# Accuracy  : 0.8332
# Precision : 0.7254
# Recall    : 0.9361
# F1 Score  : 0.8174
# F2 Score  : 0.8847
# Best Threshold  : 0.14999999999999997
# TP: 1128, TN: 1390, FP: 427, FN: 77
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.95      0.76      0.85      1817
#            1       0.73      0.94      0.82      1205
#
#     accuracy                           0.83      3022
#    macro avg       0.84      0.85      0.83      3022
# weighted avg       0.86      0.83      0.83      3022
#
# Model saved to models/rf\rf_weighted_over_sampled_residual_cnn_features_128.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/over_sampled_residual_cnn_features_256.csv...
# Accuracy  : 0.7962
# Precision : 0.6725
# Recall    : 0.9527
# F1 Score  : 0.7885
# F2 Score  : 0.8794
# Best Threshold  : 0.1
# TP: 1148, TN: 1258, FP: 559, FN: 57
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.96      0.69      0.80      1817
#            1       0.67      0.95      0.79      1205
#
#     accuracy                           0.80      3022
#    macro avg       0.81      0.82      0.80      3022
# weighted avg       0.84      0.80      0.80      3022
#
# Model saved to models/rf\rf_weighted_over_sampled_residual_cnn_features_256.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/under_sampled_residual_cnn_features_32.csv...
# Accuracy  : 0.8160
# Precision : 0.7032
# Recall    : 0.9320
# F1 Score  : 0.8016
# F2 Score  : 0.8750
# Best Threshold  : 0.15999999999999998
# TP: 1123, TN: 1343, FP: 474, FN: 82
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.74      0.83      1817
#            1       0.70      0.93      0.80      1205
#
#     accuracy                           0.82      3022
#    macro avg       0.82      0.84      0.82      3022
# weighted avg       0.85      0.82      0.82      3022
#
# Model saved to models/rf\rf_weighted_under_sampled_residual_cnn_features_32.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/under_sampled_residual_cnn_features_64.csv...
# Accuracy  : 0.8180
# Precision : 0.7061
# Recall    : 0.9311
# F1 Score  : 0.8031
# F2 Score  : 0.8753
# Best Threshold  : 0.13999999999999999
# TP: 1122, TN: 1350, FP: 467, FN: 83
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.74      0.83      1817
#            1       0.71      0.93      0.80      1205
#
#     accuracy                           0.82      3022
#    macro avg       0.82      0.84      0.82      3022
# weighted avg       0.85      0.82      0.82      3022
#
# Model saved to models/rf\rf_weighted_under_sampled_residual_cnn_features_64.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/under_sampled_residual_cnn_features_128.csv...
# Accuracy  : 0.8418
# Precision : 0.7451
# Recall    : 0.9170
# F1 Score  : 0.8222
# F2 Score  : 0.8766
# Best Threshold  : 0.16999999999999998
# TP: 1105, TN: 1439, FP: 378, FN: 100
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.79      0.86      1817
#            1       0.75      0.92      0.82      1205
#
#     accuracy                           0.84      3022
#    macro avg       0.84      0.85      0.84      3022
# weighted avg       0.86      0.84      0.84      3022
#
# Model saved to models/rf\rf_weighted_under_sampled_residual_cnn_features_128.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/under_sampled_residual_cnn_features_256.csv...
# Accuracy  : 0.8388
# Precision : 0.7359
# Recall    : 0.9295
# F1 Score  : 0.8214
# F2 Score  : 0.8830
# Best Threshold  : 0.14999999999999997
# TP: 1120, TN: 1415, FP: 402, FN: 85
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.78      0.85      1817
#            1       0.74      0.93      0.82      1205
#
#     accuracy                           0.84      3022
#    macro avg       0.84      0.85      0.84      3022
# weighted avg       0.86      0.84      0.84      3022
#
# Model saved to models/rf\rf_weighted_under_sampled_residual_cnn_features_256.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/weighted_residual_cnn_features_32.csv...
# Accuracy  : 0.8379
# Precision : 0.7338
# Recall    : 0.9311
# F1 Score  : 0.8208
# F2 Score  : 0.8836
# Best Threshold  : 0.14999999999999997
# TP: 1122, TN: 1410, FP: 407, FN: 83
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.78      0.85      1817
#            1       0.73      0.93      0.82      1205
#
#     accuracy                           0.84      3022
#    macro avg       0.84      0.85      0.84      3022
# weighted avg       0.86      0.84      0.84      3022
#
# Model saved to models/rf\rf_weighted_weighted_residual_cnn_features_32.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/weighted_residual_cnn_features_64.csv...
# Accuracy  : 0.7938
# Precision : 0.6728
# Recall    : 0.9402
# F1 Score  : 0.7844
# F2 Score  : 0.8710
# Best Threshold  : 0.13999999999999999
# TP: 1133, TN: 1266, FP: 551, FN: 72
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.95      0.70      0.80      1817
#            1       0.67      0.94      0.78      1205
#
#     accuracy                           0.79      3022
#    macro avg       0.81      0.82      0.79      3022
# weighted avg       0.84      0.79      0.80      3022
#
# Model saved to models/rf\rf_weighted_weighted_residual_cnn_features_64.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/weighted_residual_cnn_features_128.csv...
# Accuracy  : 0.8044
# Precision : 0.6830
# Recall    : 0.9510
# F1 Score  : 0.7950
# F2 Score  : 0.8818
# Best Threshold  : 0.12
# TP: 1146, TN: 1285, FP: 532, FN: 59
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.96      0.71      0.81      1817
#            1       0.68      0.95      0.80      1205
#
#     accuracy                           0.80      3022
#    macro avg       0.82      0.83      0.80      3022
# weighted avg       0.85      0.80      0.81      3022
#
# Model saved to models/rf\rf_weighted_weighted_residual_cnn_features_128.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/weighted_residual_cnn_features_256.csv...
# Accuracy  : 0.8114
# Precision : 0.6954
# Recall    : 0.9378
# F1 Score  : 0.7986
# F2 Score  : 0.8766
# Best Threshold  : 0.13999999999999999
# TP: 1130, TN: 1322, FP: 495, FN: 75
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.95      0.73      0.82      1817
#            1       0.70      0.94      0.80      1205
#
#     accuracy                           0.81      3022
#    macro avg       0.82      0.83      0.81      3022
# weighted avg       0.85      0.81      0.81      3022
#
# Model saved to models/rf\rf_weighted_weighted_residual_cnn_features_256.joblib
# Results saved to results_summary.csv
