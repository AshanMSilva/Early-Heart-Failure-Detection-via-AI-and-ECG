# %% [markdown]
# # Imports

# %%
from data_utils import train

# %% [markdown]
# # Train Model

# %% [markdown]
# ## Residual

# %% [markdown]
# ### Datasets

# %%
residual_dataset_paths = [
    "../feature-extraction/residual_cnn/datasets/normal_residual_cnn_features_32.csv",
    "../feature-extraction/residual_cnn/datasets/normal_residual_cnn_features_64.csv",
    "../feature-extraction/residual_cnn/datasets/normal_residual_cnn_features_128.csv",
    "../feature-extraction/residual_cnn/datasets/normal_residual_cnn_features_256.csv",
    "../feature-extraction/residual_cnn/datasets/over_sampled_residual_cnn_features_32.csv",
    "../feature-extraction/residual_cnn/datasets/over_sampled_residual_cnn_features_64.csv",
    "../feature-extraction/residual_cnn/datasets/over_sampled_residual_cnn_features_128.csv",
    "../feature-extraction/residual_cnn/datasets/over_sampled_residual_cnn_features_256.csv",
    "../feature-extraction/residual_cnn/datasets/under_sampled_residual_cnn_features_32.csv",
    "../feature-extraction/residual_cnn/datasets/under_sampled_residual_cnn_features_64.csv",
    "../feature-extraction/residual_cnn/datasets/under_sampled_residual_cnn_features_128.csv",
    "../feature-extraction/residual_cnn/datasets/under_sampled_residual_cnn_features_256.csv",
    "../feature-extraction/residual_cnn/datasets/weighted_residual_cnn_features_32.csv",
    "../feature-extraction/residual_cnn/datasets/weighted_residual_cnn_features_64.csv",
    "../feature-extraction/residual_cnn/datasets/weighted_residual_cnn_features_128.csv",
    "../feature-extraction/residual_cnn/datasets/weighted_residual_cnn_features_256.csv",

]

# %% [markdown]
# ### Imbalanced

# %%
train(residual_dataset_paths, "rf", "normal")
# Out:
# Processing ../feature-extraction/residual_cnn/datasets/normal_residual_cnn_features_32.csv...
# Accuracy  : 0.8451
# Precision : 0.7509
# Recall    : 0.9154
# F1 Score  : 0.8250
# F2 Score  : 0.8769
# Best Threshold  : 0.16999999999999998
# TP: 1103, TN: 1451, FP: 366, FN: 102
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.93      0.80      0.86      1817
#            1       0.75      0.92      0.82      1205
#
#     accuracy                           0.85      3022
#    macro avg       0.84      0.86      0.84      3022
# weighted avg       0.86      0.85      0.85      3022
#
# Model saved to models/rf\rf_normal_normal_residual_cnn_features_32.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/normal_residual_cnn_features_64.csv...
# Accuracy  : 0.8319
# Precision : 0.7264
# Recall    : 0.9278
# F1 Score  : 0.8149
# F2 Score  : 0.8791
# Best Threshold  : 0.15999999999999998
# TP: 1118, TN: 1396, FP: 421, FN: 87
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.77      0.85      1817
#            1       0.73      0.93      0.81      1205
#
#     accuracy                           0.83      3022
#    macro avg       0.83      0.85      0.83      3022
# weighted avg       0.86      0.83      0.83      3022
#
# Model saved to models/rf\rf_normal_normal_residual_cnn_features_64.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/normal_residual_cnn_features_128.csv...
# Accuracy  : 0.8167
# Precision : 0.7046
# Recall    : 0.9303
# F1 Score  : 0.8019
# F2 Score  : 0.8743
# Best Threshold  : 0.14999999999999997
# TP: 1121, TN: 1347, FP: 470, FN: 84
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.74      0.83      1817
#            1       0.70      0.93      0.80      1205
#
#     accuracy                           0.82      3022
#    macro avg       0.82      0.84      0.82      3022
# weighted avg       0.85      0.82      0.82      3022
#
# Model saved to models/rf\rf_normal_normal_residual_cnn_features_128.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/normal_residual_cnn_features_256.csv...
# Accuracy  : 0.8048
# Precision : 0.6854
# Recall    : 0.9436
# F1 Score  : 0.7940
# F2 Score  : 0.8775
# Best Threshold  : 0.12
# TP: 1137, TN: 1295, FP: 522, FN: 68
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.95      0.71      0.81      1817
#            1       0.69      0.94      0.79      1205
#
#     accuracy                           0.80      3022
#    macro avg       0.82      0.83      0.80      3022
# weighted avg       0.84      0.80      0.81      3022
#
# Model saved to models/rf\rf_normal_normal_residual_cnn_features_256.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/over_sampled_residual_cnn_features_32.csv...
# Accuracy  : 0.8286
# Precision : 0.7124
# Recall    : 0.9560
# F1 Score  : 0.8164
# F2 Score  : 0.8948
# Best Threshold  : 0.1
# TP: 1152, TN: 1352, FP: 465, FN: 53
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.96      0.74      0.84      1817
#            1       0.71      0.96      0.82      1205
#
#     accuracy                           0.83      3022
#    macro avg       0.84      0.85      0.83      3022
# weighted avg       0.86      0.83      0.83      3022
#
# Model saved to models/rf\rf_normal_over_sampled_residual_cnn_features_32.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/over_sampled_residual_cnn_features_64.csv...
# Accuracy  : 0.8547
# Precision : 0.7675
# Recall    : 0.9120
# F1 Score  : 0.8335
# F2 Score  : 0.8789
# Best Threshold  : 0.21999999999999995
# TP: 1099, TN: 1484, FP: 333, FN: 106
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.93      0.82      0.87      1817
#            1       0.77      0.91      0.83      1205
#
#     accuracy                           0.85      3022
#    macro avg       0.85      0.86      0.85      3022
# weighted avg       0.87      0.85      0.86      3022
#
# Model saved to models/rf\rf_normal_over_sampled_residual_cnn_features_64.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/over_sampled_residual_cnn_features_128.csv...
# Accuracy  : 0.8263
# Precision : 0.7141
# Recall    : 0.9411
# F1 Score  : 0.8120
# F2 Score  : 0.8848
# Best Threshold  : 0.13999999999999999
# TP: 1134, TN: 1363, FP: 454, FN: 71
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.95      0.75      0.84      1817
#            1       0.71      0.94      0.81      1205
#
#     accuracy                           0.83      3022
#    macro avg       0.83      0.85      0.83      3022
# weighted avg       0.86      0.83      0.83      3022
#
# Model saved to models/rf\rf_normal_over_sampled_residual_cnn_features_128.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/over_sampled_residual_cnn_features_256.csv...
# Accuracy  : 0.8144
# Precision : 0.6983
# Recall    : 0.9411
# F1 Score  : 0.8017
# F2 Score  : 0.8799
# Best Threshold  : 0.12
# TP: 1134, TN: 1327, FP: 490, FN: 71
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.95      0.73      0.83      1817
#            1       0.70      0.94      0.80      1205
#
#     accuracy                           0.81      3022
#    macro avg       0.82      0.84      0.81      3022
# weighted avg       0.85      0.81      0.82      3022
#
# Model saved to models/rf\rf_normal_over_sampled_residual_cnn_features_256.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/under_sampled_residual_cnn_features_32.csv...
# Accuracy  : 0.8087
# Precision : 0.6924
# Recall    : 0.9361
# F1 Score  : 0.7960
# F2 Score  : 0.8746
# Best Threshold  : 0.14999999999999997
# TP: 1128, TN: 1316, FP: 501, FN: 77
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.72      0.82      1817
#            1       0.69      0.94      0.80      1205
#
#     accuracy                           0.81      3022
#    macro avg       0.82      0.83      0.81      3022
# weighted avg       0.84      0.81      0.81      3022
#
# Model saved to models/rf\rf_normal_under_sampled_residual_cnn_features_32.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/under_sampled_residual_cnn_features_64.csv...
# Accuracy  : 0.7895
# Precision : 0.6659
# Recall    : 0.9477
# F1 Score  : 0.7822
# F2 Score  : 0.8738
# Best Threshold  : 0.11
# TP: 1142, TN: 1244, FP: 573, FN: 63
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.95      0.68      0.80      1817
#            1       0.67      0.95      0.78      1205
#
#     accuracy                           0.79      3022
#    macro avg       0.81      0.82      0.79      3022
# weighted avg       0.84      0.79      0.79      3022
#
# Model saved to models/rf\rf_normal_under_sampled_residual_cnn_features_64.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/under_sampled_residual_cnn_features_128.csv...
# Accuracy  : 0.8273
# Precision : 0.7196
# Recall    : 0.9286
# F1 Score  : 0.8109
# F2 Score  : 0.8776
# Best Threshold  : 0.13999999999999999
# TP: 1119, TN: 1381, FP: 436, FN: 86
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.76      0.84      1817
#            1       0.72      0.93      0.81      1205
#
#     accuracy                           0.83      3022
#    macro avg       0.83      0.84      0.83      3022
# weighted avg       0.85      0.83      0.83      3022
#
# Model saved to models/rf\rf_normal_under_sampled_residual_cnn_features_128.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/under_sampled_residual_cnn_features_256.csv...
# Accuracy  : 0.8425
# Precision : 0.7403
# Recall    : 0.9320
# F1 Score  : 0.8251
# F2 Score  : 0.8861
# Best Threshold  : 0.14999999999999997
# TP: 1123, TN: 1423, FP: 394, FN: 82
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.95      0.78      0.86      1817
#            1       0.74      0.93      0.83      1205
#
#     accuracy                           0.84      3022
#    macro avg       0.84      0.86      0.84      3022
# weighted avg       0.86      0.84      0.84      3022
#
# Model saved to models/rf\rf_normal_under_sampled_residual_cnn_features_256.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/weighted_residual_cnn_features_32.csv...
# Accuracy  : 0.8074
# Precision : 0.6875
# Recall    : 0.9477
# F1 Score  : 0.7969
# F2 Score  : 0.8810
# Best Threshold  : 0.11
# TP: 1142, TN: 1298, FP: 519, FN: 63
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.95      0.71      0.82      1817
#            1       0.69      0.95      0.80      1205
#
#     accuracy                           0.81      3022
#    macro avg       0.82      0.83      0.81      3022
# weighted avg       0.85      0.81      0.81      3022
#
# Model saved to models/rf\rf_normal_weighted_residual_cnn_features_32.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/weighted_residual_cnn_features_64.csv...
# Accuracy  : 0.7892
# Precision : 0.6675
# Recall    : 0.9394
# F1 Score  : 0.7804
# F2 Score  : 0.8686
# Best Threshold  : 0.13999999999999999
# TP: 1132, TN: 1253, FP: 564, FN: 73
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.69      0.80      1817
#            1       0.67      0.94      0.78      1205
#
#     accuracy                           0.79      3022
#    macro avg       0.81      0.81      0.79      3022
# weighted avg       0.83      0.79      0.79      3022
#
# Model saved to models/rf\rf_normal_weighted_residual_cnn_features_64.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/weighted_residual_cnn_features_128.csv...
# Accuracy  : 0.8071
# Precision : 0.6865
# Recall    : 0.9502
# F1 Score  : 0.7971
# F2 Score  : 0.8824
# Best Threshold  : 0.12
# TP: 1145, TN: 1294, FP: 523, FN: 60
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.96      0.71      0.82      1817
#            1       0.69      0.95      0.80      1205
#
#     accuracy                           0.81      3022
#    macro avg       0.82      0.83      0.81      3022
# weighted avg       0.85      0.81      0.81      3022
#
# Model saved to models/rf\rf_normal_weighted_residual_cnn_features_128.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/weighted_residual_cnn_features_256.csv...
# Accuracy  : 0.8024
# Precision : 0.6829
# Recall    : 0.9419
# F1 Score  : 0.7918
# F2 Score  : 0.8755
# Best Threshold  : 0.13
# TP: 1135, TN: 1290, FP: 527, FN: 70
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.95      0.71      0.81      1817
#            1       0.68      0.94      0.79      1205
#
#     accuracy                           0.80      3022
#    macro avg       0.82      0.83      0.80      3022
# weighted avg       0.84      0.80      0.80      3022
#
# Model saved to models/rf\rf_normal_weighted_residual_cnn_features_256.joblib
# Results saved to results_summary.csv

# %% [markdown]
# ### Under-Sampled

# %%
train(residual_dataset_paths, "rf", "under")
# Out:
# Processing ../feature-extraction/residual_cnn/datasets/normal_residual_cnn_features_32.csv...
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:484: FutureWarning: `BaseEstimator._check_n_features` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation._check_n_features` instead.
#   warnings.warn(
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:493: FutureWarning: `BaseEstimator._check_feature_names` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation._check_feature_names` instead.
#   warnings.warn(
# Accuracy  : 0.8263
# Precision : 0.7171
# Recall    : 0.9320
# F1 Score  : 0.8105
# F2 Score  : 0.8793
# Best Threshold  : 0.19999999999999996
# TP: 1123, TN: 1374, FP: 443, FN: 82
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.76      0.84      1817
#            1       0.72      0.93      0.81      1205
#
#     accuracy                           0.83      3022
#    macro avg       0.83      0.84      0.83      3022
# weighted avg       0.85      0.83      0.83      3022
#
# Model saved to models/rf\rf_under_normal_residual_cnn_features_32.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/normal_residual_cnn_features_64.csv...
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:484: FutureWarning: `BaseEstimator._check_n_features` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation._check_n_features` instead.
#   warnings.warn(
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:493: FutureWarning: `BaseEstimator._check_feature_names` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation._check_feature_names` instead.
#   warnings.warn(
# Accuracy  : 0.8402
# Precision : 0.7416
# Recall    : 0.9195
# F1 Score  : 0.8210
# F2 Score  : 0.8774
# Best Threshold  : 0.2599999999999999
# TP: 1108, TN: 1431, FP: 386, FN: 97
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.79      0.86      1817
#            1       0.74      0.92      0.82      1205
#
#     accuracy                           0.84      3022
#    macro avg       0.84      0.85      0.84      3022
# weighted avg       0.86      0.84      0.84      3022
#
# Model saved to models/rf\rf_under_normal_residual_cnn_features_64.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/normal_residual_cnn_features_128.csv...
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:484: FutureWarning: `BaseEstimator._check_n_features` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation._check_n_features` instead.
#   warnings.warn(
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:493: FutureWarning: `BaseEstimator._check_feature_names` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation._check_feature_names` instead.
#   warnings.warn(
# Accuracy  : 0.8147
# Precision : 0.7009
# Recall    : 0.9336
# F1 Score  : 0.8007
# F2 Score  : 0.8755
# Best Threshold  : 0.21999999999999995
# TP: 1125, TN: 1337, FP: 480, FN: 80
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.74      0.83      1817
#            1       0.70      0.93      0.80      1205
#
#     accuracy                           0.81      3022
#    macro avg       0.82      0.83      0.81      3022
# weighted avg       0.85      0.81      0.82      3022
#
# Model saved to models/rf\rf_under_normal_residual_cnn_features_128.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/normal_residual_cnn_features_256.csv...
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:484: FutureWarning: `BaseEstimator._check_n_features` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation._check_n_features` instead.
#   warnings.warn(
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:493: FutureWarning: `BaseEstimator._check_feature_names` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation._check_feature_names` instead.
#   warnings.warn(
# Accuracy  : 0.7952
# Precision : 0.6724
# Recall    : 0.9485
# F1 Score  : 0.7869
# F2 Score  : 0.8765
# Best Threshold  : 0.15999999999999998
# TP: 1143, TN: 1260, FP: 557, FN: 62
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.95      0.69      0.80      1817
#            1       0.67      0.95      0.79      1205
#
#     accuracy                           0.80      3022
#    macro avg       0.81      0.82      0.79      3022
# weighted avg       0.84      0.80      0.80      3022
#
# Model saved to models/rf\rf_under_normal_residual_cnn_features_256.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/over_sampled_residual_cnn_features_32.csv...
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:484: FutureWarning: `BaseEstimator._check_n_features` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation._check_n_features` instead.
#   warnings.warn(
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:493: FutureWarning: `BaseEstimator._check_feature_names` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation._check_feature_names` instead.
#   warnings.warn(
# Accuracy  : 0.8220
# Precision : 0.7035
# Recall    : 0.9568
# F1 Score  : 0.8108
# F2 Score  : 0.8926
# Best Threshold  : 0.13999999999999999
# TP: 1153, TN: 1331, FP: 486, FN: 52
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.96      0.73      0.83      1817
#            1       0.70      0.96      0.81      1205
#
#     accuracy                           0.82      3022
#    macro avg       0.83      0.84      0.82      3022
# weighted avg       0.86      0.82      0.82      3022
#
# Model saved to models/rf\rf_under_over_sampled_residual_cnn_features_32.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/over_sampled_residual_cnn_features_64.csv...
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:484: FutureWarning: `BaseEstimator._check_n_features` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation._check_n_features` instead.
#   warnings.warn(
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:493: FutureWarning: `BaseEstimator._check_feature_names` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation._check_feature_names` instead.
#   warnings.warn(
# Accuracy  : 0.8428
# Precision : 0.7450
# Recall    : 0.9212
# F1 Score  : 0.8237
# F2 Score  : 0.8796
# Best Threshold  : 0.2899999999999999
# TP: 1110, TN: 1437, FP: 380, FN: 95
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.79      0.86      1817
#            1       0.74      0.92      0.82      1205
#
#     accuracy                           0.84      3022
#    macro avg       0.84      0.86      0.84      3022
# weighted avg       0.86      0.84      0.84      3022
#
# Model saved to models/rf\rf_under_over_sampled_residual_cnn_features_64.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/over_sampled_residual_cnn_features_128.csv...
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:484: FutureWarning: `BaseEstimator._check_n_features` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation._check_n_features` instead.
#   warnings.warn(
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:493: FutureWarning: `BaseEstimator._check_feature_names` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation._check_feature_names` instead.
#   warnings.warn(
# Accuracy  : 0.8226
# Precision : 0.7095
# Recall    : 0.9402
# F1 Score  : 0.8087
# F2 Score  : 0.8828
# Best Threshold  : 0.19999999999999996
# TP: 1133, TN: 1353, FP: 464, FN: 72
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.95      0.74      0.83      1817
#            1       0.71      0.94      0.81      1205
#
#     accuracy                           0.82      3022
#    macro avg       0.83      0.84      0.82      3022
# weighted avg       0.85      0.82      0.82      3022
#
# Model saved to models/rf\rf_under_over_sampled_residual_cnn_features_128.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/over_sampled_residual_cnn_features_256.csv...
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:484: FutureWarning: `BaseEstimator._check_n_features` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation._check_n_features` instead.
#   warnings.warn(
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:493: FutureWarning: `BaseEstimator._check_feature_names` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation._check_feature_names` instead.
#   warnings.warn(
# Accuracy  : 0.7978
# Precision : 0.6739
# Recall    : 0.9552
# F1 Score  : 0.7903
# F2 Score  : 0.8816
# Best Threshold  : 0.14999999999999997
# TP: 1151, TN: 1260, FP: 557, FN: 54
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.96      0.69      0.80      1817
#            1       0.67      0.96      0.79      1205
#
#     accuracy                           0.80      3022
#    macro avg       0.82      0.82      0.80      3022
# weighted avg       0.85      0.80      0.80      3022
#
# Model saved to models/rf\rf_under_over_sampled_residual_cnn_features_256.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/under_sampled_residual_cnn_features_32.csv...
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:484: FutureWarning: `BaseEstimator._check_n_features` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation._check_n_features` instead.
#   warnings.warn(
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:493: FutureWarning: `BaseEstimator._check_feature_names` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation._check_feature_names` instead.
#   warnings.warn(
# Accuracy  : 0.8120
# Precision : 0.6982
# Recall    : 0.9311
# F1 Score  : 0.7980
# F2 Score  : 0.8729
# Best Threshold  : 0.22999999999999995
# TP: 1122, TN: 1332, FP: 485, FN: 83
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.73      0.82      1817
#            1       0.70      0.93      0.80      1205
#
#     accuracy                           0.81      3022
#    macro avg       0.82      0.83      0.81      3022
# weighted avg       0.84      0.81      0.81      3022
#
# Model saved to models/rf\rf_under_under_sampled_residual_cnn_features_32.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/under_sampled_residual_cnn_features_64.csv...
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:484: FutureWarning: `BaseEstimator._check_n_features` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation._check_n_features` instead.
#   warnings.warn(
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:493: FutureWarning: `BaseEstimator._check_feature_names` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation._check_feature_names` instead.
#   warnings.warn(
# Accuracy  : 0.8147
# Precision : 0.7019
# Recall    : 0.9303
# F1 Score  : 0.8001
# F2 Score  : 0.8735
# Best Threshold  : 0.20999999999999996
# TP: 1121, TN: 1341, FP: 476, FN: 84
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.74      0.83      1817
#            1       0.70      0.93      0.80      1205
#
#     accuracy                           0.81      3022
#    macro avg       0.82      0.83      0.81      3022
# weighted avg       0.85      0.81      0.82      3022
#
# Model saved to models/rf\rf_under_under_sampled_residual_cnn_features_64.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/under_sampled_residual_cnn_features_128.csv...
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:484: FutureWarning: `BaseEstimator._check_n_features` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation._check_n_features` instead.
#   warnings.warn(
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:493: FutureWarning: `BaseEstimator._check_feature_names` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation._check_feature_names` instead.
#   warnings.warn(
# Accuracy  : 0.8236
# Precision : 0.7129
# Recall    : 0.9336
# F1 Score  : 0.8085
# F2 Score  : 0.8792
# Best Threshold  : 0.19999999999999996
# TP: 1125, TN: 1364, FP: 453, FN: 80
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.75      0.84      1817
#            1       0.71      0.93      0.81      1205
#
#     accuracy                           0.82      3022
#    macro avg       0.83      0.84      0.82      3022
# weighted avg       0.85      0.82      0.83      3022
#
# Model saved to models/rf\rf_under_under_sampled_residual_cnn_features_128.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/under_sampled_residual_cnn_features_256.csv...
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:484: FutureWarning: `BaseEstimator._check_n_features` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation._check_n_features` instead.
#   warnings.warn(
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:493: FutureWarning: `BaseEstimator._check_feature_names` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation._check_feature_names` instead.
#   warnings.warn(
# Accuracy  : 0.8223
# Precision : 0.7093
# Recall    : 0.9394
# F1 Score  : 0.8083
# F2 Score  : 0.8822
# Best Threshold  : 0.19999999999999996
# TP: 1132, TN: 1353, FP: 464, FN: 73
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.95      0.74      0.83      1817
#            1       0.71      0.94      0.81      1205
#
#     accuracy                           0.82      3022
#    macro avg       0.83      0.84      0.82      3022
# weighted avg       0.85      0.82      0.82      3022
#
# Model saved to models/rf\rf_under_under_sampled_residual_cnn_features_256.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/weighted_residual_cnn_features_32.csv...
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:484: FutureWarning: `BaseEstimator._check_n_features` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation._check_n_features` instead.
#   warnings.warn(
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:493: FutureWarning: `BaseEstimator._check_feature_names` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation._check_feature_names` instead.
#   warnings.warn(
# Accuracy  : 0.8210
# Precision : 0.7067
# Recall    : 0.9419
# F1 Score  : 0.8075
# F2 Score  : 0.8831
# Best Threshold  : 0.18999999999999995
# TP: 1135, TN: 1346, FP: 471, FN: 70
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.95      0.74      0.83      1817
#            1       0.71      0.94      0.81      1205
#
#     accuracy                           0.82      3022
#    macro avg       0.83      0.84      0.82      3022
# weighted avg       0.85      0.82      0.82      3022
#
# Model saved to models/rf\rf_under_weighted_residual_cnn_features_32.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/weighted_residual_cnn_features_64.csv...
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:484: FutureWarning: `BaseEstimator._check_n_features` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation._check_n_features` instead.
#   warnings.warn(
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:493: FutureWarning: `BaseEstimator._check_feature_names` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation._check_feature_names` instead.
#   warnings.warn(
# Accuracy  : 0.7803
# Precision : 0.6555
# Recall    : 0.9461
# F1 Score  : 0.7745
# F2 Score  : 0.8690
# Best Threshold  : 0.18999999999999995
# TP: 1140, TN: 1218, FP: 599, FN: 65
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.95      0.67      0.79      1817
#            1       0.66      0.95      0.77      1205
#
#     accuracy                           0.78      3022
#    macro avg       0.80      0.81      0.78      3022
# weighted avg       0.83      0.78      0.78      3022
#
# Model saved to models/rf\rf_under_weighted_residual_cnn_features_64.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/weighted_residual_cnn_features_128.csv...
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:484: FutureWarning: `BaseEstimator._check_n_features` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation._check_n_features` instead.
#   warnings.warn(
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:493: FutureWarning: `BaseEstimator._check_feature_names` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation._check_feature_names` instead.
#   warnings.warn(
# Accuracy  : 0.7905
# Precision : 0.6636
# Recall    : 0.9627
# F1 Score  : 0.7856
# F2 Score  : 0.8831
# Best Threshold  : 0.14999999999999997
# TP: 1160, TN: 1229, FP: 588, FN: 45
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.96      0.68      0.80      1817
#            1       0.66      0.96      0.79      1205
#
#     accuracy                           0.79      3022
#    macro avg       0.81      0.82      0.79      3022
# weighted avg       0.84      0.79      0.79      3022
#
# Model saved to models/rf\rf_under_weighted_residual_cnn_features_128.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/weighted_residual_cnn_features_256.csv...
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:484: FutureWarning: `BaseEstimator._check_n_features` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation._check_n_features` instead.
#   warnings.warn(
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:493: FutureWarning: `BaseEstimator._check_feature_names` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation._check_feature_names` instead.
#   warnings.warn(
# Accuracy  : 0.8008
# Precision : 0.6800
# Recall    : 0.9452
# F1 Score  : 0.7910
# F2 Score  : 0.8768
# Best Threshold  : 0.18999999999999995
# TP: 1139, TN: 1281, FP: 536, FN: 66
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.95      0.71      0.81      1817
#            1       0.68      0.95      0.79      1205
#
#     accuracy                           0.80      3022
#    macro avg       0.82      0.83      0.80      3022
# weighted avg       0.84      0.80      0.80      3022
#
# Model saved to models/rf\rf_under_weighted_residual_cnn_features_256.joblib
# Results saved to results_summary.csv

# %% [markdown]
# ### Over-Sampled

# %%
train(residual_dataset_paths, "rf", "over")
# Out:
# Processing ../feature-extraction/residual_cnn/datasets/normal_residual_cnn_features_32.csv...
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# Accuracy  : 0.8216
# Precision : 0.7105
# Recall    : 0.9328
# F1 Score  : 0.8066
# F2 Score  : 0.8779
# Best Threshold  : 0.13
# TP: 1124, TN: 1359, FP: 458, FN: 81
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.75      0.83      1817
#            1       0.71      0.93      0.81      1205
#
#     accuracy                           0.82      3022
#    macro avg       0.83      0.84      0.82      3022
# weighted avg       0.85      0.82      0.82      3022
#
# Model saved to models/rf\rf_over_normal_residual_cnn_features_32.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/normal_residual_cnn_features_64.csv...
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# Accuracy  : 0.8379
# Precision : 0.7391
# Recall    : 0.9170
# F1 Score  : 0.8185
# F2 Score  : 0.8749
# Best Threshold  : 0.18999999999999995
# TP: 1105, TN: 1427, FP: 390, FN: 100
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.93      0.79      0.85      1817
#            1       0.74      0.92      0.82      1205
#
#     accuracy                           0.84      3022
#    macro avg       0.84      0.85      0.84      3022
# weighted avg       0.86      0.84      0.84      3022
#
# Model saved to models/rf\rf_over_normal_residual_cnn_features_64.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/normal_residual_cnn_features_128.csv...
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# Accuracy  : 0.8226
# Precision : 0.7148
# Recall    : 0.9237
# F1 Score  : 0.8059
# F2 Score  : 0.8727
# Best Threshold  : 0.16999999999999998
# TP: 1113, TN: 1373, FP: 444, FN: 92
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.76      0.84      1817
#            1       0.71      0.92      0.81      1205
#
#     accuracy                           0.82      3022
#    macro avg       0.83      0.84      0.82      3022
# weighted avg       0.85      0.82      0.82      3022
#
# Model saved to models/rf\rf_over_normal_residual_cnn_features_128.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/normal_residual_cnn_features_256.csv...
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# Accuracy  : 0.7879
# Precision : 0.6628
# Recall    : 0.9527
# F1 Score  : 0.7818
# F2 Score  : 0.8761
# Best Threshold  : 0.1
# TP: 1148, TN: 1233, FP: 584, FN: 57
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.96      0.68      0.79      1817
#            1       0.66      0.95      0.78      1205
#
#     accuracy                           0.79      3022
#    macro avg       0.81      0.82      0.79      3022
# weighted avg       0.84      0.79      0.79      3022
#
# Model saved to models/rf\rf_over_normal_residual_cnn_features_256.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/over_sampled_residual_cnn_features_32.csv...
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# Accuracy  : 0.8236
# Precision : 0.7066
# Recall    : 0.9535
# F1 Score  : 0.8117
# F2 Score  : 0.8913
# Best Threshold  : 0.1
# TP: 1149, TN: 1340, FP: 477, FN: 56
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.96      0.74      0.83      1817
#            1       0.71      0.95      0.81      1205
#
#     accuracy                           0.82      3022
#    macro avg       0.83      0.85      0.82      3022
# weighted avg       0.86      0.82      0.83      3022
#
# Model saved to models/rf\rf_over_over_sampled_residual_cnn_features_32.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/over_sampled_residual_cnn_features_64.csv...
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# Accuracy  : 0.8316
# Precision : 0.7254
# Recall    : 0.9295
# F1 Score  : 0.8148
# F2 Score  : 0.8799
# Best Threshold  : 0.17999999999999997
# TP: 1120, TN: 1393, FP: 424, FN: 85
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.77      0.85      1817
#            1       0.73      0.93      0.81      1205
#
#     accuracy                           0.83      3022
#    macro avg       0.83      0.85      0.83      3022
# weighted avg       0.86      0.83      0.83      3022
#
# Model saved to models/rf\rf_over_over_sampled_residual_cnn_features_64.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/over_sampled_residual_cnn_features_128.csv...
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# Accuracy  : 0.8021
# Precision : 0.6795
# Recall    : 0.9535
# F1 Score  : 0.7935
# F2 Score  : 0.8824
# Best Threshold  : 0.11
# TP: 1149, TN: 1275, FP: 542, FN: 56
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.96      0.70      0.81      1817
#            1       0.68      0.95      0.79      1205
#
#     accuracy                           0.80      3022
#    macro avg       0.82      0.83      0.80      3022
# weighted avg       0.85      0.80      0.80      3022
#
# Model saved to models/rf\rf_over_over_sampled_residual_cnn_features_128.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/over_sampled_residual_cnn_features_256.csv...
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# Accuracy  : 0.7952
# Precision : 0.6717
# Recall    : 0.9510
# F1 Score  : 0.7874
# F2 Score  : 0.8780
# Best Threshold  : 0.1
# TP: 1146, TN: 1257, FP: 560, FN: 59
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.96      0.69      0.80      1817
#            1       0.67      0.95      0.79      1205
#
#     accuracy                           0.80      3022
#    macro avg       0.81      0.82      0.79      3022
# weighted avg       0.84      0.80      0.80      3022
#
# Model saved to models/rf\rf_over_over_sampled_residual_cnn_features_256.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/under_sampled_residual_cnn_features_32.csv...
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# Accuracy  : 0.7955
# Precision : 0.6742
# Recall    : 0.9427
# F1 Score  : 0.7862
# F2 Score  : 0.8732
# Best Threshold  : 0.13999999999999999
# TP: 1136, TN: 1268, FP: 549, FN: 69
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.95      0.70      0.80      1817
#            1       0.67      0.94      0.79      1205
#
#     accuracy                           0.80      3022
#    macro avg       0.81      0.82      0.80      3022
# weighted avg       0.84      0.80      0.80      3022
#
# Model saved to models/rf\rf_over_under_sampled_residual_cnn_features_32.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/under_sampled_residual_cnn_features_64.csv...
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# Accuracy  : 0.8312
# Precision : 0.7258
# Recall    : 0.9270
# F1 Score  : 0.8141
# F2 Score  : 0.8783
# Best Threshold  : 0.16999999999999998
# TP: 1117, TN: 1395, FP: 422, FN: 88
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.77      0.85      1817
#            1       0.73      0.93      0.81      1205
#
#     accuracy                           0.83      3022
#    macro avg       0.83      0.85      0.83      3022
# weighted avg       0.85      0.83      0.83      3022
#
# Model saved to models/rf\rf_over_under_sampled_residual_cnn_features_64.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/under_sampled_residual_cnn_features_128.csv...
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# Accuracy  : 0.8289
# Precision : 0.7228
# Recall    : 0.9261
# F1 Score  : 0.8119
# F2 Score  : 0.8768
# Best Threshold  : 0.14999999999999997
# TP: 1116, TN: 1389, FP: 428, FN: 89
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.76      0.84      1817
#            1       0.72      0.93      0.81      1205
#
#     accuracy                           0.83      3022
#    macro avg       0.83      0.85      0.83      3022
# weighted avg       0.85      0.83      0.83      3022
#
# Model saved to models/rf\rf_over_under_sampled_residual_cnn_features_128.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/under_sampled_residual_cnn_features_256.csv...
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# Accuracy  : 0.8170
# Precision : 0.7017
# Recall    : 0.9411
# F1 Score  : 0.8040
# F2 Score  : 0.8810
# Best Threshold  : 0.13
# TP: 1134, TN: 1335, FP: 482, FN: 71
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.95      0.73      0.83      1817
#            1       0.70      0.94      0.80      1205
#
#     accuracy                           0.82      3022
#    macro avg       0.83      0.84      0.82      3022
# weighted avg       0.85      0.82      0.82      3022
#
# Model saved to models/rf\rf_over_under_sampled_residual_cnn_features_256.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/weighted_residual_cnn_features_32.csv...
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# Accuracy  : 0.8134
# Precision : 0.6946
# Recall    : 0.9494
# F1 Score  : 0.8022
# F2 Score  : 0.8845
# Best Threshold  : 0.12
# TP: 1144, TN: 1314, FP: 503, FN: 61
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.96      0.72      0.82      1817
#            1       0.69      0.95      0.80      1205
#
#     accuracy                           0.81      3022
#    macro avg       0.83      0.84      0.81      3022
# weighted avg       0.85      0.81      0.81      3022
#
# Model saved to models/rf\rf_over_weighted_residual_cnn_features_32.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/weighted_residual_cnn_features_64.csv...
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# Accuracy  : 0.7925
# Precision : 0.6704
# Recall    : 0.9436
# F1 Score  : 0.7839
# F2 Score  : 0.8725
# Best Threshold  : 0.13999999999999999
# TP: 1137, TN: 1258, FP: 559, FN: 68
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.95      0.69      0.80      1817
#            1       0.67      0.94      0.78      1205
#
#     accuracy                           0.79      3022
#    macro avg       0.81      0.82      0.79      3022
# weighted avg       0.84      0.79      0.79      3022
#
# Model saved to models/rf\rf_over_weighted_residual_cnn_features_64.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/weighted_residual_cnn_features_128.csv...
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# Accuracy  : 0.8011
# Precision : 0.6785
# Recall    : 0.9527
# F1 Score  : 0.7925
# F2 Score  : 0.8814
# Best Threshold  : 0.11
# TP: 1148, TN: 1273, FP: 544, FN: 57
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.96      0.70      0.81      1817
#            1       0.68      0.95      0.79      1205
#
#     accuracy                           0.80      3022
#    macro avg       0.82      0.83      0.80      3022
# weighted avg       0.85      0.80      0.80      3022
#
# Model saved to models/rf\rf_over_weighted_residual_cnn_features_128.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/weighted_residual_cnn_features_256.csv...
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# Accuracy  : 0.8233
# Precision : 0.7149
# Recall    : 0.9261
# F1 Score  : 0.8069
# F2 Score  : 0.8745
# Best Threshold  : 0.15999999999999998
# TP: 1116, TN: 1372, FP: 445, FN: 89
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.76      0.84      1817
#            1       0.71      0.93      0.81      1205
#
#     accuracy                           0.82      3022
#    macro avg       0.83      0.84      0.82      3022
# weighted avg       0.85      0.82      0.83      3022
#
# Model saved to models/rf\rf_over_weighted_residual_cnn_features_256.joblib
# Results saved to results_summary.csv

# %% [markdown]
# ### Weighted

# %%
train(residual_dataset_paths, "rf", "weighted")
# Out:
# Processing ../feature-extraction/residual_cnn/datasets/normal_residual_cnn_features_32.csv...
# Accuracy  : 0.8213
# Precision : 0.7106
# Recall    : 0.9311
# F1 Score  : 0.8060
# F2 Score  : 0.8767
# Best Threshold  : 0.13
# TP: 1122, TN: 1360, FP: 457, FN: 83
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.75      0.83      1817
#            1       0.71      0.93      0.81      1205
#
#     accuracy                           0.82      3022
#    macro avg       0.83      0.84      0.82      3022
# weighted avg       0.85      0.82      0.82      3022
#
# Model saved to models/rf\rf_weighted_normal_residual_cnn_features_32.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/normal_residual_cnn_features_64.csv...
# Accuracy  : 0.8200
# Precision : 0.7083
# Recall    : 0.9328
# F1 Score  : 0.8052
# F2 Score  : 0.8772
# Best Threshold  : 0.13999999999999999
# TP: 1124, TN: 1354, FP: 463, FN: 81
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.75      0.83      1817
#            1       0.71      0.93      0.81      1205
#
#     accuracy                           0.82      3022
#    macro avg       0.83      0.84      0.82      3022
# weighted avg       0.85      0.82      0.82      3022
#
# Model saved to models/rf\rf_weighted_normal_residual_cnn_features_64.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/normal_residual_cnn_features_128.csv...
# Accuracy  : 0.8177
# Precision : 0.7059
# Recall    : 0.9303
# F1 Score  : 0.8027
# F2 Score  : 0.8747
# Best Threshold  : 0.14999999999999997
# TP: 1121, TN: 1350, FP: 467, FN: 84
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.74      0.83      1817
#            1       0.71      0.93      0.80      1205
#
#     accuracy                           0.82      3022
#    macro avg       0.82      0.84      0.82      3022
# weighted avg       0.85      0.82      0.82      3022
#
# Model saved to models/rf\rf_weighted_normal_residual_cnn_features_128.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/normal_residual_cnn_features_256.csv...
# Accuracy  : 0.8051
# Precision : 0.6860
# Recall    : 0.9427
# F1 Score  : 0.7941
# F2 Score  : 0.8771
# Best Threshold  : 0.12
# TP: 1136, TN: 1297, FP: 520, FN: 69
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.95      0.71      0.81      1817
#            1       0.69      0.94      0.79      1205
#
#     accuracy                           0.81      3022
#    macro avg       0.82      0.83      0.80      3022
# weighted avg       0.84      0.81      0.81      3022
#
# Model saved to models/rf\rf_weighted_normal_residual_cnn_features_256.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/over_sampled_residual_cnn_features_32.csv...
# Accuracy  : 0.8332
# Precision : 0.7200
# Recall    : 0.9519
# F1 Score  : 0.8199
# F2 Score  : 0.8943
# Best Threshold  : 0.11
# TP: 1147, TN: 1371, FP: 446, FN: 58
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.96      0.75      0.84      1817
#            1       0.72      0.95      0.82      1205
#
#     accuracy                           0.83      3022
#    macro avg       0.84      0.85      0.83      3022
# weighted avg       0.86      0.83      0.83      3022
#
# Model saved to models/rf\rf_weighted_over_sampled_residual_cnn_features_32.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/over_sampled_residual_cnn_features_64.csv...
# Accuracy  : 0.8339
# Precision : 0.7281
# Recall    : 0.9311
# F1 Score  : 0.8172
# F2 Score  : 0.8819
# Best Threshold  : 0.16999999999999998
# TP: 1122, TN: 1398, FP: 419, FN: 83
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.77      0.85      1817
#            1       0.73      0.93      0.82      1205
#
#     accuracy                           0.83      3022
#    macro avg       0.84      0.85      0.83      3022
# weighted avg       0.86      0.83      0.84      3022
#
# Model saved to models/rf\rf_weighted_over_sampled_residual_cnn_features_64.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/over_sampled_residual_cnn_features_128.csv...
# Accuracy  : 0.8332
# Precision : 0.7254
# Recall    : 0.9361
# F1 Score  : 0.8174
# F2 Score  : 0.8847
# Best Threshold  : 0.14999999999999997
# TP: 1128, TN: 1390, FP: 427, FN: 77
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.95      0.76      0.85      1817
#            1       0.73      0.94      0.82      1205
#
#     accuracy                           0.83      3022
#    macro avg       0.84      0.85      0.83      3022
# weighted avg       0.86      0.83      0.83      3022
#
# Model saved to models/rf\rf_weighted_over_sampled_residual_cnn_features_128.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/over_sampled_residual_cnn_features_256.csv...
# Accuracy  : 0.7962
# Precision : 0.6725
# Recall    : 0.9527
# F1 Score  : 0.7885
# F2 Score  : 0.8794
# Best Threshold  : 0.1
# TP: 1148, TN: 1258, FP: 559, FN: 57
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.96      0.69      0.80      1817
#            1       0.67      0.95      0.79      1205
#
#     accuracy                           0.80      3022
#    macro avg       0.81      0.82      0.80      3022
# weighted avg       0.84      0.80      0.80      3022
#
# Model saved to models/rf\rf_weighted_over_sampled_residual_cnn_features_256.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/under_sampled_residual_cnn_features_32.csv...
# Accuracy  : 0.8160
# Precision : 0.7032
# Recall    : 0.9320
# F1 Score  : 0.8016
# F2 Score  : 0.8750
# Best Threshold  : 0.15999999999999998
# TP: 1123, TN: 1343, FP: 474, FN: 82
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.74      0.83      1817
#            1       0.70      0.93      0.80      1205
#
#     accuracy                           0.82      3022
#    macro avg       0.82      0.84      0.82      3022
# weighted avg       0.85      0.82      0.82      3022
#
# Model saved to models/rf\rf_weighted_under_sampled_residual_cnn_features_32.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/under_sampled_residual_cnn_features_64.csv...
# Accuracy  : 0.8180
# Precision : 0.7061
# Recall    : 0.9311
# F1 Score  : 0.8031
# F2 Score  : 0.8753
# Best Threshold  : 0.13999999999999999
# TP: 1122, TN: 1350, FP: 467, FN: 83
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.74      0.83      1817
#            1       0.71      0.93      0.80      1205
#
#     accuracy                           0.82      3022
#    macro avg       0.82      0.84      0.82      3022
# weighted avg       0.85      0.82      0.82      3022
#
# Model saved to models/rf\rf_weighted_under_sampled_residual_cnn_features_64.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/under_sampled_residual_cnn_features_128.csv...
# Accuracy  : 0.8418
# Precision : 0.7451
# Recall    : 0.9170
# F1 Score  : 0.8222
# F2 Score  : 0.8766
# Best Threshold  : 0.16999999999999998
# TP: 1105, TN: 1439, FP: 378, FN: 100
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.79      0.86      1817
#            1       0.75      0.92      0.82      1205
#
#     accuracy                           0.84      3022
#    macro avg       0.84      0.85      0.84      3022
# weighted avg       0.86      0.84      0.84      3022
#
# Model saved to models/rf\rf_weighted_under_sampled_residual_cnn_features_128.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/under_sampled_residual_cnn_features_256.csv...
# Accuracy  : 0.8388
# Precision : 0.7359
# Recall    : 0.9295
# F1 Score  : 0.8214
# F2 Score  : 0.8830
# Best Threshold  : 0.14999999999999997
# TP: 1120, TN: 1415, FP: 402, FN: 85
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.78      0.85      1817
#            1       0.74      0.93      0.82      1205
#
#     accuracy                           0.84      3022
#    macro avg       0.84      0.85      0.84      3022
# weighted avg       0.86      0.84      0.84      3022
#
# Model saved to models/rf\rf_weighted_under_sampled_residual_cnn_features_256.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/weighted_residual_cnn_features_32.csv...
# Accuracy  : 0.8379
# Precision : 0.7338
# Recall    : 0.9311
# F1 Score  : 0.8208
# F2 Score  : 0.8836
# Best Threshold  : 0.14999999999999997
# TP: 1122, TN: 1410, FP: 407, FN: 83
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.78      0.85      1817
#            1       0.73      0.93      0.82      1205
#
#     accuracy                           0.84      3022
#    macro avg       0.84      0.85      0.84      3022
# weighted avg       0.86      0.84      0.84      3022
#
# Model saved to models/rf\rf_weighted_weighted_residual_cnn_features_32.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/weighted_residual_cnn_features_64.csv...
# Accuracy  : 0.7938
# Precision : 0.6728
# Recall    : 0.9402
# F1 Score  : 0.7844
# F2 Score  : 0.8710
# Best Threshold  : 0.13999999999999999
# TP: 1133, TN: 1266, FP: 551, FN: 72
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.95      0.70      0.80      1817
#            1       0.67      0.94      0.78      1205
#
#     accuracy                           0.79      3022
#    macro avg       0.81      0.82      0.79      3022
# weighted avg       0.84      0.79      0.80      3022
#
# Model saved to models/rf\rf_weighted_weighted_residual_cnn_features_64.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/weighted_residual_cnn_features_128.csv...
# Accuracy  : 0.8044
# Precision : 0.6830
# Recall    : 0.9510
# F1 Score  : 0.7950
# F2 Score  : 0.8818
# Best Threshold  : 0.12
# TP: 1146, TN: 1285, FP: 532, FN: 59
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.96      0.71      0.81      1817
#            1       0.68      0.95      0.80      1205
#
#     accuracy                           0.80      3022
#    macro avg       0.82      0.83      0.80      3022
# weighted avg       0.85      0.80      0.81      3022
#
# Model saved to models/rf\rf_weighted_weighted_residual_cnn_features_128.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/residual_cnn/datasets/weighted_residual_cnn_features_256.csv...
# Accuracy  : 0.8114
# Precision : 0.6954
# Recall    : 0.9378
# F1 Score  : 0.7986
# F2 Score  : 0.8766
# Best Threshold  : 0.13999999999999999
# TP: 1130, TN: 1322, FP: 495, FN: 75
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.95      0.73      0.82      1817
#            1       0.70      0.94      0.80      1205
#
#     accuracy                           0.81      3022
#    macro avg       0.82      0.83      0.81      3022
# weighted avg       0.85      0.81      0.81      3022
#
# Model saved to models/rf\rf_weighted_weighted_residual_cnn_features_256.joblib
# Results saved to results_summary.csv

# %% [markdown]
# ## 1D CNN

# %% [markdown]
# ### Datasets

# %%
cnn_1d_dataset_paths = [
    "../feature-extraction/1d_cnn/datasets/normal_1d_cnn_features_32.csv",
    "../feature-extraction/1d_cnn/datasets/normal_1d_cnn_features_64.csv",
    "../feature-extraction/1d_cnn/datasets/normal_1d_cnn_features_128.csv",
    "../feature-extraction/1d_cnn/datasets/normal_1d_cnn_features_256.csv",
    "../feature-extraction/1d_cnn/datasets/over_sampled_1d_cnn_features_32.csv",
    "../feature-extraction/1d_cnn/datasets/over_sampled_1d_cnn_features_64.csv",
    "../feature-extraction/1d_cnn/datasets/over_sampled_1d_cnn_features_128.csv",
    "../feature-extraction/1d_cnn/datasets/over_sampled_1d_cnn_features_256.csv",
    "../feature-extraction/1d_cnn/datasets/under_sampled_1d_cnn_features_32.csv",
    "../feature-extraction/1d_cnn/datasets/under_sampled_1d_cnn_features_64.csv",
    "../feature-extraction/1d_cnn/datasets/under_sampled_1d_cnn_features_128.csv",
    "../feature-extraction/1d_cnn/datasets/under_sampled_1d_cnn_features_256.csv",
    "../feature-extraction/1d_cnn/datasets/weighted_1d_cnn_features_32.csv",
    "../feature-extraction/1d_cnn/datasets/weighted_1d_cnn_features_64.csv",
    "../feature-extraction/1d_cnn/datasets/weighted_1d_cnn_features_128.csv",
    "../feature-extraction/1d_cnn/datasets/weighted_1d_cnn_features_256.csv",

]

# %% [markdown]
# ### Imbalanced

# %%
train(cnn_1d_dataset_paths, "rf", "normal")
# Out:
# Processing ../feature-extraction/1d_cnn/datasets/normal_1d_cnn_features_32.csv...
# Accuracy  : 0.8577
# Precision : 0.7666
# Recall    : 0.9242
# F1 Score  : 0.8381
# F2 Score  : 0.8877
# Best Threshold  : 0.14999999999999997
# TP: 1110, TN: 1476, FP: 338, FN: 91
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.81      0.87      1814
#            1       0.77      0.92      0.84      1201
#
#     accuracy                           0.86      3015
#    macro avg       0.85      0.87      0.86      3015
# weighted avg       0.87      0.86      0.86      3015
#
# Model saved to models/rf\rf_normal_normal_1d_cnn_features_32.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/1d_cnn/datasets/normal_1d_cnn_features_64.csv...
# Accuracy  : 0.8567
# Precision : 0.7654
# Recall    : 0.9234
# F1 Score  : 0.8370
# F2 Score  : 0.8868
# Best Threshold  : 0.13999999999999999
# TP: 1109, TN: 1474, FP: 340, FN: 92
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.81      0.87      1814
#            1       0.77      0.92      0.84      1201
#
#     accuracy                           0.86      3015
#    macro avg       0.85      0.87      0.85      3015
# weighted avg       0.87      0.86      0.86      3015
#
# Model saved to models/rf\rf_normal_normal_1d_cnn_features_64.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/1d_cnn/datasets/normal_1d_cnn_features_128.csv...
# Accuracy  : 0.8594
# Precision : 0.7715
# Recall    : 0.9192
# F1 Score  : 0.8389
# F2 Score  : 0.8853
# Best Threshold  : 0.13
# TP: 1104, TN: 1487, FP: 327, FN: 97
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.82      0.88      1814
#            1       0.77      0.92      0.84      1201
#
#     accuracy                           0.86      3015
#    macro avg       0.86      0.87      0.86      3015
# weighted avg       0.87      0.86      0.86      3015
#
# Model saved to models/rf\rf_normal_normal_1d_cnn_features_128.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/1d_cnn/datasets/normal_1d_cnn_features_256.csv...
# Accuracy  : 0.8411
# Precision : 0.7490
# Recall    : 0.9042
# F1 Score  : 0.8193
# F2 Score  : 0.8682
# Best Threshold  : 0.17999999999999997
# TP: 1086, TN: 1450, FP: 364, FN: 115
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.93      0.80      0.86      1814
#            1       0.75      0.90      0.82      1201
#
#     accuracy                           0.84      3015
#    macro avg       0.84      0.85      0.84      3015
# weighted avg       0.86      0.84      0.84      3015
#
# Model saved to models/rf\rf_normal_normal_1d_cnn_features_256.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/1d_cnn/datasets/over_sampled_1d_cnn_features_32.csv...
# Accuracy  : 0.8504
# Precision : 0.7520
# Recall    : 0.9317
# F1 Score  : 0.8323
# F2 Score  : 0.8892
# Best Threshold  : 0.11
# TP: 1119, TN: 1445, FP: 369, FN: 82
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.95      0.80      0.87      1814
#            1       0.75      0.93      0.83      1201
#
#     accuracy                           0.85      3015
#    macro avg       0.85      0.86      0.85      3015
# weighted avg       0.87      0.85      0.85      3015
#
# Model saved to models/rf\rf_normal_over_sampled_1d_cnn_features_32.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/1d_cnn/datasets/over_sampled_1d_cnn_features_64.csv...
# Accuracy  : 0.8511
# Precision : 0.7534
# Recall    : 0.9309
# F1 Score  : 0.8328
# F2 Score  : 0.8890
# Best Threshold  : 0.1
# TP: 1118, TN: 1448, FP: 366, FN: 83
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.95      0.80      0.87      1814
#            1       0.75      0.93      0.83      1201
#
#     accuracy                           0.85      3015
#    macro avg       0.85      0.86      0.85      3015
# weighted avg       0.87      0.85      0.85      3015
#
# Model saved to models/rf\rf_normal_over_sampled_1d_cnn_features_64.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/1d_cnn/datasets/over_sampled_1d_cnn_features_128.csv...
# Accuracy  : 0.8683
# Precision : 0.7871
# Recall    : 0.9176
# F1 Score  : 0.8474
# F2 Score  : 0.8881
# Best Threshold  : 0.12
# TP: 1102, TN: 1516, FP: 298, FN: 99
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.84      0.88      1814
#            1       0.79      0.92      0.85      1201
#
#     accuracy                           0.87      3015
#    macro avg       0.86      0.88      0.87      3015
# weighted avg       0.88      0.87      0.87      3015
#
# Model saved to models/rf\rf_normal_over_sampled_1d_cnn_features_128.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/1d_cnn/datasets/over_sampled_1d_cnn_features_256.csv...
# Accuracy  : 0.8511
# Precision : 0.7561
# Recall    : 0.9242
# F1 Score  : 0.8318
# F2 Score  : 0.8849
# Best Threshold  : 0.12
# TP: 1110, TN: 1456, FP: 358, FN: 91
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.80      0.87      1814
#            1       0.76      0.92      0.83      1201
#
#     accuracy                           0.85      3015
#    macro avg       0.85      0.86      0.85      3015
# weighted avg       0.87      0.85      0.85      3015
#
# Model saved to models/rf\rf_normal_over_sampled_1d_cnn_features_256.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/1d_cnn/datasets/under_sampled_1d_cnn_features_32.csv...
# Accuracy  : 0.8398
# Precision : 0.7368
# Recall    : 0.9301
# F1 Score  : 0.8222
# F2 Score  : 0.8837
# Best Threshold  : 0.13
# TP: 1117, TN: 1415, FP: 399, FN: 84
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.78      0.85      1814
#            1       0.74      0.93      0.82      1201
#
#     accuracy                           0.84      3015
#    macro avg       0.84      0.86      0.84      3015
# weighted avg       0.86      0.84      0.84      3015
#
# Model saved to models/rf\rf_normal_under_sampled_1d_cnn_features_32.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/1d_cnn/datasets/under_sampled_1d_cnn_features_64.csv...
# Accuracy  : 0.8478
# Precision : 0.7531
# Recall    : 0.9192
# F1 Score  : 0.8279
# F2 Score  : 0.8804
# Best Threshold  : 0.14999999999999997
# TP: 1104, TN: 1452, FP: 362, FN: 97
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.80      0.86      1814
#            1       0.75      0.92      0.83      1201
#
#     accuracy                           0.85      3015
#    macro avg       0.85      0.86      0.85      3015
# weighted avg       0.86      0.85      0.85      3015
#
# Model saved to models/rf\rf_normal_under_sampled_1d_cnn_features_64.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/1d_cnn/datasets/under_sampled_1d_cnn_features_128.csv...
# Accuracy  : 0.8511
# Precision : 0.7600
# Recall    : 0.9151
# F1 Score  : 0.8304
# F2 Score  : 0.8792
# Best Threshold  : 0.16999999999999998
# TP: 1099, TN: 1467, FP: 347, FN: 102
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.93      0.81      0.87      1814
#            1       0.76      0.92      0.83      1201
#
#     accuracy                           0.85      3015
#    macro avg       0.85      0.86      0.85      3015
# weighted avg       0.87      0.85      0.85      3015
#
# Model saved to models/rf\rf_normal_under_sampled_1d_cnn_features_128.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/1d_cnn/datasets/under_sampled_1d_cnn_features_256.csv...
# Accuracy  : 0.8478
# Precision : 0.7497
# Recall    : 0.9276
# F1 Score  : 0.8292
# F2 Score  : 0.8855
# Best Threshold  : 0.12
# TP: 1114, TN: 1442, FP: 372, FN: 87
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.79      0.86      1814
#            1       0.75      0.93      0.83      1201
#
#     accuracy                           0.85      3015
#    macro avg       0.85      0.86      0.85      3015
# weighted avg       0.87      0.85      0.85      3015
#
# Model saved to models/rf\rf_normal_under_sampled_1d_cnn_features_256.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/1d_cnn/datasets/weighted_1d_cnn_features_32.csv...
# Accuracy  : 0.8471
# Precision : 0.7493
# Recall    : 0.9259
# F1 Score  : 0.8283
# F2 Score  : 0.8842
# Best Threshold  : 0.13999999999999999
# TP: 1112, TN: 1442, FP: 372, FN: 89
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.79      0.86      1814
#            1       0.75      0.93      0.83      1201
#
#     accuracy                           0.85      3015
#    macro avg       0.85      0.86      0.85      3015
# weighted avg       0.87      0.85      0.85      3015
#
# Model saved to models/rf\rf_normal_weighted_1d_cnn_features_32.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/1d_cnn/datasets/weighted_1d_cnn_features_64.csv...
# Accuracy  : 0.8355
# Precision : 0.7315
# Recall    : 0.9276
# F1 Score  : 0.8179
# F2 Score  : 0.8804
# Best Threshold  : 0.13
# TP: 1114, TN: 1405, FP: 409, FN: 87
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.77      0.85      1814
#            1       0.73      0.93      0.82      1201
#
#     accuracy                           0.84      3015
#    macro avg       0.84      0.85      0.83      3015
# weighted avg       0.86      0.84      0.84      3015
#
# Model saved to models/rf\rf_normal_weighted_1d_cnn_features_64.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/1d_cnn/datasets/weighted_1d_cnn_features_128.csv...
# Accuracy  : 0.8381
# Precision : 0.7341
# Recall    : 0.9309
# F1 Score  : 0.8209
# F2 Score  : 0.8835
# Best Threshold  : 0.12
# TP: 1118, TN: 1409, FP: 405, FN: 83
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.78      0.85      1814
#            1       0.73      0.93      0.82      1201
#
#     accuracy                           0.84      3015
#    macro avg       0.84      0.85      0.84      3015
# weighted avg       0.86      0.84      0.84      3015
#
# Model saved to models/rf\rf_normal_weighted_1d_cnn_features_128.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/1d_cnn/datasets/weighted_1d_cnn_features_256.csv...
# Accuracy  : 0.8650
# Precision : 0.7820
# Recall    : 0.9167
# F1 Score  : 0.8440
# F2 Score  : 0.8862
# Best Threshold  : 0.14999999999999997
# TP: 1101, TN: 1507, FP: 307, FN: 100
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.83      0.88      1814
#            1       0.78      0.92      0.84      1201
#
#     accuracy                           0.87      3015
#    macro avg       0.86      0.87      0.86      3015
# weighted avg       0.88      0.87      0.87      3015
#
# Model saved to models/rf\rf_normal_weighted_1d_cnn_features_256.joblib
# Results saved to results_summary.csv

# %% [markdown]
# ### Under-Sampled

# %%
train(cnn_1d_dataset_paths, "rf", "under")
# Out:
# Processing ../feature-extraction/1d_cnn/datasets/normal_1d_cnn_features_32.csv...
# Accuracy  : 0.8624
# Precision : 0.7737
# Recall    : 0.9251
# F1 Score  : 0.8426
# F2 Score  : 0.8902
# Best Threshold  : 0.24999999999999992
# TP: 1111, TN: 1489, FP: 325, FN: 90
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.82      0.88      1814
#            1       0.77      0.93      0.84      1201
#
#     accuracy                           0.86      3015
#    macro avg       0.86      0.87      0.86      3015
# weighted avg       0.88      0.86      0.86      3015
#
# Model saved to models/rf\rf_under_normal_1d_cnn_features_32.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/1d_cnn/datasets/normal_1d_cnn_features_64.csv...
# Accuracy  : 0.8514
# Precision : 0.7539
# Recall    : 0.9309
# F1 Score  : 0.8331
# F2 Score  : 0.8891
# Best Threshold  : 0.20999999999999996
# TP: 1118, TN: 1449, FP: 365, FN: 83
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.95      0.80      0.87      1814
#            1       0.75      0.93      0.83      1201
#
#     accuracy                           0.85      3015
#    macro avg       0.85      0.86      0.85      3015
# weighted avg       0.87      0.85      0.85      3015
#
# Model saved to models/rf\rf_under_normal_1d_cnn_features_64.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/1d_cnn/datasets/normal_1d_cnn_features_128.csv...
# Accuracy  : 0.8935
# Precision : 0.8465
# Recall    : 0.8951
# F1 Score  : 0.8701
# F2 Score  : 0.8849
# Best Threshold  : 0.4299999999999998
# TP: 1075, TN: 1619, FP: 195, FN: 126
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.93      0.89      0.91      1814
#            1       0.85      0.90      0.87      1201
#
#     accuracy                           0.89      3015
#    macro avg       0.89      0.89      0.89      3015
# weighted avg       0.90      0.89      0.89      3015
#
# Model saved to models/rf\rf_under_normal_1d_cnn_features_128.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/1d_cnn/datasets/normal_1d_cnn_features_256.csv...
# Accuracy  : 0.8119
# Precision : 0.7001
# Recall    : 0.9234
# F1 Score  : 0.7964
# F2 Score  : 0.8680
# Best Threshold  : 0.19999999999999996
# TP: 1109, TN: 1339, FP: 475, FN: 92
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.74      0.83      1814
#            1       0.70      0.92      0.80      1201
#
#     accuracy                           0.81      3015
#    macro avg       0.82      0.83      0.81      3015
# weighted avg       0.84      0.81      0.81      3015
#
# Model saved to models/rf\rf_under_normal_1d_cnn_features_256.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/1d_cnn/datasets/over_sampled_1d_cnn_features_32.csv...
# Accuracy  : 0.8541
# Precision : 0.7587
# Recall    : 0.9292
# F1 Score  : 0.8353
# F2 Score  : 0.8892
# Best Threshold  : 0.17999999999999997
# TP: 1116, TN: 1459, FP: 355, FN: 85
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.80      0.87      1814
#            1       0.76      0.93      0.84      1201
#
#     accuracy                           0.85      3015
#    macro avg       0.85      0.87      0.85      3015
# weighted avg       0.87      0.85      0.86      3015
#
# Model saved to models/rf\rf_under_over_sampled_1d_cnn_features_32.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/1d_cnn/datasets/over_sampled_1d_cnn_features_64.csv...
# Accuracy  : 0.8633
# Precision : 0.7768
# Recall    : 0.9217
# F1 Score  : 0.8431
# F2 Score  : 0.8886
# Best Threshold  : 0.20999999999999996
# TP: 1107, TN: 1496, FP: 318, FN: 94
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.82      0.88      1814
#            1       0.78      0.92      0.84      1201
#
#     accuracy                           0.86      3015
#    macro avg       0.86      0.87      0.86      3015
# weighted avg       0.88      0.86      0.86      3015
#
# Model saved to models/rf\rf_under_over_sampled_1d_cnn_features_64.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/1d_cnn/datasets/over_sampled_1d_cnn_features_128.csv...
# Accuracy  : 0.8524
# Precision : 0.7551
# Recall    : 0.9317
# F1 Score  : 0.8341
# F2 Score  : 0.8901
# Best Threshold  : 0.13999999999999999
# TP: 1119, TN: 1451, FP: 363, FN: 82
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.95      0.80      0.87      1814
#            1       0.76      0.93      0.83      1201
#
#     accuracy                           0.85      3015
#    macro avg       0.85      0.87      0.85      3015
# weighted avg       0.87      0.85      0.85      3015
#
# Model saved to models/rf\rf_under_over_sampled_1d_cnn_features_128.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/1d_cnn/datasets/over_sampled_1d_cnn_features_256.csv...
# Accuracy  : 0.8388
# Precision : 0.7332
# Recall    : 0.9359
# F1 Score  : 0.8222
# F2 Score  : 0.8869
# Best Threshold  : 0.14999999999999997
# TP: 1124, TN: 1405, FP: 409, FN: 77
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.95      0.77      0.85      1814
#            1       0.73      0.94      0.82      1201
#
#     accuracy                           0.84      3015
#    macro avg       0.84      0.86      0.84      3015
# weighted avg       0.86      0.84      0.84      3015
#
# Model saved to models/rf\rf_under_over_sampled_1d_cnn_features_256.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/1d_cnn/datasets/under_sampled_1d_cnn_features_32.csv...
# Accuracy  : 0.8750
# Precision : 0.8047
# Recall    : 0.9059
# F1 Score  : 0.8523
# F2 Score  : 0.8837
# Best Threshold  : 0.33999999999999986
# TP: 1088, TN: 1550, FP: 264, FN: 113
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.93      0.85      0.89      1814
#            1       0.80      0.91      0.85      1201
#
#     accuracy                           0.87      3015
#    macro avg       0.87      0.88      0.87      3015
# weighted avg       0.88      0.87      0.88      3015
#
# Model saved to models/rf\rf_under_under_sampled_1d_cnn_features_32.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/1d_cnn/datasets/under_sampled_1d_cnn_features_64.csv...
# Accuracy  : 0.8763
# Precision : 0.8113
# Recall    : 0.8984
# F1 Score  : 0.8526
# F2 Score  : 0.8795
# Best Threshold  : 0.3799999999999999
# TP: 1079, TN: 1563, FP: 251, FN: 122
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.93      0.86      0.89      1814
#            1       0.81      0.90      0.85      1201
#
#     accuracy                           0.88      3015
#    macro avg       0.87      0.88      0.87      3015
# weighted avg       0.88      0.88      0.88      3015
#
# Model saved to models/rf\rf_under_under_sampled_1d_cnn_features_64.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/1d_cnn/datasets/under_sampled_1d_cnn_features_128.csv...
# Accuracy  : 0.8481
# Precision : 0.7553
# Recall    : 0.9151
# F1 Score  : 0.8276
# F2 Score  : 0.8779
# Best Threshold  : 0.2599999999999999
# TP: 1099, TN: 1458, FP: 356, FN: 102
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.93      0.80      0.86      1814
#            1       0.76      0.92      0.83      1201
#
#     accuracy                           0.85      3015
#    macro avg       0.84      0.86      0.85      3015
# weighted avg       0.86      0.85      0.85      3015
#
# Model saved to models/rf\rf_under_under_sampled_1d_cnn_features_128.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/1d_cnn/datasets/under_sampled_1d_cnn_features_256.csv...
# Accuracy  : 0.8418
# Precision : 0.7391
# Recall    : 0.9317
# F1 Score  : 0.8243
# F2 Score  : 0.8856
# Best Threshold  : 0.16999999999999998
# TP: 1119, TN: 1419, FP: 395, FN: 82
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.95      0.78      0.86      1814
#            1       0.74      0.93      0.82      1201
#
#     accuracy                           0.84      3015
#    macro avg       0.84      0.86      0.84      3015
# weighted avg       0.86      0.84      0.84      3015
#
# Model saved to models/rf\rf_under_under_sampled_1d_cnn_features_256.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/1d_cnn/datasets/weighted_1d_cnn_features_32.csv...
# Accuracy  : 0.8716
# Precision : 0.7980
# Recall    : 0.9076
# F1 Score  : 0.8492
# F2 Score  : 0.8833
# Best Threshold  : 0.32999999999999985
# TP: 1090, TN: 1538, FP: 276, FN: 111
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.93      0.85      0.89      1814
#            1       0.80      0.91      0.85      1201
#
#     accuracy                           0.87      3015
#    macro avg       0.87      0.88      0.87      3015
# weighted avg       0.88      0.87      0.87      3015
#
# Model saved to models/rf\rf_under_weighted_1d_cnn_features_32.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/1d_cnn/datasets/weighted_1d_cnn_features_64.csv...
# Accuracy  : 0.8368
# Precision : 0.7309
# Recall    : 0.9342
# F1 Score  : 0.8202
# F2 Score  : 0.8850
# Best Threshold  : 0.19999999999999996
# TP: 1122, TN: 1401, FP: 413, FN: 79
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.95      0.77      0.85      1814
#            1       0.73      0.93      0.82      1201
#
#     accuracy                           0.84      3015
#    macro avg       0.84      0.85      0.84      3015
# weighted avg       0.86      0.84      0.84      3015
#
# Model saved to models/rf\rf_under_weighted_1d_cnn_features_64.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/1d_cnn/datasets/weighted_1d_cnn_features_128.csv...
# Accuracy  : 0.8348
# Precision : 0.7287
# Recall    : 0.9326
# F1 Score  : 0.8181
# F2 Score  : 0.8831
# Best Threshold  : 0.16999999999999998
# TP: 1120, TN: 1397, FP: 417, FN: 81
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.95      0.77      0.85      1814
#            1       0.73      0.93      0.82      1201
#
#     accuracy                           0.83      3015
#    macro avg       0.84      0.85      0.83      3015
# weighted avg       0.86      0.83      0.84      3015
#
# Model saved to models/rf\rf_under_weighted_1d_cnn_features_128.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/1d_cnn/datasets/weighted_1d_cnn_features_256.csv...
# Accuracy  : 0.8580
# Precision : 0.7686
# Recall    : 0.9209
# F1 Score  : 0.8379
# F2 Score  : 0.8858
# Best Threshold  : 0.20999999999999996
# TP: 1106, TN: 1481, FP: 333, FN: 95
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.82      0.87      1814
#            1       0.77      0.92      0.84      1201
#
#     accuracy                           0.86      3015
#    macro avg       0.85      0.87      0.86      3015
# weighted avg       0.87      0.86      0.86      3015
#
# Model saved to models/rf\rf_under_weighted_1d_cnn_features_256.joblib
# Results saved to results_summary.csv

# %% [markdown]
# ### Over-Sampled

# %%
train(cnn_1d_dataset_paths, "rf", "over")
# Out:
# Processing ../feature-extraction/1d_cnn/datasets/normal_1d_cnn_features_32.csv...
# Accuracy  : 0.8478
# Precision : 0.7473
# Recall    : 0.9334
# F1 Score  : 0.8301
# F2 Score  : 0.8891
# Best Threshold  : 0.14999999999999997
# TP: 1121, TN: 1435, FP: 379, FN: 80
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.95      0.79      0.86      1814
#            1       0.75      0.93      0.83      1201
#
#     accuracy                           0.85      3015
#    macro avg       0.85      0.86      0.85      3015
# weighted avg       0.87      0.85      0.85      3015
#
# Model saved to models/rf\rf_over_normal_1d_cnn_features_32.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/1d_cnn/datasets/normal_1d_cnn_features_64.csv...
# Accuracy  : 0.8471
# Precision : 0.7477
# Recall    : 0.9301
# F1 Score  : 0.8289
# F2 Score  : 0.8868
# Best Threshold  : 0.13999999999999999
# TP: 1117, TN: 1437, FP: 377, FN: 84
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.79      0.86      1814
#            1       0.75      0.93      0.83      1201
#
#     accuracy                           0.85      3015
#    macro avg       0.85      0.86      0.85      3015
# weighted avg       0.87      0.85      0.85      3015
#
# Model saved to models/rf\rf_over_normal_1d_cnn_features_64.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/1d_cnn/datasets/normal_1d_cnn_features_128.csv...
# Accuracy  : 0.8574
# Precision : 0.7668
# Recall    : 0.9226
# F1 Score  : 0.8375
# F2 Score  : 0.8865
# Best Threshold  : 0.13999999999999999
# TP: 1108, TN: 1477, FP: 337, FN: 93
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.81      0.87      1814
#            1       0.77      0.92      0.84      1201
#
#     accuracy                           0.86      3015
#    macro avg       0.85      0.87      0.86      3015
# weighted avg       0.87      0.86      0.86      3015
#
# Model saved to models/rf\rf_over_normal_1d_cnn_features_128.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/1d_cnn/datasets/normal_1d_cnn_features_256.csv...
# Accuracy  : 0.8269
# Precision : 0.7247
# Recall    : 0.9117
# F1 Score  : 0.8075
# F2 Score  : 0.8670
# Best Threshold  : 0.16999999999999998
# TP: 1095, TN: 1398, FP: 416, FN: 106
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.93      0.77      0.84      1814
#            1       0.72      0.91      0.81      1201
#
#     accuracy                           0.83      3015
#    macro avg       0.83      0.84      0.83      3015
# weighted avg       0.85      0.83      0.83      3015
#
# Model saved to models/rf\rf_over_normal_1d_cnn_features_256.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/1d_cnn/datasets/over_sampled_1d_cnn_features_32.csv...
# Accuracy  : 0.8454
# Precision : 0.7439
# Recall    : 0.9334
# F1 Score  : 0.8279
# F2 Score  : 0.8881
# Best Threshold  : 0.12
# TP: 1121, TN: 1428, FP: 386, FN: 80
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.95      0.79      0.86      1814
#            1       0.74      0.93      0.83      1201
#
#     accuracy                           0.85      3015
#    macro avg       0.85      0.86      0.84      3015
# weighted avg       0.87      0.85      0.85      3015
#
# Model saved to models/rf\rf_over_over_sampled_1d_cnn_features_32.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/1d_cnn/datasets/over_sampled_1d_cnn_features_64.csv...
# Accuracy  : 0.8461
# Precision : 0.7439
# Recall    : 0.9359
# F1 Score  : 0.8289
# F2 Score  : 0.8899
# Best Threshold  : 0.1
# TP: 1124, TN: 1427, FP: 387, FN: 77
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.95      0.79      0.86      1814
#            1       0.74      0.94      0.83      1201
#
#     accuracy                           0.85      3015
#    macro avg       0.85      0.86      0.84      3015
# weighted avg       0.87      0.85      0.85      3015
#
# Model saved to models/rf\rf_over_over_sampled_1d_cnn_features_64.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/1d_cnn/datasets/over_sampled_1d_cnn_features_128.csv...
# Accuracy  : 0.8620
# Precision : 0.7731
# Recall    : 0.9251
# F1 Score  : 0.8423
# F2 Score  : 0.8901
# Best Threshold  : 0.12
# TP: 1111, TN: 1488, FP: 326, FN: 90
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.82      0.88      1814
#            1       0.77      0.93      0.84      1201
#
#     accuracy                           0.86      3015
#    macro avg       0.86      0.87      0.86      3015
# weighted avg       0.88      0.86      0.86      3015
#
# Model saved to models/rf\rf_over_over_sampled_1d_cnn_features_128.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/1d_cnn/datasets/over_sampled_1d_cnn_features_256.csv...
# Accuracy  : 0.8451
# Precision : 0.7434
# Recall    : 0.9334
# F1 Score  : 0.8276
# F2 Score  : 0.8880
# Best Threshold  : 0.11
# TP: 1121, TN: 1427, FP: 387, FN: 80
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.95      0.79      0.86      1814
#            1       0.74      0.93      0.83      1201
#
#     accuracy                           0.85      3015
#    macro avg       0.85      0.86      0.84      3015
# weighted avg       0.87      0.85      0.85      3015
#
# Model saved to models/rf\rf_over_over_sampled_1d_cnn_features_256.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/1d_cnn/datasets/under_sampled_1d_cnn_features_32.csv...
# Accuracy  : 0.8507
# Precision : 0.7539
# Recall    : 0.9284
# F1 Score  : 0.8321
# F2 Score  : 0.8873
# Best Threshold  : 0.15999999999999998
# TP: 1115, TN: 1450, FP: 364, FN: 86
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.80      0.87      1814
#            1       0.75      0.93      0.83      1201
#
#     accuracy                           0.85      3015
#    macro avg       0.85      0.86      0.85      3015
# weighted avg       0.87      0.85      0.85      3015
#
# Model saved to models/rf\rf_over_under_sampled_1d_cnn_features_32.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/1d_cnn/datasets/under_sampled_1d_cnn_features_64.csv...
# Accuracy  : 0.8235
# Precision : 0.7121
# Recall    : 0.9351
# F1 Score  : 0.8085
# F2 Score  : 0.8800
# Best Threshold  : 0.13
# TP: 1123, TN: 1360, FP: 454, FN: 78
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.95      0.75      0.84      1814
#            1       0.71      0.94      0.81      1201
#
#     accuracy                           0.82      3015
#    macro avg       0.83      0.84      0.82      3015
# weighted avg       0.85      0.82      0.83      3015
#
# Model saved to models/rf\rf_over_under_sampled_1d_cnn_features_64.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/1d_cnn/datasets/under_sampled_1d_cnn_features_128.csv...
# Accuracy  : 0.8421
# Precision : 0.7444
# Recall    : 0.9192
# F1 Score  : 0.8227
# F2 Score  : 0.8780
# Best Threshold  : 0.17999999999999997
# TP: 1104, TN: 1435, FP: 379, FN: 97
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.79      0.86      1814
#            1       0.74      0.92      0.82      1201
#
#     accuracy                           0.84      3015
#    macro avg       0.84      0.86      0.84      3015
# weighted avg       0.86      0.84      0.84      3015
#
# Model saved to models/rf\rf_over_under_sampled_1d_cnn_features_128.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/1d_cnn/datasets/under_sampled_1d_cnn_features_256.csv...
# Accuracy  : 0.8557
# Precision : 0.7671
# Recall    : 0.9159
# F1 Score  : 0.8349
# F2 Score  : 0.8817
# Best Threshold  : 0.15999999999999998
# TP: 1100, TN: 1480, FP: 334, FN: 101
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.82      0.87      1814
#            1       0.77      0.92      0.83      1201
#
#     accuracy                           0.86      3015
#    macro avg       0.85      0.87      0.85      3015
# weighted avg       0.87      0.86      0.86      3015
#
# Model saved to models/rf\rf_over_under_sampled_1d_cnn_features_256.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/1d_cnn/datasets/weighted_1d_cnn_features_32.csv...
# Accuracy  : 0.8328
# Precision : 0.7250
# Recall    : 0.9351
# F1 Score  : 0.8167
# F2 Score  : 0.8838
# Best Threshold  : 0.13
# TP: 1123, TN: 1388, FP: 426, FN: 78
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.95      0.77      0.85      1814
#            1       0.72      0.94      0.82      1201
#
#     accuracy                           0.83      3015
#    macro avg       0.84      0.85      0.83      3015
# weighted avg       0.86      0.83      0.83      3015
#
# Model saved to models/rf\rf_over_weighted_1d_cnn_features_32.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/1d_cnn/datasets/weighted_1d_cnn_features_64.csv...
# Accuracy  : 0.8328
# Precision : 0.7279
# Recall    : 0.9267
# F1 Score  : 0.8154
# F2 Score  : 0.8787
# Best Threshold  : 0.13999999999999999
# TP: 1113, TN: 1398, FP: 416, FN: 88
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.77      0.85      1814
#            1       0.73      0.93      0.82      1201
#
#     accuracy                           0.83      3015
#    macro avg       0.83      0.85      0.83      3015
# weighted avg       0.86      0.83      0.83      3015
#
# Model saved to models/rf\rf_over_weighted_1d_cnn_features_64.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/1d_cnn/datasets/weighted_1d_cnn_features_128.csv...
# Accuracy  : 0.8381
# Precision : 0.7353
# Recall    : 0.9276
# F1 Score  : 0.8203
# F2 Score  : 0.8815
# Best Threshold  : 0.13
# TP: 1114, TN: 1413, FP: 401, FN: 87
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.78      0.85      1814
#            1       0.74      0.93      0.82      1201
#
#     accuracy                           0.84      3015
#    macro avg       0.84      0.85      0.84      3015
# weighted avg       0.86      0.84      0.84      3015
#
# Model saved to models/rf\rf_over_weighted_1d_cnn_features_128.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/1d_cnn/datasets/weighted_1d_cnn_features_256.csv...
# Accuracy  : 0.8411
# Precision : 0.7372
# Recall    : 0.9342
# F1 Score  : 0.8241
# F2 Score  : 0.8868
# Best Threshold  : 0.12
# TP: 1122, TN: 1414, FP: 400, FN: 79
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.95      0.78      0.86      1814
#            1       0.74      0.93      0.82      1201
#
#     accuracy                           0.84      3015
#    macro avg       0.84      0.86      0.84      3015
# weighted avg       0.86      0.84      0.84      3015
#
# Model saved to models/rf\rf_over_weighted_1d_cnn_features_256.joblib
# Results saved to results_summary.csv

# %% [markdown]
# ### Weighted

# %%
train(cnn_1d_dataset_paths, "rf", "weighted")
# Out:
# Processing ../feature-extraction/1d_cnn/datasets/normal_1d_cnn_features_32.csv...
# Accuracy  : 0.8458
# Precision : 0.7453
# Recall    : 0.9309
# F1 Score  : 0.8278
# F2 Score  : 0.8867
# Best Threshold  : 0.13
# TP: 1118, TN: 1432, FP: 382, FN: 83
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.95      0.79      0.86      1814
#            1       0.75      0.93      0.83      1201
#
#     accuracy                           0.85      3015
#    macro avg       0.85      0.86      0.84      3015
# weighted avg       0.87      0.85      0.85      3015
#
# Model saved to models/rf\rf_weighted_normal_1d_cnn_features_32.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/1d_cnn/datasets/normal_1d_cnn_features_64.csv...
# Accuracy  : 0.8610
# Precision : 0.7742
# Recall    : 0.9192
# F1 Score  : 0.8405
# F2 Score  : 0.8860
# Best Threshold  : 0.14999999999999997
# TP: 1104, TN: 1492, FP: 322, FN: 97
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.82      0.88      1814
#            1       0.77      0.92      0.84      1201
#
#     accuracy                           0.86      3015
#    macro avg       0.86      0.87      0.86      3015
# weighted avg       0.87      0.86      0.86      3015
#
# Model saved to models/rf\rf_weighted_normal_1d_cnn_features_64.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/1d_cnn/datasets/normal_1d_cnn_features_128.csv...
# Accuracy  : 0.8846
# Precision : 0.8243
# Recall    : 0.9026
# F1 Score  : 0.8617
# F2 Score  : 0.8858
# Best Threshold  : 0.20999999999999996
# TP: 1084, TN: 1583, FP: 231, FN: 117
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.93      0.87      0.90      1814
#            1       0.82      0.90      0.86      1201
#
#     accuracy                           0.88      3015
#    macro avg       0.88      0.89      0.88      3015
# weighted avg       0.89      0.88      0.89      3015
#
# Model saved to models/rf\rf_weighted_normal_1d_cnn_features_128.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/1d_cnn/datasets/normal_1d_cnn_features_256.csv...
# Accuracy  : 0.8249
# Precision : 0.7212
# Recall    : 0.9134
# F1 Score  : 0.8060
# F2 Score  : 0.8672
# Best Threshold  : 0.14999999999999997
# TP: 1097, TN: 1390, FP: 424, FN: 104
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.93      0.77      0.84      1814
#            1       0.72      0.91      0.81      1201
#
#     accuracy                           0.82      3015
#    macro avg       0.83      0.84      0.82      3015
# weighted avg       0.85      0.82      0.83      3015
#
# Model saved to models/rf\rf_weighted_normal_1d_cnn_features_256.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/1d_cnn/datasets/over_sampled_1d_cnn_features_32.csv...
# Accuracy  : 0.8580
# Precision : 0.7671
# Recall    : 0.9242
# F1 Score  : 0.8384
# F2 Score  : 0.8879
# Best Threshold  : 0.12
# TP: 1110, TN: 1477, FP: 337, FN: 91
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.81      0.87      1814
#            1       0.77      0.92      0.84      1201
#
#     accuracy                           0.86      3015
#    macro avg       0.85      0.87      0.86      3015
# weighted avg       0.87      0.86      0.86      3015
#
# Model saved to models/rf\rf_weighted_over_sampled_1d_cnn_features_32.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/1d_cnn/datasets/over_sampled_1d_cnn_features_64.csv...
# Accuracy  : 0.8484
# Precision : 0.7487
# Recall    : 0.9326
# F1 Score  : 0.8306
# F2 Score  : 0.8889
# Best Threshold  : 0.1
# TP: 1120, TN: 1438, FP: 376, FN: 81
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.95      0.79      0.86      1814
#            1       0.75      0.93      0.83      1201
#
#     accuracy                           0.85      3015
#    macro avg       0.85      0.86      0.85      3015
# weighted avg       0.87      0.85      0.85      3015
#
# Model saved to models/rf\rf_weighted_over_sampled_1d_cnn_features_64.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/1d_cnn/datasets/over_sampled_1d_cnn_features_128.csv...
# Accuracy  : 0.8657
# Precision : 0.7807
# Recall    : 0.9217
# F1 Score  : 0.8454
# F2 Score  : 0.8896
# Best Threshold  : 0.11
# TP: 1107, TN: 1503, FP: 311, FN: 94
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.83      0.88      1814
#            1       0.78      0.92      0.85      1201
#
#     accuracy                           0.87      3015
#    macro avg       0.86      0.88      0.86      3015
# weighted avg       0.88      0.87      0.87      3015
#
# Model saved to models/rf\rf_weighted_over_sampled_1d_cnn_features_128.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/1d_cnn/datasets/over_sampled_1d_cnn_features_256.csv...
# Accuracy  : 0.8584
# Precision : 0.7688
# Recall    : 0.9217
# F1 Score  : 0.8383
# F2 Score  : 0.8865
# Best Threshold  : 0.13
# TP: 1107, TN: 1481, FP: 333, FN: 94
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.82      0.87      1814
#            1       0.77      0.92      0.84      1201
#
#     accuracy                           0.86      3015
#    macro avg       0.85      0.87      0.86      3015
# weighted avg       0.87      0.86      0.86      3015
#
# Model saved to models/rf\rf_weighted_over_sampled_1d_cnn_features_256.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/1d_cnn/datasets/under_sampled_1d_cnn_features_32.csv...
# Accuracy  : 0.8358
# Precision : 0.7286
# Recall    : 0.9367
# F1 Score  : 0.8197
# F2 Score  : 0.8861
# Best Threshold  : 0.12
# TP: 1125, TN: 1395, FP: 419, FN: 76
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.95      0.77      0.85      1814
#            1       0.73      0.94      0.82      1201
#
#     accuracy                           0.84      3015
#    macro avg       0.84      0.85      0.83      3015
# weighted avg       0.86      0.84      0.84      3015
#
# Model saved to models/rf\rf_weighted_under_sampled_1d_cnn_features_32.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/1d_cnn/datasets/under_sampled_1d_cnn_features_64.csv...
# Accuracy  : 0.8398
# Precision : 0.7400
# Recall    : 0.9217
# F1 Score  : 0.8209
# F2 Score  : 0.8786
# Best Threshold  : 0.13999999999999999
# TP: 1107, TN: 1425, FP: 389, FN: 94
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.79      0.86      1814
#            1       0.74      0.92      0.82      1201
#
#     accuracy                           0.84      3015
#    macro avg       0.84      0.85      0.84      3015
# weighted avg       0.86      0.84      0.84      3015
#
# Model saved to models/rf\rf_weighted_under_sampled_1d_cnn_features_64.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/1d_cnn/datasets/under_sampled_1d_cnn_features_128.csv...
# Accuracy  : 0.8428
# Precision : 0.7451
# Recall    : 0.9201
# F1 Score  : 0.8234
# F2 Score  : 0.8788
# Best Threshold  : 0.14999999999999997
# TP: 1105, TN: 1436, FP: 378, FN: 96
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.79      0.86      1814
#            1       0.75      0.92      0.82      1201
#
#     accuracy                           0.84      3015
#    macro avg       0.84      0.86      0.84      3015
# weighted avg       0.86      0.84      0.84      3015
#
# Model saved to models/rf\rf_weighted_under_sampled_1d_cnn_features_128.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/1d_cnn/datasets/under_sampled_1d_cnn_features_256.csv...
# Accuracy  : 0.8488
# Precision : 0.7519
# Recall    : 0.9259
# F1 Score  : 0.8299
# F2 Score  : 0.8849
# Best Threshold  : 0.12
# TP: 1112, TN: 1447, FP: 367, FN: 89
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.80      0.86      1814
#            1       0.75      0.93      0.83      1201
#
#     accuracy                           0.85      3015
#    macro avg       0.85      0.86      0.85      3015
# weighted avg       0.87      0.85      0.85      3015
#
# Model saved to models/rf\rf_weighted_under_sampled_1d_cnn_features_256.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/1d_cnn/datasets/weighted_1d_cnn_features_32.csv...
# Accuracy  : 0.8531
# Precision : 0.7607
# Recall    : 0.9209
# F1 Score  : 0.8331
# F2 Score  : 0.8837
# Best Threshold  : 0.14999999999999997
# TP: 1106, TN: 1466, FP: 348, FN: 95
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.81      0.87      1814
#            1       0.76      0.92      0.83      1201
#
#     accuracy                           0.85      3015
#    macro avg       0.85      0.86      0.85      3015
# weighted avg       0.87      0.85      0.85      3015
#
# Model saved to models/rf\rf_weighted_weighted_1d_cnn_features_32.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/1d_cnn/datasets/weighted_1d_cnn_features_64.csv...
# Accuracy  : 0.8398
# Precision : 0.7393
# Recall    : 0.9234
# F1 Score  : 0.8212
# F2 Score  : 0.8796
# Best Threshold  : 0.13999999999999999
# TP: 1109, TN: 1423, FP: 391, FN: 92
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.78      0.85      1814
#            1       0.74      0.92      0.82      1201
#
#     accuracy                           0.84      3015
#    macro avg       0.84      0.85      0.84      3015
# weighted avg       0.86      0.84      0.84      3015
#
# Model saved to models/rf\rf_weighted_weighted_1d_cnn_features_64.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/1d_cnn/datasets/weighted_1d_cnn_features_128.csv...
# Accuracy  : 0.8342
# Precision : 0.7274
# Recall    : 0.9334
# F1 Score  : 0.8177
# F2 Score  : 0.8834
# Best Threshold  : 0.11
# TP: 1121, TN: 1394, FP: 420, FN: 80
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.95      0.77      0.85      1814
#            1       0.73      0.93      0.82      1201
#
#     accuracy                           0.83      3015
#    macro avg       0.84      0.85      0.83      3015
# weighted avg       0.86      0.83      0.84      3015
#
# Model saved to models/rf\rf_weighted_weighted_1d_cnn_features_128.joblib
# Results saved to results_summary.csv
#
# Processing ../feature-extraction/1d_cnn/datasets/weighted_1d_cnn_features_256.csv...
# Accuracy  : 0.8557
# Precision : 0.7645
# Recall    : 0.9217
# F1 Score  : 0.8358
# F2 Score  : 0.8853
# Best Threshold  : 0.13
# TP: 1107, TN: 1473, FP: 341, FN: 94
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.81      0.87      1814
#            1       0.76      0.92      0.84      1201
#
#     accuracy                           0.86      3015
#    macro avg       0.85      0.87      0.85      3015
# weighted avg       0.87      0.86      0.86      3015
#
# Model saved to models/rf\rf_weighted_weighted_1d_cnn_features_256.joblib
# Results saved to results_summary.csv
