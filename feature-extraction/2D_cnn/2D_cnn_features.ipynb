# %% [markdown]
# ## Load Data

# %%
import numpy as np

loaded = np.load("../../ecg_dataset.npz")
X = loaded["x"]
y = loaded["y"]

# %%
X = X.transpose(0, 2, 1)[..., np.newaxis]  # now shape = (n_samples, 12, 5000, 1)

# %%
#import numpy as np
#from sklearn.model_selection import train_test_split

#from google.colab import drive

# Mount Google Drive
#drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Imports

# %%
from tensorflow.keras.models import load_model

model = load_model('../../models/3-layers/base_dense32_best_model.h5')
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
model.summary()
# Out:
# Model: "functional_19"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_19 (InputLayer)     │ (None, 12, 5000, 1)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_57 (Conv2D)              │ (None, 12, 5000, 32)   │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_57          │ (None, 12, 5000, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_57 (MaxPooling2D) │ (None, 6, 2500, 32)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# ...

# %%
for i, layer in enumerate(model.layers):
    print(i, layer.name)
# Out:
# 0 input_layer_19
# 1 conv2d_57
# 2 batch_normalization_57
# 3 max_pooling2d_57
# 4 conv2d_58
# 5 batch_normalization_58
# 6 max_pooling2d_58
# 7 conv2d_59
# 8 batch_normalization_59
# 9 max_pooling2d_59
# 10 flatten_19
# 11 dense_38
# 12 dropout_19
# 13 dense_39

# %%
from tensorflow.keras.models import Model

feature_extractor = Model(inputs=model.input, outputs=model.layers[-2].output)

# %%
feature_extractor.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_19 (InputLayer)     │ (None, 12, 5000, 1)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_57 (Conv2D)              │ (None, 12, 5000, 32)   │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_57          │ (None, 12, 5000, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_57 (MaxPooling2D) │ (None, 6, 2500, 32)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# ...

# %%
import os

import sys
sys.path.append('..')

from helper_functions import get_features_dataframe_with_metadata

# %% [markdown]
# # Import Model Definition

# %%
from tensorflow.keras.models import load_model, Model

def load_2d_cnn_feature_extractor_model(full_model_path):
    """
    Loads a trained 2D CNN model and returns a feature extraction model 
    that outputs from the second-to-last layer.
    """
    full_model = load_model(full_model_path)
    if len(full_model.layers) == 0:
        raise ValueError(f"No layers found in model loaded from: {full_model_path}")
    
    # Extract features from the layer before the final output
    feature_model = Model(inputs=full_model.input, outputs=full_model.layers[-2].output)
    return feature_model

# %% [markdown]
# # Base

# %% [markdown]
# ## n-32

# %%
feature_model = load_2d_cnn_feature_extractor_model('../../models/3-layers/base_dense32_best_model.h5')
df = get_features_dataframe_with_metadata(
    feature_model= feature_model,
    dataset_path='../../filtered_dataset.csv',
    ecg_signals=X
)

full_path = os.path.join("datasets", "features_with_metadata_base_dense32.csv")
df.to_csv(full_path, index=False)
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %% [markdown]
# ## n-64

# %%
feature_model = load_2d_cnn_feature_extractor_model('../../models/3-layers/base_dense64_best_model.h5')
df = get_features_dataframe_with_metadata(
    feature_model=feature_model,
    dataset_path='../../filtered_dataset.csv',
    ecg_signals=X
)

full_path = os.path.join("datasets", "features_with_metadata_base_dense64.csv")
df.to_csv(full_path, index=False)
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %% [markdown]
# ## n-128

# %%
feature_model = load_2d_cnn_feature_extractor_model('../../models/3-layers/base_dense128_best_model.h5')
df = get_features_dataframe_with_metadata(
    feature_model=feature_model,
    dataset_path='../../filtered_dataset.csv',
    ecg_signals=X
)

full_path = os.path.join("datasets", "features_with_metadata_base_dense128.csv")
df.to_csv(full_path, index=False)
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %% [markdown]
# ## n-256

# %%
feature_model = load_2d_cnn_feature_extractor_model('../../models/3-layers/base_dense256_best_model.h5')
df = get_features_dataframe_with_metadata(
    feature_model=feature_model,
    dataset_path='../../filtered_dataset.csv',
    ecg_signals=X
)

full_path = os.path.join("datasets", "features_with_metadata_base_dense256.csv")
df.to_csv(full_path, index=False)
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %% [markdown]
# # Weighted

# %% [markdown]
# ## n-32

# %%
feature_model = load_2d_cnn_feature_extractor_model('../../models/3-layers/weighted_dense32_best_model.h5')
df = get_features_dataframe_with_metadata(
    feature_model=feature_model,
    dataset_path='../../filtered_dataset.csv',
    ecg_signals=X
)

full_path = os.path.join("datasets", "features_with_metadata_weighted_dense32.csv")
df.to_csv(full_path, index=False)
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %% [markdown]
# ## n-64

# %%
feature_model = load_2d_cnn_feature_extractor_model('../../models/3-layers/weighted_dense64_best_model.h5')
df = get_features_dataframe_with_metadata(
    feature_model=feature_model,
    dataset_path='../../filtered_dataset.csv',
    ecg_signals=X
)

full_path = os.path.join("datasets", "features_with_metadata_weighted_dense64.csv")
df.to_csv(full_path, index=False)
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %% [markdown]
# ## n-128

# %%
feature_model = load_2d_cnn_feature_extractor_model('../../models/3-layers/weighted_dense128_best_model.h5')
df = get_features_dataframe_with_metadata(
    feature_model=feature_model,
    dataset_path='../../filtered_dataset.csv',
    ecg_signals=X
)

full_path = os.path.join("datasets", "features_with_metadata_weighted_dense128.csv")
df.to_csv(full_path, index=False)
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %% [markdown]
# ## n-256

# %%
feature_model = load_2d_cnn_feature_extractor_model('../../models/3-layers/weighted_dense256_best_model.h5')
df = get_features_dataframe_with_metadata(
    feature_model=feature_model,
    dataset_path='../../filtered_dataset.csv',
    ecg_signals=X
)

full_path = os.path.join("datasets", "features_with_metadata_weighted_dense256.csv")
df.to_csv(full_path, index=False)
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %% [markdown]
# # Under Sampled

# %% [markdown]
# ## n-32

# %%
feature_model = load_2d_cnn_feature_extractor_model('../../models/3-layers/undersampling_dense32_best_model.h5')
df = get_features_dataframe_with_metadata(
    feature_model=feature_model,
    dataset_path='../../filtered_dataset.csv',
    ecg_signals=X
)

full_path = os.path.join("datasets", "features_with_metadata_undersampling_dense32.csv")
df.to_csv(full_path, index=False)
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %% [markdown]
# ## n-64

# %%
feature_model = load_2d_cnn_feature_extractor_model('../../models/3-layers/undersampling_dense64_best_model.h5')
df = get_features_dataframe_with_metadata(
    feature_model=feature_model,
    dataset_path='../../filtered_dataset.csv',
    ecg_signals=X
)

full_path = os.path.join("datasets", "features_with_metadata_undersampling_dense64.csv")
df.to_csv(full_path, index=False)
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %% [markdown]
# ## n-128

# %%
feature_model = load_2d_cnn_feature_extractor_model('../../models/3-layers/undersampling_dense128_best_model.h5')
df = get_features_dataframe_with_metadata(
    feature_model=feature_model,
    dataset_path='../../filtered_dataset.csv',
    ecg_signals=X
)

full_path = os.path.join("datasets", "features_with_metadata_undersampling_dense128.csv")
df.to_csv(full_path, index=False)
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %% [markdown]
# ## n-256

# %%
feature_model = load_2d_cnn_feature_extractor_model('../../models/3-layers/undersampling_dense256_best_model.h5')
df = get_features_dataframe_with_metadata(
    feature_model=feature_model,
    dataset_path='../../filtered_dataset.csv',
    ecg_signals=X
)

full_path = os.path.join("datasets", "features_with_metadata_undersampling_dense256.csv")
df.to_csv(full_path, index=False)
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %% [markdown]
# # Over Sampled

# %% [markdown]
# ## n-32

# %%
feature_model = load_2d_cnn_feature_extractor_model('../../models/3-layers/oversampling_dense32_best_model.h5')
df = get_features_dataframe_with_metadata(
    feature_model=feature_model,
    dataset_path='../../filtered_dataset.csv',
    ecg_signals=X
)

full_path = os.path.join("datasets", "features_with_metadata_oversampling_dense32.csv")
df.to_csv(full_path, index=False)
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %% [markdown]
# ## n-64

# %%
feature_model = load_2d_cnn_feature_extractor_model('../../models/3-layers/oversampling_dense64_best_model.h5')
df = get_features_dataframe_with_metadata(
    feature_model=feature_model,
    dataset_path='../../filtered_dataset.csv',
    ecg_signals=X
)

full_path = os.path.join("datasets", "features_with_metadata_oversampling_dense64.csv")
df.to_csv(full_path, index=False)
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %% [markdown]
# ## n-128

# %%
feature_model = load_2d_cnn_feature_extractor_model('../../models/3-layers/oversampling_dense128_best_model.h5')
df = get_features_dataframe_with_metadata(
    feature_model=feature_model,
    dataset_path='../../filtered_dataset.csv',
    ecg_signals=X
)

full_path = os.path.join("datasets", "features_with_metadata_oversampling_dense128.csv")
df.to_csv(full_path, index=False)
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %% [markdown]
# ## n-256

# %%
feature_model = load_2d_cnn_feature_extractor_model('../../models/3-layers/oversampling_dense256_best_model.h5')
df = get_features_dataframe_with_metadata(
    feature_model=feature_model,
    dataset_path='../../filtered_dataset.csv',
    ecg_signals=X
)

full_path = os.path.join("datasets", "features_with_metadata_oversampling_dense256.csv")
df.to_csv(full_path, index=False)
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
