# %% [markdown]
# # Load Data

# %%
import numpy as np

loaded = np.load("../../ecg_dataset.npz")
X = loaded["x"]
y = loaded["y"]

# %% [markdown]
# # Imports

# %%
import os

import sys
sys.path.append('..')

from helper_functions import get_features_dataframe_with_metadata
# Out:
# WARNING:tensorflow:From C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\tensorflow_addons\utils\tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(
# ...

# %% [markdown]
# # Normal

# %% [markdown]
# ## n-32

# %%
df = get_features_dataframe_with_metadata("../../models/ResidualCNN/ResidualCNN_FeatureExtractor_32.h5", "../../filtered_dataset.csv", X)

full_path = os.path.join("datasets", "normal_residual_cnn_features_32.csv")

df.to_csv(full_path, index=False)

# %% [markdown]
# ## n-64

# %%
df = get_features_dataframe_with_metadata("../../models/ResidualCNN/ResidualCNN_FeatureExtractor_64.h5", "../../filtered_dataset.csv", X)

full_path = os.path.join("datasets", "normal_residual_cnn_features_64.csv")

df.to_csv(full_path, index=False)

# %% [markdown]
# ## n-128

# %%
df = get_features_dataframe_with_metadata("../../models/ResidualCNN/ResidualCNN_FeatureExtractor_128.h5", "../../filtered_dataset.csv", X)

full_path = os.path.join("datasets", "normal_residual_cnn_features_128.csv")

df.to_csv(full_path, index=False)

# %% [markdown]
# ## n-256

# %%
df = get_features_dataframe_with_metadata("../../models/ResidualCNN/ResidualCNN_FeatureExtractor_256.h5", "../../filtered_dataset.csv", X)

full_path = os.path.join("datasets", "normal_residual_cnn_features_256.csv")

df.to_csv(full_path, index=False)

# %% [markdown]
# # Weighted

# %% [markdown]
# ## n-32

# %%
df = get_features_dataframe_with_metadata("../../models/ResidualCNN/Weighted_ResidualCNN_FeatureExtractor_32.h5", "../../filtered_dataset.csv", X)

full_path = os.path.join("datasets", "weighted_residual_cnn_features_32.csv")

df.to_csv(full_path, index=False)

# %% [markdown]
# ## n-64

# %%
df = get_features_dataframe_with_metadata("../../models/ResidualCNN/Weighted_ResidualCNN_FeatureExtractor_64.h5", "../../filtered_dataset.csv", X)

full_path = os.path.join("datasets", "weighted_residual_cnn_features_64.csv")

df.to_csv(full_path, index=False)

# %% [markdown]
# ## n-128

# %%
df = get_features_dataframe_with_metadata("../../models/ResidualCNN/Weighted_ResidualCNN_FeatureExtractor_128.h5", "../../filtered_dataset.csv", X)

full_path = os.path.join("datasets", "weighted_residual_cnn_features_128.csv")

df.to_csv(full_path, index=False)

# %% [markdown]
# ## n-256

# %%
df = get_features_dataframe_with_metadata("../../models/ResidualCNN/Weighted_ResidualCNN_FeatureExtractor_256.h5", "../../filtered_dataset.csv", X)

full_path = os.path.join("datasets", "weighted_residual_cnn_features_256.csv")

df.to_csv(full_path, index=False)

# %% [markdown]
# # Under Sampled

# %% [markdown]
# ## n-32

# %%
df = get_features_dataframe_with_metadata("../../models/ResidualCNN/Under_Sampled_ResidualCNN_FeatureExtractor_32.h5", "../../filtered_dataset.csv", X)

full_path = os.path.join("datasets", "under_sampled_residual_cnn_features_32.csv")

df.to_csv(full_path, index=False)

# %% [markdown]
# ## n-64

# %%
df = get_features_dataframe_with_metadata("../../models/ResidualCNN/Under_Sampled_ResidualCNN_FeatureExtractor_64.h5", "../../filtered_dataset.csv", X)

full_path = os.path.join("datasets", "under_sampled_residual_cnn_features_64.csv")

df.to_csv(full_path, index=False)

# %% [markdown]
# ## n-128

# %%
df = get_features_dataframe_with_metadata("../../models/ResidualCNN/Under_Sampled_ResidualCNN_FeatureExtractor_128.h5", "../../filtered_dataset.csv", X)

full_path = os.path.join("datasets", "under_sampled_residual_cnn_features_128.csv")

df.to_csv(full_path, index=False)

# %% [markdown]
# ## n-256

# %%
df = get_features_dataframe_with_metadata("../../models/ResidualCNN/Under_Sampled_ResidualCNN_FeatureExtractor_256.h5", "../../filtered_dataset.csv", X)

full_path = os.path.join("datasets", "under_sampled_residual_cnn_features_256.csv")

df.to_csv(full_path, index=False)

# %% [markdown]
# # Over Sampled

# %% [markdown]
# ## n-32

# %%
df = get_features_dataframe_with_metadata("../../models/ResidualCNN/Over_Sampled_ResidualCNN_FeatureExtractor_32.h5", "../../filtered_dataset.csv", X)

full_path = os.path.join("datasets", "over_sampled_residual_cnn_features_32.csv")

df.to_csv(full_path, index=False)

# %% [markdown]
# ## n-64

# %%
df = get_features_dataframe_with_metadata("../../models/ResidualCNN/Over_Sampled_ResidualCNN_FeatureExtractor_64.h5", "../../filtered_dataset.csv", X)

full_path = os.path.join("datasets", "over_sampled_residual_cnn_features_64.csv")

df.to_csv(full_path, index=False)

# %% [markdown]
# ## n-128

# %%
df = get_features_dataframe_with_metadata("../../models/ResidualCNN/Over_Sampled_ResidualCNN_FeatureExtractor_128.h5", "../../filtered_dataset.csv", X)

full_path = os.path.join("datasets", "over_sampled_residual_cnn_features_128.csv")

df.to_csv(full_path, index=False)

# %% [markdown]
# ## n-256

# %%
df = get_features_dataframe_with_metadata("../../models/ResidualCNN/Over_Sampled_ResidualCNN_FeatureExtractor_256.h5", "../../filtered_dataset.csv", X)

full_path = os.path.join("datasets", "over_sampled_residual_cnn_features_256.csv")

df.to_csv(full_path, index=False)
